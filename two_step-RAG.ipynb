# %% [markdown]
# # Import required packages

# %%
#!pip install llama-cpp-python

# %%
#load packages
import pandas as pd
from functools import partial
from langchain.text_splitter import RecursiveCharacterTextSplitter
import os
import json
import tiktoken
import nltk
import chromadb
from sentence_transformers import SentenceTransformer
from transformers import AutoProcessor, AutoTokenizer, AutoModelForImageTextToText, AutoModelForCausalLM, AutoModel 
import torch
from huggingface_hub import login
from dotenv import load_dotenv
import torchvision
from llama_cpp import Llama
import requests

# %% [markdown]
# # Load in Documents
#
# In this section we will load in the scraped documents and clean them.

# %%
#read in csv for majors
majors = pd.read_csv("Scraped_data/uva_majors.csv")

#remove non major data
majors = majors.iloc[8:-1]

# %%
# remove the extra text from the text column
test = 'Info For Students Alumni Military Affiliated Students Faculty & Staff Search Search Submit Search Close search Info For Students Alumni Military Affiliated Students Faculty & Staff Calendars Academic Calendars Exam Schedules Student Records Diplomas Transcripts FERPA Programs Calendar Schools University Registrar Carruthers Hall, 1001 N. Emmet St. P.O. Box 400203 Charlottesville, VA 22904-4203 Staff Directory Contact Info Phone: (434) 924-4122 Fax: (434) 924-4156 Email: [email protected] Hours Of Operation M-F: 10am - noon and 1pm - 4pm Â© 2024 By the Rector and Visitors of the University of Virginia Legal Privacy Report a Barrier Share Your Feedback University of Virginia Mar 31, 2025 Undergraduate Record 2024-2025 Select a Catalog Undergraduate Record 2024-2025 Graduate Record 2024-2025 Global Search Catalog Search Choose Search Location Select an option Courses Programs Schools/Colleges & Departments Policies and Other Non-Academic Content Entire Catalog Search Keyword Field Whole Word/Phrase Advanced Search Catalog Navigation Catalog Home Academic Calendar Admission Schools Programs, Degrees & Course Info Student Resources ROTC University Regulations About UVA Archived Records HELP Undergraduate Record 2024-2025'
text_to_remove_head = 'Info For Students Alumni Military Affiliated Students Faculty & Staff Search Search Submit Search Close search Info For Students Alumni Military Affiliated Students Faculty & Staff Calendars Academic Calendars Exam Schedules Student Records Diplomas Transcripts FERPA Programs Calendar Schools University Registrar Carruthers Hall, 1001 N. Emmet St. P.O. Box 400203 Charlottesville, VA 22904-4203 Staff Directory Contact Info Phone: (434) 924-4122 Fax: (434) 924-4156 Email: [email protected] Hours Of Operation M-F: 10am - noon and 1pm - 4pm Â© 2024 By the Rector and Visitors of the University of Virginia Legal Privacy Report a Barrier Share Your Feedback University of Virginia Mar 12, 2025 Undergraduate Record 2024-2025 Select a Catalog Undergraduate Record 2024-2025 Graduate Record 2024-2025 Global Search Catalog Search Choose Search Location Select an option Courses Programs Schools/Colleges & Departments Policies and Other Non-Academic Content Entire Catalog Search Keyword Field Whole Word/Phrase Advanced Search Catalog Navigation Catalog Home Academic Calendar Admission Schools Programs, Degrees & Course Info Student Resources ROTC University Regulations About UVA Archived Records HELP Undergraduate Record 2024-2025' 
text_to_remove_tail = 'Back to Top | Print-Friendly Page (opens a new window) All catalogs © 2025 University of Virginia. Powered by Modern Campus Catalog™ . .'
#function to remove the text
def remove_text(text):
    if text.startswith(text_to_remove_head):
        text = text[len(text_to_remove_head):]
    if text.startswith(test):
        text = text[len(test):]
    if text.endswith(text_to_remove_tail):
        text = text[:-len(text_to_remove_tail)]
    return text.strip()

#apply the function to the text column
majors['Text'] = majors['Text'].apply(remove_text)

#since some of the majors have extra text that is a bit different, we need to remove it
majors[majors['Major'] == 'Psychology, B.A.']['Text']

#majors[50:90]
# Out:
# 64    Psychology, B.A. Print-Friendly Page (opens a ...
# Name: Text, dtype: object

# %%
# remove extra text from the majors column where majors includes "interdisciplinary"
text_to_remove = 'Interdisciplinary - '
text_to_remove2 = 'Interdisciplinary Major - '
def remove_text_majors(text):
    if text.startswith(text_to_remove):
        text = text[len(text_to_remove):]
    if text.startswith(text_to_remove2):
        text = text[len(text_to_remove2):]
    return text.strip()

#apply the function to the majors column
majors['Major'] = majors['Major'].apply(remove_text_majors)

# %%
majors[20:40]
# Out:
#                                Major  \
# 28                     English, B.A.
# 29      Environmental Sciences, B.A.
# 30      Environmental Sciences, B.S.
# 31             Foreign Affairs, B.A.
# 32                      French, B.A.
# 33                      German, B.A.
# 34                  Government, B.A.
# 35                     History, B.A.
# 36                  American Studies
# 37                       Archaeology
# 38     Chinese Language & Literature
# 39                 Cognitive Science
# 40                East Asian Studies
# 41  Environmental Thought & Practice
# 42                    German Studies
# 43                    Global Studies
# 44                     Human Biology
# 45    Japanese Language & Literature
# 46                    Jewish Studies
# 47                       Linguistics
#
#                                                  Text
# 28  English, B.A. Print-Friendly Page (opens a new...
# 29  Environmental Sciences, B.A. Print-Friendly Pa...
# 30  Environmental Sciences, B.S. Print-Friendly Pa...
# 31  Foreign Affairs, B.A. Print-Friendly Page (ope...
# 32  French, B.A. Print-Friendly Page (opens a new ...
# 33  German, B.A. Print-Friendly Page (opens a new ...
# 34  Government, B.A. Print-Friendly Page (opens a ...
# 35  History, B.A. Print-Friendly Page (opens a new...
# 36  Interdisciplinary Major - American Studies Pri...
# 37  Interdisciplinary Major - Archaeology Print-Fr...
# 38  Interdisciplinary Major - Chinese Language & L...
# 39  Interdisciplinary Major - Cognitive Science Pr...
# 40  Interdisciplinary Major - East Asian Studies P...
# 41  Interdisciplinary Major - Environmental Though...
# 42  Interdisciplinary Major - German Studies Print...
# 43  Interdisciplinary Major - Global Studies Print...
# 44  Interdisciplinary Major - Human Biology Print-...
# 45  Interdisciplinary Major - Japanese Language & ...
# 46  Interdisciplinary Major - Jewish Studies Print...
# 47  Interdisciplinary Major - Linguistics Print-Fr...

# %%
#read in schools data
schools = pd.read_csv("Scraped_data/uva_schools_academic_rules.csv")
schools
# Out:
#                                               School  \
# 0                             School of Architecture
# 1                         College of Arts & Sciences
# 2                        McIntire School of Commerce
# 3      School of Continuing and Professional Studies
# 4                             School of Data Science
# 5          School of Education and Human Development
# 6          School of Engineering and Applied Science
# 7  Frank Batten School of Leadership and Public P...
# 8                                  School of Nursing
#
#                                                 Text
# 0  Info For Students Alumni Military Affiliated S...
# 1  Info For Students Alumni Military Affiliated S...
# 2  Info For Students Alumni Military Affiliated S...
# 3  Info For Students Alumni Military Affiliated S...
# 4  Info For Students Alumni Military Affiliated S...
# 5  Info For Students Alumni Military Affiliated S...
# 6  Info For Students Alumni Military Affiliated S...
# 7  Info For Students Alumni Military Affiliated S...
# 8  Info For Students Alumni Military Affiliated S...

# %%
# remove the extra text from the text column
extra_begining_text = 'Info For Students Alumni Military Affiliated Students Faculty & Staff Search Search Submit Search Close search Info For Students Alumni Military Affiliated Students Faculty & Staff Calendars Academic Calendars Exam Schedules Student Records Diplomas Transcripts FERPA Programs Calendar Schools University Registrar Carruthers Hall, 1001 N. Emmet St. P.O. Box 400203 Charlottesville, VA 22904-4203 Staff Directory Contact Info Phone: (434) 924-4122 Fax: (434) 924-4156 Email: [email protected] Hours Of Operation M-F: 10am - noon and 1pm - 4pm Â© 2024 By the Rector and Visitors of the University of Virginia Legal Privacy Report a Barrier Share Your Feedback University of Virginia Mar 31, 2025 Undergraduate Record 2024-2025 Select a Catalog Undergraduate Record 2024-2025 Graduate Record 2024-2025 Global Search Catalog Search Choose Search Location Select an option Courses Programs Schools/Colleges & Departments Policies and Other Non-Academic Content Entire Catalog Search Keyword Field Whole Word/Phrase Advanced Search Catalog Navigation Catalog Home Academic Calendar Admission Schools Programs, Degrees & Course Info Student Resources ROTC University Regulations About UVA Archived Records HELP Undergraduate Record 2024-2025'

def remove_text_requirements(text):
    if text.startswith(extra_begining_text):
        text = text[len(extra_begining_text):]
    return text.strip()

#run the function on the text column
schools['Text'] = schools['Text'].apply(remove_text_requirements)

# %%
schools
# Out:
#                                               School  \
# 0                             School of Architecture
# 1                         College of Arts & Sciences
# 2                        McIntire School of Commerce
# 3      School of Continuing and Professional Studies
# 4                             School of Data Science
# 5          School of Education and Human Development
# 6          School of Engineering and Applied Science
# 7  Frank Batten School of Leadership and Public P...
# 8                                  School of Nursing
#
#                                                 Text
# 0  School of Architecture: Academic Rules, Regula...
# 1  College of Arts & Sciences: Academic Rules, Re...
# 2  McIntire School of Commerce: Academic Rules, R...
# 3  School of Continuing and Professional Studies:...
# 4  School of Data Science: Academic Rules Print-F...
# 5  School of Education and Human Development: Aca...
# 6  School of Engineering and Applied Science: Aca...
# 7  Frank Batten School of Leadership and Public P...
# 8  School of Nursing: Academic Rules, Regulations...

# %%
# read in class data
classes = pd.read_csv("Lous_List_Database/Fall_25_UVA_w_descr.csv")
classes.head()
# Out:
#    ClassNumber Mnemonic Number Section        Type Units  \
# 0        10003      AAS   1010     100     Lecture     4
# 1        12774      AAS   1010     101  Discussion     0
# 2        10006      AAS   1010     102  Discussion     0
# 3        10004      AAS   1010     103  Discussion     0
# 4        10005      AAS   1010     104  Discussion     0
#
#                         Instructor                   Days  \
# 0  Robert Vinson, Naseemah Mohamed  TuTh 12:30pm - 1:45pm
# 1                  To Be Announced     We 6:00pm - 6:50pm
# 2                  To Be Announced     We 5:00pm - 5:50pm
# 3                  To Be Announced     Tu 7:00pm - 7:50pm
# 4                  To Be Announced     Tu 8:00pm - 8:50pm
#
#                   Room                                              Title  \
# 0       Minor Hall 125  Introduction to African-American and African S...
# 1  New Cabell Hall 283  Introduction to African-American and African S...
# 2  New Cabell Hall 287  Introduction to African-American and African S...
# 3  New Cabell Hall 411  Introduction to African-American and African S...
# 4  New Cabell Hall 411  Introduction to African-American and African S...
#
#   Topic Status  Enrollment  EnrollmentLimit  Waitlist  \
# 0   NaN   Open           0              180         0
# 1   NaN   Open           0               20         0
# 2   NaN   Open           0               20         0
# 3   NaN   Open           0               20         0
# 4   NaN   Open           0               20         0
#
#                                          Description
# 0  This introductory course surveys the histories...
# 1  This introductory course surveys the histories...
# 2  This introductory course surveys the histories...
# 3  This introductory course surveys the histories...
# 4  This introductory course surveys the histories...

# %% [markdown]
# # Add school metadata to majors and convert to dictionary

# %%
# copy of the majors data frame
majors_meta = majors
majors_meta['School'] = None
majors_meta = majors_meta.reset_index(drop=True)

#add school to each majors in major data frame
majors_meta['School'][0:3] = 'School of Architecture'
majors_meta['School'][3:62] = 'College of Arts and Sciences'
majors_meta['School'][62:63] = 'McIntire School of Commerce'
majors_meta['School'][63:65] = 'School of Continuing and Professional Studies'
majors_meta['School'][65:66] = 'School of Data Science'
majors_meta['School'][66:72] = 'School of Education and Human Development'
majors_meta['School'][72:83] = 'School of Engineering and Applied Science'
majors_meta['School'][83:84] = 'Frank Batten School of Leadership and Public Policy'
majors_meta['School'][84:85] = 'School of Nursing'
# Out:
# /var/folders/42/069x05gj0h785d4_lrjy8mhw0000gn/T/ipykernel_51659/684139997.py:7: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   majors_meta['School'][0:3] = 'School of Architecture'
# /var/folders/42/069x05gj0h785d4_lrjy8mhw0000gn/T/ipykernel_51659/684139997.py:8: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   majors_meta['School'][3:62] = 'College of Arts and Sciences'
# /var/folders/42/069x05gj0h785d4_lrjy8mhw0000gn/T/ipykernel_51659/684139997.py:9: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   majors_meta['School'][62:63] = 'McIntire School of Commerce'
# /var/folders/42/069x05gj0h785d4_lrjy8mhw0000gn/T/ipykernel_51659/684139997.py:10: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   majors_meta['School'][63:65] = 'School of Continuing and Professional Studies'
# /var/folders/42/069x05gj0h785d4_lrjy8mhw0000gn/T/ipykernel_51659/684139997.py:11: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   majors_meta['School'][65:66] = 'School of Data Science'
# /var/folders/42/069x05gj0h785d4_lrjy8mhw0000gn/T/ipykernel_51659/684139997.py:12: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   majors_meta['School'][66:72] = 'School of Education and Human Development'
# /var/folders/42/069x05gj0h785d4_lrjy8mhw0000gn/T/ipykernel_51659/684139997.py:13: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   majors_meta['School'][72:83] = 'School of Engineering and Applied Science'
# /var/folders/42/069x05gj0h785d4_lrjy8mhw0000gn/T/ipykernel_51659/684139997.py:14: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   majors_meta['School'][83:84] = 'Frank Batten School of Leadership and Public Policy'
# /var/folders/42/069x05gj0h785d4_lrjy8mhw0000gn/T/ipykernel_51659/684139997.py:15: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   majors_meta['School'][84:85] = 'School of Nursing'

# %%
majors_meta.head(10)
# Out:
#                                         Major  \
# 0              Architectural History, B.Ar.H.
# 1                          Architecture, B.S.
# 2  Urban and Environmental Planning, B.U.E.P.
# 3  African-American and African Studies, B.A.
# 4                          Anthropology, B.A.
# 5                    Applied Statistics, B.A.
# 6                          Area Studies, B.A.
# 7                                 Art History
# 8                                  Studio Art
# 9                             Astronomy, B.A.
#
#                                                 Text  \
# 0  Architectural History, B.Ar.H. Print-Friendly ...
# 1  Architecture, B.S. Print-Friendly Page (opens ...
# 2  Urban and Environmental Planning, B.U.E.P. Pri...
# 3  African American and African Studies, B.A. Pri...
# 4  Anthropology, B.A. Print-Friendly Page (opens ...
# 5  Applied Statistics, B.A. Print-Friendly Page (...
# 6  Area Studies, B.A. Print-Friendly Page (opens ...
# 7  History of Art Print-Friendly Page (opens a ne...
# 8  Studio Art Print-Friendly Page (opens a new wi...
# 9  Astronomy, B.A. Print-Friendly Page (opens a n...
#
#                          School
# 0        School of Architecture
# 1        School of Architecture
# 2        School of Architecture
# 3  College of Arts and Sciences
# 4  College of Arts and Sciences
# 5  College of Arts and Sciences
# 6  College of Arts and Sciences
# 7  College of Arts and Sciences
# 8  College of Arts and Sciences
# 9  College of Arts and Sciences

# %%
#convert majors to dictionary
majors_dict = majors_meta.to_dict(orient='records')
majors_dict[0:2]
# Out:
# [{'Major': 'Architectural History, B.Ar.H.',
#   'Text': 'Architectural History, B.Ar.H. Print-Friendly Page (opens a new window) Return to: School of Architecture: Degree Programs Universal Curriculum Requirements To be awarded a degree from the School of Architecture, students are required to complete universal curriculum requirements in addition to the program requirements provided below. The school universal curriculum requirements can be found on the school Degree Programs page . Program Requirements Undergraduate students entering the School of Architecture share a Common First Year in the School of Architecture . Students take core courses in Architectural History, Architecture, and Urban & Environmental Planning to provide a framework for the study of\xa0the built environment\xa0through observation, analysis, and design. Students must pass each core course with a grade of C- or higher. During the spring semester of the first year, students choose an intended major: Bachelor of Architectural History (BArH), Bachelor of Science Architecture, or Bachelor of Urban and Environmental Planning. The undergraduate curriculum in architectural history provides an introduction to the discipline within a liberal arts program.\xa0Students select one of the following two concentrations: Architectural History or Historic Preservation. Students in both concentrations take the first-year School of Architecture curriculum, including ARH 1010 and ARH 1020. ARH 4591(certain ARTH 4591 courses may be substituted with permission of the Director of the Undergraduate Program) is taken in the third year as a preparatory research and writing course for the thesis. ARH 4999, taken during the fourth year, allows students to research and write an independent advanced paper on a topic of their choice while working closely with a faculty member in the department. Under certain circumstances, permission may be requested from the Director of the Undergraduate Program to work with a faculty member from outside the department. This thesis, with faculty comments, becomes part of the student’s permanent record. Those students considering the\xa04+1 Track in the\xa0Master of Architectural History\xa0program should take ARH 4999 during the fall semester of their fourth year. International travel and education abroad can provide unparalleled opportunities for students to refine and extend their study of architectural history. Department faculty enthusiastically encourage international study, and advisers work closely with students to integrate rigorous and rewarding study abroad experiences into their major. All students must take courses in the following areas in the College of Arts & Sciences as general education requirements: 6 credits in Natural Sciences/Mathematics, 6 credits in English/Foreign Literature (one of which must be ENWR), 6 credits in Historical Studies/Social Sciences. Students must demonstrate an intermediate level of competency in a foreign language. (4) Grading Standards Students must have a minimum of 122 credits with at least a 2.000 GPA in order to graduate with a Bachelor of Architectural History degree (10). The department also offers a minor in Architectural History, and a minor is also available in Historic Preservation. Concentrations Architectural History This concentration allows students to focus on architectural history from all periods and prepares them to write a thesis on a subject of their choice. To ensure breadth of knowledge, students must take at least one course from all four of the following distribution areas: the Americas, Asia & the Pacific, Africa & the Mediterranean, and Europe. An additional four Architectural History electives (12 credits) may be taken in areas of the student’s choice. The content of at least two courses taken to fulfill major requirements must be primarily before 1400. These courses must include ARH 4591 and ARH 4999. Appropriate historic preservation, landscape architecture, and art history courses may be used to fulfill architectural his ...
#   'School': 'School of Architecture'},
#  {'Major': 'Architecture, B.S.',
#   'Text': 'Architecture, B.S. Print-Friendly Page (opens a new window) Return to: School of Architecture: Degree Programs At UVA School of Architecture, our undergraduate Architecture programs are framed by an innovative curriculum that addresses the many ways in which design shapes and invents the world around us. The work of our students and faculty is investigative, critical, articulate, experimental and rigorous. The undergraduate curriculum in Architecture introduces students to methodologies to critically understand and creatively transform the built environment. Design innovation requires creativity, technical knowledge, cultural awareness, risk-taking, and meaningful questioning. Our curriculum uses design as a mode of critical inquiry to explore questions and pose new visions for a range of scales, all of which constitute the disciplinary realm of architecture: from cities, territories, infrastructure, and buildings to rooms, installations, furniture, and clothing. The first year of study is a shared Common First Year curriculum, wherein students take courses in three School of Architecture departments: Architecture, Urban + Environmental Planning, and Architectural History. Universal Curriculum Requirements To be awarded a degree from the School of Architecture, students are required to complete universal curriculum requirements in addition to the program requirements provided below. The school universal curriculum requirements can be found on the school Degree Programs page . Program Requirements Undergraduate students entering the School of Architecture share a common first-year curriculum. Students take core courses in Architectural History, Architecture and Urban and Environmental Planning to provide a framework for the study of contemporary culture through observation, analysis, and considered design of our ongoing constructed occupation of the earth. Students must pass each core course with a grade of C- or higher. For the first year curriculum, please refer to Common First Year in the School of Architecture. During the spring semester of the first year, students choose an intended major: Bachelor of Science Architecture, Bachelor of Architectural History, or\xa0Bachelor of Urban and Environmental Planning. Core Requirements Grading Standards A student must receive a grade of at least a C- in required courses,\xa0design studios, and minor requirements or must retake the course. Students must complete each of the Following courses: ARCH 1010\xa0-\xa0Lessons of the Lawn Credits: 3 ARCH 2010\xa0-\xa0Foundation Studio II Credits: 6 ARCH 2710\xa0-\xa0CAAD 3D Geometrical Modeling and Visualization Credits: 3 ARCH 2020\xa0-\xa0Foundation Studio III Credits: 6 ARH 3403\xa0-\xa0World Contemporary Architecture Credits: 3 ARCH 2114\xa0-\xa0Sustainability and Systems in the Built Environment Credits:          3 ARCH 3010\xa0-\xa0Foundation Studio IV Credits: 6 ARCH 3020\xa0-\xa0Foundation Studio V Credits: 6 ARCH 3120\xa0-\xa0Theories of Architecture Credits: 3 ARCH 3240\xa0-\xa0Introduction to Structural Design Credits:          3 ARCH 3260\xa0-\xa0Building Matters Credits: 3 ARCH 4010\xa0-\xa0Research Studio Credits: 6 ARCH 4100\xa0-\xa0Independent Design Research (Thesis) Seminar Credits:          3 ARCH 4020\xa0-\xa0Advanced Design Research Studio Credits:          6 OR ARCH 4995\xa0-\xa0Independent Design Research (Thesis) Studio Credits:          6 Open Electives (15 Credits) Humanities Elective (3 Credits) General Education Electives (12 Credits) Physics Electives (3 credits) Social /Behavioral Science Electives (3 credits) Notes Students interested in pursuing Independent Design Research (Thesis) Studio in their final year of study must apply for the IDR (Thesis) track and maintain the program requirements. If accepted, they must register for ARCH 4100 Independent Design Research (Thesis) Seminar in the fall semester in lieu of a School of Architecture Elective and ARCH 4995 Independent Design Research (Thesis) Stu ...
#   'School': 'School of Architecture'}]

# %%
#convert schools to dictionary
schools_dict = schools.to_dict(orient='records')
schools_dict[0:2]
# Out:
# [{'School': 'School of Architecture',
#   'Text': 'School of Architecture: Academic Rules, Regulations, and Information Print-Friendly Page (opens a new window) About Academic Rules Degree Programs Minor Programs Courses Click on a link to be taken to the entry below. Admission Requirements Academic Standing Appeals from Students Awards for Academic Excellence Curricular Requirements Course Rules Degree Information Direct Admissions Policy Grades Intra-University Transfers Leaving and Returning to the University Majors and Minors Public Professional Licensure Disclosure Student Intellectual Property Transfer Credit Admission Requirements All prospective undergraduate students apply through the University Office of Undergraduate Admissions; http://www.admission.virginia.edu/ For general information about the School of Architecture and undergraduate admissions: https://www.arch.virginia.edu/apply/undergraduate-admissions Academic Standing Academic Good Standing Students, in the School of Architecture, are considered to be in academic good standing at the end of a semester if, in that semester, they meet the following criteria: • Complete at least 12 credits of coursework. • Maintain at least a 2.0 cumulative GPA. • Have no more than one grade below C- (or NC for CR/NC). Academic Warning A student will be placed on academic warning\xa0if they fail to maintain academic good standing in any semester (see the “Academic Good Standing” section of the Record). Part-time students incur academic probation if they do not maintain a cumulative 2.000-grade\xa0point average. Academic Suspension Suspension is enforced withdrawal from the University. Any student who has previously been placed on academic probation will be suspended if placed on probation again. The term of the first suspension is through at least one full fall or one full spring semester. The term of a suspension may be longer, if the Dean’s Office decides it is appropriate for the circumstances. A second suspension is final and the student is not allowed to return to the University. Procedures for Returning to the University from suspension are described below under Returning to the University. Academic credits taken elsewhere while on academic suspension are not accepted for transfer towards a UVa degree. Attendance Students are expected to attend all class sessions in person, including lectures and other prescribed activities of the courses for which they are registered. Although the course instructor sets course attendance requirements, any student who is absent from more than 50 percent of the class sessions may automatically receive a grade of F in that course. Consistent with the UVA Undergraduate Record, unless otherwise notified by the instructor, students enrolled in all School of Architecture undergraduate courses are required to attend every scheduled class session in person and to arrive on time prepared for the class. If you are unable to attend a class session for any reason, you must notify your instructor in advance of the class. In courses where class participation represents a portion of the course grade, the instructor has complete discretion to assign the class participation grade that s/he decides is appropriate. Faculty may drop students from their course with notification who are not in attendance on the first day of the semester. Class Standing Students are categorized by class according to the number of credits they have earned as follows: first year: 0-29 credits; second year: 30-59 credits; third year: 60-89 credits; fourth year: 90 or more credits. AP and transfer credits are included in the computation of class standing; credits not completed or completed unsuccessfully are not included. Students in the Department of Architecture are classified according to their studio level. Satisfactory Progress Toward a Degree In order to enroll for a fifth semester , students must have earned at least 54 semester hours (includes approved summer, transfer, AP, IB and dual enrollment credits). To enr ...
#  {'School': 'College of Arts & Sciences',
#   'Text': 'College of Arts & Sciences: Academic Rules, Regulations, and Information Print-Friendly Page (opens a new window) About Academic Rules Degree Programs Minor Programs Courses Click on a link to be taken to the entry below. Academic Advising Academic Standing Appeals from Students Awards for Academic Excellence College Curriculum Course Rules Degree Information Final Examinations Grades Intra-University Transfers Leaving and Returning to the University Majors and Minors Study Abroad Transfer Credit Academic Advising Academic advising for College undergraduates is the responsibility of the Associate Dean for Undergraduate Programs, the assistant deans in the College (known as Association Deans), and the faculty of the departments within the College.\xa0 Detailed information about the academic policies and programs of the College, along with links to Departmental homepages is available at http://college.as.virginia.edu . In order to provide every entering student with individual academic advising, the College uses the association system.\xa0 The student body of the College is partitioned into numerous associations representing either first-year residence halls, Echols Scholars, student-athletes, veterans, or transfer students.\xa0 Each association has an Association Dean who serves as the academic advising dean throughout a student’s time in the College.\xa0 The Association Deans are experts regarding the academic policies and rules of the College, as well as the whole range of academic and non-academic resources available to undergraduates in the College.\xa0 The Association Deans are at the nexus of College advising and thus serve as the principal links between academic advising and the more general concerns of residential life in the College. In addition to Association Deans, upon matriculation every student is assigned a faculty member who serves as the student’s faculty advisor for the first two years.\xa0 Third-year and fourth-year students are assigned a major department advisor by their major department.\xa0 Each department and interdepartmental program has a faculty member designated as the Director of the Undergraduate Program who is charged with organizing undergraduate advising in its major.\xa0 These persons are thoroughly informed about every course offered for undergraduates in their respective fields. A list of the Directors appears online at the College’s website: http://college.as.virginia.edu/ugrad-directors .\xa0 Midway through each semester, the departments and interdepartmental programs in the College issue a complete description of courses to be offered in the following semester through SIS. Pre-Health Advising While there is no pre-medical minor or concentration at the University, a student planning to apply to medical, dental, or veterinary school should bear the following in mind when planning his/her undergraduate curriculum: Virtually all medical schools require one-year courses with laboratory in chemistry, biology, organic chemistry, and physics. Some schools also list requirements in English, mathematics, and the social sciences. Prospective students in health education should major in the subject that interests them most, as professional schools in the health sciences do not require specific undergraduate majors for admission.\xa0 However, non-science majors should elect the requisite science courses as they pursue their major, and science majors should elect advanced courses in the humanities and social sciences while they pursue their major.\xa0 Demonstrating a broad education in the liberal arts to admissions committees is most important.\xa0 Students should consult with their Association Dean regarding Pre-Health advising.\xa0 Additional advising is available through the University Career Center. Pre-Law Advising There is no pre-law program in the College, as law schools typically look for high achieving students regardless of their College major.\xa0 Students interested in law school ...

# %%
# dictionary for school to classes matching with Mnemonic
#query sis api
api_url = 'https://sisuva.admin.virginia.edu/psc/ihprd/UVSS/SA/s/WEBLIB_HCX_CM.H_CLASS_SEARCH.FieldFormula.IScript_ClassSearchOptions?institution=UVA01&term=1248'

r = requests.get(api_url)

sis = json.loads(r.text)
sis_df = pd.DataFrame(sis['subjects'])

# %%
# remove subject letters from descr column
sis_df['descr'] = sis_df.apply(lambda row: row['descr'].replace(row['subject'], ''), axis=1)
# remove extra spaces from descr column
sis_df['descr'] = sis_df['descr'].str.replace(r'- ', '', regex=True).str.replace(r'\s+', ' ', regex=True).str.strip()
sis_df.head()
# Out:
#   subject                                    descr acad_groups acad_orgs  \
# 0     AAS     African-American and African Studies      [CGAS]     [AAS]
# 1    ACCT                               Accounting      [SCPS]   [SCPSD]
# 2    AIRS                              Air Science      [PROV]    [AIRS]
# 3    ALAR  Architecture and Landscape Architecture      [ARCH]    [ALAR]
# 4    AMST                         American Studies      [CGAS]    [AMST]
#
#         careers campuses
# 0  [GRAD, UGRD]   [MAIN]
# 1  [GRAD, UGRD]   [SCPS]
# 2        [UGRD]   [MAIN]
# 3        [GRAD]   [MAIN]
# 4  [GRAD, UGRD]   [MAIN]

# %%
# Perform a left merge
merged_classes = classes.merge(sis_df[['subject', 'descr']], how='left', left_on='Mnemonic', right_on='subject')

# Drop the redundant 'subject' column from the merged DataFrame
merged_classes = merged_classes.drop(columns=['subject'])

# add column for semester = Fall and column for year = spring
merged_classes['semester'] = 'Fall'
merged_classes['year'] = '2025'

#replace nan description with 'none'
merged_classes['Description'] = merged_classes['Description'].fillna('none')


# Display the first few rows of the merged DataFrame
merged_classes.head()
# Out:
#    ClassNumber Mnemonic Number Section        Type Units  \
# 0        10003      AAS   1010     100     Lecture     4
# 1        12774      AAS   1010     101  Discussion     0
# 2        10006      AAS   1010     102  Discussion     0
# 3        10004      AAS   1010     103  Discussion     0
# 4        10005      AAS   1010     104  Discussion     0
#
#                         Instructor                   Days  \
# 0  Robert Vinson, Naseemah Mohamed  TuTh 12:30pm - 1:45pm
# 1                  To Be Announced     We 6:00pm - 6:50pm
# 2                  To Be Announced     We 5:00pm - 5:50pm
# 3                  To Be Announced     Tu 7:00pm - 7:50pm
# 4                  To Be Announced     Tu 8:00pm - 8:50pm
#
#                   Room                                              Title  \
# 0       Minor Hall 125  Introduction to African-American and African S...
# 1  New Cabell Hall 283  Introduction to African-American and African S...
# 2  New Cabell Hall 287  Introduction to African-American and African S...
# 3  New Cabell Hall 411  Introduction to African-American and African S...
# 4  New Cabell Hall 411  Introduction to African-American and African S...
#
#   Topic Status  Enrollment  EnrollmentLimit  Waitlist  \
# 0   NaN   Open           0              180         0
# 1   NaN   Open           0               20         0
# 2   NaN   Open           0               20         0
# 3   NaN   Open           0               20         0
# 4   NaN   Open           0               20         0
#
#                                          Description  \
# 0  This introductory course surveys the histories...
# 1  This introductory course surveys the histories...
# 2  This introductory course surveys the histories...
# 3  This introductory course surveys the histories...
# 4  This introductory course surveys the histories...
#
#                                   descr semester  year
# 0  African-American and African Studies     Fall  2025
# 1  African-American and African Studies     Fall  2025
# 2  African-American and African Studies     Fall  2025
# 3  African-American and African Studies     Fall  2025
# 4  African-American and African Studies     Fall  2025

# %%
#convdert classes to dictionary
classes_dict = merged_classes.to_dict(orient='records')
classes_dict[0:2]
# Out:
# [{'ClassNumber': 10003,
#   'Mnemonic': 'AAS',
#   'Number': '1010',
#   'Section': '100',
#   'Type': 'Lecture',
#   'Units': '4',
#   'Instructor': 'Robert Vinson, Naseemah Mohamed',
#   'Days': 'TuTh 12:30pm - 1:45pm',
#   'Room': 'Minor Hall 125',
#   'Title': 'Introduction to African-American and African Studies I',
#   'Topic': nan,
#   'Status': 'Open',
#   'Enrollment': 0,
#   'EnrollmentLimit': 180,
#   'Waitlist': 0,
#   'Description': 'This introductory course surveys the histories of people of African descent in Africa, the Americas, and the Caribbean from approximately the Middle Ages to the 1880s. Emphases include the Atlantic slave trade and its complex relationship to Africa; the economic systems, cultures, and communities of Africans and African-Americans in the New World, in slavery and in freedom; the rise of anti-slavery movements; and the socio-economic systems that replaced slavery in the late 19th century.',
#   'descr': 'African-American and African Studies',
#   'semester': 'Fall',
#   'year': '2025'},
#  {'ClassNumber': 12774,
#   'Mnemonic': 'AAS',
#   'Number': '1010',
#   'Section': '101',
#   'Type': 'Discussion',
#   'Units': '0',
#   'Instructor': 'To Be Announced',
#   'Days': 'We 6:00pm - 6:50pm',
#   'Room': 'New Cabell Hall 283',
#   'Title': 'Introduction to African-American and African Studies I',
#   'Topic': nan,
#   'Status': 'Open',
#   'Enrollment': 0,
#   'EnrollmentLimit': 20,
#   'Waitlist': 0,
#   'Description': 'This introductory course surveys the histories of people of African descent in Africa, the Americas, and the Caribbean from approximately the Middle Ages to the 1880s. Emphases include the Atlantic slave trade and its complex relationship to Africa; the economic systems, cultures, and communities of Africans and African-Americans in the New World, in slavery and in freedom; the rise of anti-slavery movements; and the socio-economic systems that replaced slavery in the late 19th century.',
#   'descr': 'African-American and African Studies',
#   'semester': 'Fall',
#   'year': '2025'}]

# %% [markdown]
# # Chunking

# %%
# disable tokenizer parallelism so we stop getting problems
os.environ["TOKENIZERS_PARALLELISM"] = "false"

# %%
nltk.download("punkt")

# Load tokenizer (for OpenAI models)
tokenizer = tiktoken.get_encoding("cl100k_base")

# Function to chunk text while maintaining sentence structure
def chunk_text(text, max_tokens=500):
    sentences = nltk.tokenize.sent_tokenize(text)
    chunks = []
    current_chunk = []
    current_length = 0

    for sentence in sentences:
        sentence_tokens = len(tokenizer.encode(sentence))
        if current_length + sentence_tokens > max_tokens:
            chunks.append(" ".join(current_chunk))
            current_chunk = []
            current_length = 0
        current_chunk.append(sentence)
        current_length += sentence_tokens

    if current_chunk:
        chunks.append(" ".join(current_chunk))

    return chunks
# Out:
# [nltk_data] Downloading package punkt to /Users/rfell/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!

# %% [markdown]
# # Store data in ChromaDB vectorized database

# %%
# Initialize ChromaDB
chroma_client = chromadb.PersistentClient(path="./chroma_db")  
collection = chroma_client.get_or_create_collection(name="Majors_Collection")
#create separate collection for classes
collection_classes = chroma_client.get_or_create_collection(name="Classes_Collection")

# Load embedding model
model = SentenceTransformer("all-MiniLM-L6-v2")

# %% [markdown]
# ## Don't rerun adding info to database

# %%
# Store chunked majors data
for course in majors_dict:
    chunks = chunk_text(course["Text"])
    for i, chunk in enumerate(chunks):
        embedding = model.encode(chunk).tolist()  # Convert to list for ChromaDB
        collection.add(
            ids=[f"{course['Major']}_chunk{i}"],  
            embeddings=[embedding],  
            metadatas=[{
                "Major": course["Major"],
                "chunk_index": i,
                "Text": chunk,
                "School": course['School']
            }]
        )

print("Chunked course descriptions stored in ChromaDB!")
# Out:
# Insert of existing embedding ID: Architectural History, B.Ar.H._chunk0
# Add of existing embedding ID: Architectural History, B.Ar.H._chunk0
# Insert of existing embedding ID: Architectural History, B.Ar.H._chunk1
# Add of existing embedding ID: Architectural History, B.Ar.H._chunk1
# Insert of existing embedding ID: Architectural History, B.Ar.H._chunk2
# Add of existing embedding ID: Architectural History, B.Ar.H._chunk2
# Insert of existing embedding ID: Architectural History, B.Ar.H._chunk3
# Add of existing embedding ID: Architectural History, B.Ar.H._chunk3
# Insert of existing embedding ID: Architecture, B.S._chunk0
# Add of existing embedding ID: Architecture, B.S._chunk0
# Insert of existing embedding ID: Architecture, B.S._chunk1
# Add of existing embedding ID: Architecture, B.S._chunk1
# Insert of existing embedding ID: Architecture, B.S._chunk2
# Add of existing embedding ID: Architecture, B.S._chunk2
# Insert of existing embedding ID: Urban and Environmental Planning, B.U.E.P._chunk0
# Add of existing embedding ID: Urban and Environmental Planning, B.U.E.P._chunk0
# Insert of existing embedding ID: Urban and Environmental Planning, B.U.E.P._chunk1
# Add of existing embedding ID: Urban and Environmental Planning, B.U.E.P._chunk1
# Insert of existing embedding ID: Urban and Environmental Planning, B.U.E.P._chunk2
# Add of existing embedding ID: Urban and Environmental Planning, B.U.E.P._chunk2
# Insert of existing embedding ID: Urban and Environmental Planning, B.U.E.P._chunk3
# Add of existing embedding ID: Urban and Environmental Planning, B.U.E.P._chunk3
# Insert of existing embedding ID: African-American and African Studies, B.A._chunk0
# Add of existing embedding ID: African-American and African Studies, B.A._chunk0
# Insert of existing embedding ID: African-American and African Studies, B.A._chunk1
# Add of existing embedding ID: African-American and African Studies, B.A._chunk1
# Insert of existing embedding ID: African-American and African Studies, B.A._chunk2
# Add of existing embedding ID: African-American and African Studies, B.A._chunk2
# Insert of existing embedding ID: Anthropology, B.A._chunk0
# Add of existing embedding ID: Anthropology, B.A._chunk0
# Insert of existing embedding ID: Anthropology, B.A._chunk1
# Add of existing embedding ID: Anthropology, B.A._chunk1
# Insert of existing embedding ID: Anthropology, B.A._chunk2
# Add of existing embedding ID: Anthropology, B.A._chunk2
# Insert of existing embedding ID: Anthropology, B.A._chunk3
# Add of existing embedding ID: Anthropology, B.A._chunk3
# Insert of existing embedding ID: Anthropology, B.A._chunk4
# Add of existing embedding ID: Anthropology, B.A._chunk4
# Insert of existing embedding ID: Anthropology, B.A._chunk5
# Add of existing embedding ID: Anthropology, B.A._chunk5
# Insert of existing embedding ID: Anthropology, B.A._chunk6
# Add of existing embedding ID: Anthropology, B.A._chunk6
# Insert of existing embedding ID: Anthropology, B.A._chunk7
# Add of existing embedding ID: Anthropology, B.A._chunk7
# Insert of existing embedding ID: Anthropology, B.A._chunk8
# Add of existing embedding ID: Anthropology, B.A._chunk8
# Insert of existing embedding ID: Anthropology, B.A._chunk9
# Add of existing embedding ID: Anthropology, B.A._chunk9
# Insert of existing embedding ID: Applied Statistics, B.A._chunk0
# Add of existing embedding ID: Applied Statistics, B.A._chunk0
# Insert of existing embedding ID: Applied Statistics, B.A._chunk1
# Add of existing embedding ID: Applied Statistics, B.A._chunk1
# Insert of existing embedding ID: Applied Statistics, B.A._chunk2
# Add of existing embedding ID: Applied Statistics, B.A._chunk2
# Insert of existing embedding ID: Applied Statistics, B.A._chunk3
# Add of existing embedding ID: Applied Statistics, B.A._chunk3
# Insert of existing embedding ID: Applied Statistics, B.A._chunk4
# Add of existing embedding ID: Applied Statistics, B.A._chunk4
# Insert of existing embedding ID: Applied Statistics, B.A._chunk5
# Add of existing embedding ID: Applied Statistics, B.A._chunk5
# Insert of existing embedding ID: Area Studies, B.A._chunk0
# Add of existing embedding ID: Area Studies, B.A._chunk0
# Insert of existing embedding ID: Area Studies, B.A._chunk1
# Add of existing embedding ID: Area Studies, B.A._chunk1
# Insert of existing embedding ID: Art History_chunk0
# Add of existing embedding ID: Art History_chunk0
# Insert of existing embedding ID: Art History_chunk1
# Add of existing embedding ID: Art History_chunk1
# Insert of existing embedding ID: Art History_chunk2
# Add of existing embedding ID: Art History_chunk2
# Insert of existing embedding ID: Art History_chunk3
# Add of existing embedding ID: Art History_chunk3
# Insert of existing embedding ID: Art History_chunk4
# Add of existing embedding ID: Art History_chunk4
# Insert of existing embedding ID: Studio Art_chunk0
# Add of existing embedding ID: Studio Art_chunk0
# Insert of existing embedding ID: Studio Art_chunk1
# Add of existing embedding ID: Studio Art_chunk1
# Insert of existing embedding ID: Studio Art_chunk2
# Add of existing embedding ID: Studio Art_chunk2
# Insert of existing embedding ID: Studio Art_chunk3
# Add of existing embedding ID: Studio Art_chunk3
# Insert of existing embedding ID: Studio Art_chunk4
# Add of existing embedding ID: Studio Art_chunk4
# Insert of existing embedding ID: Astronomy, B.A._chunk0
# Add of existing embedding ID: Astronomy, B.A._chunk0
# Insert of existing embedding ID: Astronomy, B.A._chunk1
# Add of existing embedding ID: Astronomy, B.A._chunk1
# Insert of existing embedding ID: Astronomy, B.S._chunk0
# Add of existing embedding ID: Astronomy, B.S._chunk0
# Insert of existing embedding ID: Astronomy, B.S._chunk1
# Add of existing embedding ID: Astronomy, B.S._chunk1
# Insert of existing embedding ID: Astronomy, B.S._chunk2
# Add of existing embedding ID: Astronomy, B.S._chunk2
# Insert of existing embedding ID: Behavioral Neuroscience, B.S._chunk0
# Add of existing embedding ID: Behavioral Neuroscience, B.S._chunk0
# Insert of existing embedding ID: Behavioral Neuroscience, B.S._chunk1
# Add of existing embedding ID: Behavioral Neuroscience, B.S._chunk1
# Insert of existing embedding ID: Behavioral Neuroscience, B.S._chunk2
# Add of existing embedding ID: Behavioral Neuroscience, B.S._chunk2
# Insert of existing embedding ID: Behavioral Neuroscience, B.S._chunk3
# Add of existing embedding ID: Behavioral Neuroscience, B.S._chunk3
# Insert of existing embedding ID: Behavioral Neuroscience, B.S._chunk4
# Add of existing embedding ID: Behavioral Neuroscience, B.S._chunk4
# Insert of existing embedding ID: Biology, B.A._chunk0
# Add of existing embedding ID: Biology, B.A._chunk0
# Insert of existing embedding ID: Biology, B.A._chunk1
# Add of existing embedding ID: Biology, B.A._chunk1
# Insert of existing embedding ID: Biology, B.A._chunk2
# Add of existing embedding ID: Biology, B.A._chunk2
# Insert of existing embedding ID: Biology, B.A._chunk3
# Add of existing embedding ID: Biology, B.A._chunk3
# Insert of existing embedding ID: Biology, B.A._chunk4
# Add of existing embedding ID: Biology, B.A._chunk4
# Insert of existing embedding ID: Biology, B.A._chunk5
# Add of existing embedding ID: Biology, B.A._chunk5
# Insert of existing embedding ID: Biology, B.A._chunk6
# Add of existing embedding ID: Biology, B.A._chunk6
# Insert of existing embedding ID: Biology, B.S._chunk0
# Add of existing embedding ID: Biology, B.S._chunk0
# Insert of existing embedding ID: Biology, B.S._chunk1
# Add of existing embedding ID: Biology, B.S._chunk1
# Insert of existing embedding ID: Biology, B.S._chunk2
# Add of existing embedding ID: Biology, B.S._chunk2
# Insert of existing embedding ID: Biology, B.S._chunk3
# Add of existing embedding ID: Biology, B.S._chunk3
# Insert of existing embedding ID: Biology, B.S._chunk4
# Add of existing embedding ID: Biology, B.S._chunk4
# Insert of existing embedding ID: Biology, B.S._chunk5
# Add of existing embedding ID: Biology, B.S._chunk5
# Insert of existing embedding ID: Biology, B.S._chunk6
# Add of existing embedding ID: Biology, B.S._chunk6
# Insert of existing embedding ID: Chemistry, B.A._chunk0
# Add of existing embedding ID: Chemistry, B.A._chunk0
# Insert of existing embedding ID: Chemistry, B.A._chunk1
# Add of existing embedding ID: Chemistry, B.A._chunk1
# Insert of existing embedding ID: Chemistry, B.A._chunk2
# Add of existing embedding ID: Chemistry, B.A._chunk2
# Insert of existing embedding ID: Chemistry, B.S._chunk0
# Add of existing embedding ID: Chemistry, B.S._chunk0
# Insert of existing embedding ID: Chemistry, B.S._chunk1
# Add of existing embedding ID: Chemistry, B.S._chunk1
# Insert of existing embedding ID: Chemistry, B.S._chunk2
# Add of existing embedding ID: Chemistry, B.S._chunk2
# Insert of existing embedding ID: Chemistry, B.S._chunk3
# Add of existing embedding ID: Chemistry, B.S._chunk3
# Insert of existing embedding ID: Chemistry, B.S._chunk4
# Add of existing embedding ID: Chemistry, B.S._chunk4
# Insert of existing embedding ID: Chemistry, B.S._chunk5
# Add of existing embedding ID: Chemistry, B.S._chunk5
# Insert of existing embedding ID: Chemistry, B.S._chunk6
# Add of existing embedding ID: Chemistry, B.S._chunk6
# Insert of existing embedding ID: Chemistry, B.S._chunk7
# Add of existing embedding ID: Chemistry, B.S._chunk7
# Insert of existing embedding ID: Chemistry, B.S._chunk8
# Add of existing embedding ID: Chemistry, B.S._chunk8
# Insert of existing embedding ID: Chemistry, B.S._chunk9
# Add of existing embedding ID: Chemistry, B.S._chunk9
# Insert of existing embedding ID: Chemistry, B.S._chunk10
# Add of existing embedding ID: Chemistry, B.S._chunk10
# Insert of existing embedding ID: Chemistry, B.S._chunk11
# Add of existing embedding ID: Chemistry, B.S._chunk11
# Insert of existing embedding ID: Chemistry, B.S._chunk12
# Add of existing embedding ID: Chemistry, B.S._chunk12
# Insert of existing embedding ID: Classics, B.A._chunk0
# Add of existing embedding ID: Classics, B.A._chunk0
# Insert of existing embedding ID: Classics, B.A._chunk1
# Add of existing embedding ID: Classics, B.A._chunk1
# Insert of existing embedding ID: Classics, B.A._chunk2
# Add of existing embedding ID: Classics, B.A._chunk2
# Insert of existing embedding ID: Computer Science, B.A._chunk0
# Add of existing embedding ID: Computer Science, B.A._chunk0
# Insert of existing embedding ID: Computer Science, B.A._chunk1
# Add of existing embedding ID: Computer Science, B.A._chunk1
# Insert of existing embedding ID: Computer Science, B.A._chunk2
# Add of existing embedding ID: Computer Science, B.A._chunk2
# Insert of existing embedding ID: Computer Science, B.A._chunk3
# Add of existing embedding ID: Computer Science, B.A._chunk3
# Insert of existing embedding ID: Computer Science, B.A._chunk4
# Add of existing embedding ID: Computer Science, B.A._chunk4
# Insert of existing embedding ID: Computer Science, B.A._chunk5
# Add of existing embedding ID: Computer Science, B.A._chunk5
# Insert of existing embedding ID: Drama, B.A._chunk0
# Add of existing embedding ID: Drama, B.A._chunk0
# Insert of existing embedding ID: Drama, B.A._chunk1
# Add of existing embedding ID: Drama, B.A._chunk1
# Insert of existing embedding ID: Drama, B.A._chunk2
# Add of existing embedding ID: Drama, B.A._chunk2
# Insert of existing embedding ID: Drama, B.A._chunk3
# Add of existing embedding ID: Drama, B.A._chunk3
# Insert of existing embedding ID: Economics, B.A._chunk0
# Add of existing embedding ID: Economics, B.A._chunk0
# Insert of existing embedding ID: Economics, B.A._chunk1
# Add of existing embedding ID: Economics, B.A._chunk1
# Insert of existing embedding ID: Economics, B.A._chunk2
# Add of existing embedding ID: Economics, B.A._chunk2
# Insert of existing embedding ID: Economics, B.A._chunk3
# Add of existing embedding ID: Economics, B.A._chunk3
# Insert of existing embedding ID: Economics, B.A._chunk4
# Add of existing embedding ID: Economics, B.A._chunk4
# Insert of existing embedding ID: Economics, B.A._chunk5
# Add of existing embedding ID: Economics, B.A._chunk5
# Insert of existing embedding ID: Economics, B.A._chunk6
# Add of existing embedding ID: Economics, B.A._chunk6
# Insert of existing embedding ID: Economics, B.A._chunk7
# Add of existing embedding ID: Economics, B.A._chunk7
# Insert of existing embedding ID: Economics, B.A._chunk8
# Add of existing embedding ID: Economics, B.A._chunk8
# Insert of existing embedding ID: Economics, B.A._chunk9
# Add of existing embedding ID: Economics, B.A._chunk9
# Insert of existing embedding ID: Economics, B.A._chunk10
# Add of existing embedding ID: Economics, B.A._chunk10
# Insert of existing embedding ID: Economics, B.A._chunk11
# Add of existing embedding ID: Economics, B.A._chunk11
# Insert of existing embedding ID: English, B.A._chunk0
# Add of existing embedding ID: English, B.A._chunk0
# Insert of existing embedding ID: English, B.A._chunk1
# Add of existing embedding ID: English, B.A._chunk1
# Insert of existing embedding ID: English, B.A._chunk2
# Add of existing embedding ID: English, B.A._chunk2
# Insert of existing embedding ID: English, B.A._chunk3
# Add of existing embedding ID: English, B.A._chunk3
# Insert of existing embedding ID: English, B.A._chunk4
# Add of existing embedding ID: English, B.A._chunk4
# Insert of existing embedding ID: English, B.A._chunk5
# Add of existing embedding ID: English, B.A._chunk5
# Insert of existing embedding ID: Environmental Sciences, B.A._chunk0
# Add of existing embedding ID: Environmental Sciences, B.A._chunk0
# Insert of existing embedding ID: Environmental Sciences, B.A._chunk1
# Add of existing embedding ID: Environmental Sciences, B.A._chunk1
# Insert of existing embedding ID: Environmental Sciences, B.A._chunk2
# Add of existing embedding ID: Environmental Sciences, B.A._chunk2
# Insert of existing embedding ID: Environmental Sciences, B.A._chunk3
# Add of existing embedding ID: Environmental Sciences, B.A._chunk3
# Insert of existing embedding ID: Environmental Sciences, B.A._chunk4
# Add of existing embedding ID: Environmental Sciences, B.A._chunk4
# Insert of existing embedding ID: Environmental Sciences, B.S._chunk0
# Add of existing embedding ID: Environmental Sciences, B.S._chunk0
# Insert of existing embedding ID: Environmental Sciences, B.S._chunk1
# Add of existing embedding ID: Environmental Sciences, B.S._chunk1
# Insert of existing embedding ID: Environmental Sciences, B.S._chunk2
# Add of existing embedding ID: Environmental Sciences, B.S._chunk2
# Insert of existing embedding ID: Environmental Sciences, B.S._chunk3
# Add of existing embedding ID: Environmental Sciences, B.S._chunk3
# Insert of existing embedding ID: Environmental Sciences, B.S._chunk4
# Add of existing embedding ID: Environmental Sciences, B.S._chunk4
# Insert of existing embedding ID: Foreign Affairs, B.A._chunk0
# Add of existing embedding ID: Foreign Affairs, B.A._chunk0
# Insert of existing embedding ID: Foreign Affairs, B.A._chunk1
# Add of existing embedding ID: Foreign Affairs, B.A._chunk1
# Insert of existing embedding ID: Foreign Affairs, B.A._chunk2
# Add of existing embedding ID: Foreign Affairs, B.A._chunk2
# Insert of existing embedding ID: Foreign Affairs, B.A._chunk3
# Add of existing embedding ID: Foreign Affairs, B.A._chunk3
# Insert of existing embedding ID: Foreign Affairs, B.A._chunk4
# Add of existing embedding ID: Foreign Affairs, B.A._chunk4
# Insert of existing embedding ID: French, B.A._chunk0
# Add of existing embedding ID: French, B.A._chunk0
# Insert of existing embedding ID: French, B.A._chunk1
# Add of existing embedding ID: French, B.A._chunk1
# Insert of existing embedding ID: German, B.A._chunk0
# Add of existing embedding ID: German, B.A._chunk0
# Insert of existing embedding ID: German, B.A._chunk1
# Add of existing embedding ID: German, B.A._chunk1
# Insert of existing embedding ID: Government, B.A._chunk0
# Add of existing embedding ID: Government, B.A._chunk0
# Insert of existing embedding ID: Government, B.A._chunk1
# Add of existing embedding ID: Government, B.A._chunk1
# Insert of existing embedding ID: Government, B.A._chunk2
# Add of existing embedding ID: Government, B.A._chunk2
# Insert of existing embedding ID: Government, B.A._chunk3
# Add of existing embedding ID: Government, B.A._chunk3
# Insert of existing embedding ID: Government, B.A._chunk4
# Add of existing embedding ID: Government, B.A._chunk4
# Insert of existing embedding ID: History, B.A._chunk0
# Add of existing embedding ID: History, B.A._chunk0
# Insert of existing embedding ID: History, B.A._chunk1
# Add of existing embedding ID: History, B.A._chunk1
# Insert of existing embedding ID: History, B.A._chunk2
# Add of existing embedding ID: History, B.A._chunk2
# Insert of existing embedding ID: History, B.A._chunk3
# Add of existing embedding ID: History, B.A._chunk3
# Insert of existing embedding ID: History, B.A._chunk4
# Add of existing embedding ID: History, B.A._chunk4
# Insert of existing embedding ID: History, B.A._chunk5
# Add of existing embedding ID: History, B.A._chunk5
# Insert of existing embedding ID: History, B.A._chunk6
# Add of existing embedding ID: History, B.A._chunk6
# Insert of existing embedding ID: History, B.A._chunk7
# Add of existing embedding ID: History, B.A._chunk7
# Insert of existing embedding ID: History, B.A._chunk8
# Add of existing embedding ID: History, B.A._chunk8
# Insert of existing embedding ID: History, B.A._chunk9
# Add of existing embedding ID: History, B.A._chunk9
# Insert of existing embedding ID: History, B.A._chunk10
# Add of existing embedding ID: History, B.A._chunk10
# Insert of existing embedding ID: History, B.A._chunk11
# Add of existing embedding ID: History, B.A._chunk11
# Insert of existing embedding ID: American Studies_chunk0
# Add of existing embedding ID: American Studies_chunk0
# Insert of existing embedding ID: American Studies_chunk1
# Add of existing embedding ID: American Studies_chunk1
# Insert of existing embedding ID: American Studies_chunk2
# Add of existing embedding ID: American Studies_chunk2
# Insert of existing embedding ID: American Studies_chunk3
# Add of existing embedding ID: American Studies_chunk3
# Insert of existing embedding ID: American Studies_chunk4
# Add of existing embedding ID: American Studies_chunk4
# Insert of existing embedding ID: Archaeology_chunk0
# Add of existing embedding ID: Archaeology_chunk0
# Insert of existing embedding ID: Archaeology_chunk1
# Add of existing embedding ID: Archaeology_chunk1
# Insert of existing embedding ID: Chinese Language & Literature_chunk0
# Add of existing embedding ID: Chinese Language & Literature_chunk0
# Insert of existing embedding ID: Chinese Language & Literature_chunk1
# Add of existing embedding ID: Chinese Language & Literature_chunk1
# Insert of existing embedding ID: Chinese Language & Literature_chunk2
# Add of existing embedding ID: Chinese Language & Literature_chunk2
# Insert of existing embedding ID: Chinese Language & Literature_chunk3
# Add of existing embedding ID: Chinese Language & Literature_chunk3
# Insert of existing embedding ID: Cognitive Science_chunk0
# Add of existing embedding ID: Cognitive Science_chunk0
# Insert of existing embedding ID: Cognitive Science_chunk1
# Add of existing embedding ID: Cognitive Science_chunk1
# Insert of existing embedding ID: Cognitive Science_chunk2
# Add of existing embedding ID: Cognitive Science_chunk2
# Insert of existing embedding ID: Cognitive Science_chunk3
# Add of existing embedding ID: Cognitive Science_chunk3
# Insert of existing embedding ID: Cognitive Science_chunk4
# Add of existing embedding ID: Cognitive Science_chunk4
# Insert of existing embedding ID: Cognitive Science_chunk5
# Add of existing embedding ID: Cognitive Science_chunk5
# Insert of existing embedding ID: Cognitive Science_chunk6
# Add of existing embedding ID: Cognitive Science_chunk6
# Insert of existing embedding ID: East Asian Studies_chunk0
# Add of existing embedding ID: East Asian Studies_chunk0
# Insert of existing embedding ID: East Asian Studies_chunk1
# Add of existing embedding ID: East Asian Studies_chunk1
# Insert of existing embedding ID: East Asian Studies_chunk2
# Add of existing embedding ID: East Asian Studies_chunk2
# Insert of existing embedding ID: East Asian Studies_chunk3
# Add of existing embedding ID: East Asian Studies_chunk3
# Insert of existing embedding ID: East Asian Studies_chunk4
# Add of existing embedding ID: East Asian Studies_chunk4
# Insert of existing embedding ID: East Asian Studies_chunk5
# Add of existing embedding ID: East Asian Studies_chunk5
# Insert of existing embedding ID: East Asian Studies_chunk6
# Add of existing embedding ID: East Asian Studies_chunk6
# Insert of existing embedding ID: Environmental Thought & Practice_chunk0
# Add of existing embedding ID: Environmental Thought & Practice_chunk0
# Insert of existing embedding ID: Environmental Thought & Practice_chunk1
# Add of existing embedding ID: Environmental Thought & Practice_chunk1
# Insert of existing embedding ID: Environmental Thought & Practice_chunk2
# Add of existing embedding ID: Environmental Thought & Practice_chunk2
# Insert of existing embedding ID: Environmental Thought & Practice_chunk3
# Add of existing embedding ID: Environmental Thought & Practice_chunk3
# Insert of existing embedding ID: Environmental Thought & Practice_chunk4
# Add of existing embedding ID: Environmental Thought & Practice_chunk4
# Insert of existing embedding ID: Environmental Thought & Practice_chunk5
# Add of existing embedding ID: Environmental Thought & Practice_chunk5
# Insert of existing embedding ID: German Studies_chunk0
# Add of existing embedding ID: German Studies_chunk0
# Insert of existing embedding ID: German Studies_chunk1
# Add of existing embedding ID: German Studies_chunk1
# Insert of existing embedding ID: German Studies_chunk2
# Add of existing embedding ID: German Studies_chunk2
# Insert of existing embedding ID: Global Studies_chunk0
# Add of existing embedding ID: Global Studies_chunk0
# Insert of existing embedding ID: Global Studies_chunk1
# Add of existing embedding ID: Global Studies_chunk1
# Insert of existing embedding ID: Global Studies_chunk2
# Add of existing embedding ID: Global Studies_chunk2
# Insert of existing embedding ID: Global Studies_chunk3
# Add of existing embedding ID: Global Studies_chunk3
# Insert of existing embedding ID: Global Studies_chunk4
# Add of existing embedding ID: Global Studies_chunk4
# Insert of existing embedding ID: Global Studies_chunk5
# Add of existing embedding ID: Global Studies_chunk5
# Insert of existing embedding ID: Global Studies_chunk6
# Add of existing embedding ID: Global Studies_chunk6
# Insert of existing embedding ID: Global Studies_chunk7
# Add of existing embedding ID: Global Studies_chunk7
# Insert of existing embedding ID: Global Studies_chunk8
# Add of existing embedding ID: Global Studies_chunk8
# Insert of existing embedding ID: Global Studies_chunk9
# Add of existing embedding ID: Global Studies_chunk9
# Insert of existing embedding ID: Global Studies_chunk10
# Add of existing embedding ID: Global Studies_chunk10
# Insert of existing embedding ID: Global Studies_chunk11
# Add of existing embedding ID: Global Studies_chunk11
# Insert of existing embedding ID: Global Studies_chunk12
# Add of existing embedding ID: Global Studies_chunk12
# Insert of existing embedding ID: Global Studies_chunk13
# Add of existing embedding ID: Global Studies_chunk13
# Insert of existing embedding ID: Global Studies_chunk14
# Add of existing embedding ID: Global Studies_chunk14
# Insert of existing embedding ID: Human Biology_chunk0
# Add of existing embedding ID: Human Biology_chunk0
# Insert of existing embedding ID: Human Biology_chunk1
# Add of existing embedding ID: Human Biology_chunk1
# Insert of existing embedding ID: Human Biology_chunk2
# Add of existing embedding ID: Human Biology_chunk2
# Insert of existing embedding ID: Human Biology_chunk3
# Add of existing embedding ID: Human Biology_chunk3
# Insert of existing embedding ID: Human Biology_chunk4
# Add of existing embedding ID: Human Biology_chunk4
# Insert of existing embedding ID: Human Biology_chunk5
# Add of existing embedding ID: Human Biology_chunk5
# Insert of existing embedding ID: Human Biology_chunk6
# Add of existing embedding ID: Human Biology_chunk6
# Insert of existing embedding ID: Japanese Language & Literature_chunk0
# Add of existing embedding ID: Japanese Language & Literature_chunk0
# Insert of existing embedding ID: Japanese Language & Literature_chunk1
# Add of existing embedding ID: Japanese Language & Literature_chunk1
# Insert of existing embedding ID: Japanese Language & Literature_chunk2
# Add of existing embedding ID: Japanese Language & Literature_chunk2
# Insert of existing embedding ID: Jewish Studies_chunk0
# Add of existing embedding ID: Jewish Studies_chunk0
# Insert of existing embedding ID: Jewish Studies_chunk1
# Add of existing embedding ID: Jewish Studies_chunk1
# Insert of existing embedding ID: Jewish Studies_chunk2
# Add of existing embedding ID: Jewish Studies_chunk2
# Insert of existing embedding ID: Jewish Studies_chunk3
# Add of existing embedding ID: Jewish Studies_chunk3
# Insert of existing embedding ID: Jewish Studies_chunk4
# Add of existing embedding ID: Jewish Studies_chunk4
# Insert of existing embedding ID: Linguistics_chunk0
# Add of existing embedding ID: Linguistics_chunk0
# Insert of existing embedding ID: Linguistics_chunk1
# Add of existing embedding ID: Linguistics_chunk1
# Insert of existing embedding ID: Medieval Studies_chunk0
# Add of existing embedding ID: Medieval Studies_chunk0
# Insert of existing embedding ID: Medieval Studies_chunk1
# Add of existing embedding ID: Medieval Studies_chunk1
# Insert of existing embedding ID: Medieval Studies_chunk2
# Add of existing embedding ID: Medieval Studies_chunk2
# Insert of existing embedding ID: Middle Eastern Languages and Literatures_chunk0
# Add of existing embedding ID: Middle Eastern Languages and Literatures_chunk0
# Insert of existing embedding ID: Middle Eastern Languages and Literatures_chunk1
# Add of existing embedding ID: Middle Eastern Languages and Literatures_chunk1
# Insert of existing embedding ID: Middle Eastern Languages and Literatures_chunk2
# Add of existing embedding ID: Middle Eastern Languages and Literatures_chunk2
# Insert of existing embedding ID: Middle Eastern Languages and Literatures_chunk3
# Add of existing embedding ID: Middle Eastern Languages and Literatures_chunk3
# Insert of existing embedding ID: Middle Eastern Languages and Literatures_chunk4
# Add of existing embedding ID: Middle Eastern Languages and Literatures_chunk4
# Insert of existing embedding ID: Middle Eastern Studies_chunk0
# Add of existing embedding ID: Middle Eastern Studies_chunk0
# Insert of existing embedding ID: Middle Eastern Studies_chunk1
# Add of existing embedding ID: Middle Eastern Studies_chunk1
# Insert of existing embedding ID: Middle Eastern Studies_chunk2
# Add of existing embedding ID: Middle Eastern Studies_chunk2
# Insert of existing embedding ID: Middle Eastern Studies_chunk3
# Add of existing embedding ID: Middle Eastern Studies_chunk3
# Insert of existing embedding ID: Neuroscience_chunk0
# Add of existing embedding ID: Neuroscience_chunk0
# Insert of existing embedding ID: Neuroscience_chunk1
# Add of existing embedding ID: Neuroscience_chunk1
# Insert of existing embedding ID: Neuroscience_chunk2
# Add of existing embedding ID: Neuroscience_chunk2
# Insert of existing embedding ID: Neuroscience_chunk3
# Add of existing embedding ID: Neuroscience_chunk3
# Insert of existing embedding ID: Neuroscience_chunk4
# Add of existing embedding ID: Neuroscience_chunk4
# Insert of existing embedding ID: Neuroscience_chunk5
# Add of existing embedding ID: Neuroscience_chunk5
# Insert of existing embedding ID: Neuroscience_chunk6
# Add of existing embedding ID: Neuroscience_chunk6
# Insert of existing embedding ID: Political & Social Thought_chunk0
# Add of existing embedding ID: Political & Social Thought_chunk0
# Insert of existing embedding ID: Political & Social Thought_chunk1
# Add of existing embedding ID: Political & Social Thought_chunk1
# Insert of existing embedding ID: Political & Social Thought_chunk2
# Add of existing embedding ID: Political & Social Thought_chunk2
# Insert of existing embedding ID: Political Philosophy, Policy, & Law_chunk0
# Add of existing embedding ID: Political Philosophy, Policy, & Law_chunk0
# Insert of existing embedding ID: Political Philosophy, Policy, & Law_chunk1
# Add of existing embedding ID: Political Philosophy, Policy, & Law_chunk1
# Insert of existing embedding ID: Political Philosophy, Policy, & Law_chunk2
# Add of existing embedding ID: Political Philosophy, Policy, & Law_chunk2
# Insert of existing embedding ID: Political Philosophy, Policy, & Law_chunk3
# Add of existing embedding ID: Political Philosophy, Policy, & Law_chunk3
# Insert of existing embedding ID: Political Philosophy, Policy, & Law_chunk4
# Add of existing embedding ID: Political Philosophy, Policy, & Law_chunk4
# Insert of existing embedding ID: South Asian Languages and Literatures_chunk0
# Add of existing embedding ID: South Asian Languages and Literatures_chunk0
# Insert of existing embedding ID: South Asian Languages and Literatures_chunk1
# Add of existing embedding ID: South Asian Languages and Literatures_chunk1
# Insert of existing embedding ID: South Asian Languages and Literatures_chunk2
# Add of existing embedding ID: South Asian Languages and Literatures_chunk2
# Insert of existing embedding ID: South Asian Languages and Literatures_chunk3
# Add of existing embedding ID: South Asian Languages and Literatures_chunk3
# Insert of existing embedding ID: South Asian Languages and Literatures_chunk4
# Add of existing embedding ID: South Asian Languages and Literatures_chunk4
# Insert of existing embedding ID: South Asian Studies_chunk0
# Add of existing embedding ID: South Asian Studies_chunk0
# Insert of existing embedding ID: South Asian Studies_chunk1
# Add of existing embedding ID: South Asian Studies_chunk1
# Insert of existing embedding ID: South Asian Studies_chunk2
# Add of existing embedding ID: South Asian Studies_chunk2
# Insert of existing embedding ID: South Asian Studies_chunk3
# Add of existing embedding ID: South Asian Studies_chunk3
# Insert of existing embedding ID: Women, Gender, and Sexuality_chunk0
# Add of existing embedding ID: Women, Gender, and Sexuality_chunk0
# Insert of existing embedding ID: Women, Gender, and Sexuality_chunk1
# Add of existing embedding ID: Women, Gender, and Sexuality_chunk1
# Insert of existing embedding ID: Women, Gender, and Sexuality_chunk2
# Add of existing embedding ID: Women, Gender, and Sexuality_chunk2
# Insert of existing embedding ID: Women, Gender, and Sexuality_chunk3
# Add of existing embedding ID: Women, Gender, and Sexuality_chunk3
# Insert of existing embedding ID: Italian, B.A._chunk0
# Add of existing embedding ID: Italian, B.A._chunk0
# Insert of existing embedding ID: Italian, B.A._chunk1
# Add of existing embedding ID: Italian, B.A._chunk1
# Insert of existing embedding ID: Italian, B.A._chunk2
# Add of existing embedding ID: Italian, B.A._chunk2
# Insert of existing embedding ID: Italian, B.A._chunk3
# Add of existing embedding ID: Italian, B.A._chunk3
# Insert of existing embedding ID: Italian, B.A._chunk4
# Add of existing embedding ID: Italian, B.A._chunk4
# Insert of existing embedding ID: Italian, B.A._chunk5
# Add of existing embedding ID: Italian, B.A._chunk5
# Insert of existing embedding ID: Italian, B.A._chunk6
# Add of existing embedding ID: Italian, B.A._chunk6
# Insert of existing embedding ID: Italian, B.A._chunk7
# Add of existing embedding ID: Italian, B.A._chunk7
# Insert of existing embedding ID: Italian, B.A._chunk8
# Add of existing embedding ID: Italian, B.A._chunk8
# Insert of existing embedding ID: Italian, B.A._chunk9
# Add of existing embedding ID: Italian, B.A._chunk9
# Insert of existing embedding ID: Mathematics, B.A._chunk0
# Add of existing embedding ID: Mathematics, B.A._chunk0
# Insert of existing embedding ID: Mathematics, B.A._chunk1
# Add of existing embedding ID: Mathematics, B.A._chunk1
# Insert of existing embedding ID: Mathematics, B.A._chunk2
# Add of existing embedding ID: Mathematics, B.A._chunk2
# Insert of existing embedding ID: Mathematics, B.A._chunk3
# Add of existing embedding ID: Mathematics, B.A._chunk3
# Insert of existing embedding ID: Mathematics, B.A._chunk4
# Add of existing embedding ID: Mathematics, B.A._chunk4
# Insert of existing embedding ID: Mathematics, B.A._chunk5
# Add of existing embedding ID: Mathematics, B.A._chunk5
# Insert of existing embedding ID: Media Studies, B.A._chunk0
# Add of existing embedding ID: Media Studies, B.A._chunk0
# Insert of existing embedding ID: Media Studies, B.A._chunk1
# Add of existing embedding ID: Media Studies, B.A._chunk1
# Insert of existing embedding ID: Media Studies, B.A._chunk2
# Add of existing embedding ID: Media Studies, B.A._chunk2
# Insert of existing embedding ID: Media Studies, B.A._chunk3
# Add of existing embedding ID: Media Studies, B.A._chunk3
# Insert of existing embedding ID: Media Studies, B.A._chunk4
# Add of existing embedding ID: Media Studies, B.A._chunk4
# Insert of existing embedding ID: Media Studies, B.A._chunk5
# Add of existing embedding ID: Media Studies, B.A._chunk5
# Insert of existing embedding ID: Media Studies, B.A._chunk6
# Add of existing embedding ID: Media Studies, B.A._chunk6
# Insert of existing embedding ID: Media Studies, B.A._chunk7
# Add of existing embedding ID: Media Studies, B.A._chunk7
# Insert of existing embedding ID: Media Studies, B.A._chunk8
# Add of existing embedding ID: Media Studies, B.A._chunk8
# Insert of existing embedding ID: Media Studies, B.A._chunk9
# Add of existing embedding ID: Media Studies, B.A._chunk9
# Insert of existing embedding ID: Music, B.A._chunk0
# Add of existing embedding ID: Music, B.A._chunk0
# Insert of existing embedding ID: Music, B.A._chunk1
# Add of existing embedding ID: Music, B.A._chunk1
# Insert of existing embedding ID: Music, B.A._chunk2
# Add of existing embedding ID: Music, B.A._chunk2
# Insert of existing embedding ID: Music, B.A._chunk3
# Add of existing embedding ID: Music, B.A._chunk3
# Insert of existing embedding ID: Music, B.A._chunk4
# Add of existing embedding ID: Music, B.A._chunk4
# Insert of existing embedding ID: Music, B.A._chunk5
# Add of existing embedding ID: Music, B.A._chunk5
# Insert of existing embedding ID: Music, B.A._chunk6
# Add of existing embedding ID: Music, B.A._chunk6
# Insert of existing embedding ID: Philosophy, B.A._chunk0
# Add of existing embedding ID: Philosophy, B.A._chunk0
# Insert of existing embedding ID: Philosophy, B.A._chunk1
# Add of existing embedding ID: Philosophy, B.A._chunk1
# Insert of existing embedding ID: Philosophy, B.A._chunk2
# Add of existing embedding ID: Philosophy, B.A._chunk2
# Insert of existing embedding ID: Physics, B.A._chunk0
# Add of existing embedding ID: Physics, B.A._chunk0
# Insert of existing embedding ID: Physics, B.A._chunk1
# Add of existing embedding ID: Physics, B.A._chunk1
# Insert of existing embedding ID: Physics, B.S._chunk0
# Add of existing embedding ID: Physics, B.S._chunk0
# Insert of existing embedding ID: Physics, B.S._chunk1
# Add of existing embedding ID: Physics, B.S._chunk1
# Insert of existing embedding ID: Physics, B.S._chunk2
# Add of existing embedding ID: Physics, B.S._chunk2
# Insert of existing embedding ID: Physics, B.S._chunk3
# Add of existing embedding ID: Physics, B.S._chunk3
# Insert of existing embedding ID: Physics, B.S._chunk4
# Add of existing embedding ID: Physics, B.S._chunk4
# Insert of existing embedding ID: Psychology, B.A._chunk0
# Add of existing embedding ID: Psychology, B.A._chunk0
# Insert of existing embedding ID: Psychology, B.A._chunk1
# Add of existing embedding ID: Psychology, B.A._chunk1
# Insert of existing embedding ID: Psychology, B.A._chunk2
# Add of existing embedding ID: Psychology, B.A._chunk2
# Insert of existing embedding ID: Psychology, B.A._chunk3
# Add of existing embedding ID: Psychology, B.A._chunk3
# Insert of existing embedding ID: Religious Studies, B.A._chunk0
# Add of existing embedding ID: Religious Studies, B.A._chunk0
# Insert of existing embedding ID: Religious Studies, B.A._chunk1
# Add of existing embedding ID: Religious Studies, B.A._chunk1
# Insert of existing embedding ID: Religious Studies, B.A._chunk2
# Add of existing embedding ID: Religious Studies, B.A._chunk2
# Insert of existing embedding ID: Religious Studies, B.A._chunk3
# Add of existing embedding ID: Religious Studies, B.A._chunk3
# Insert of existing embedding ID: Religious Studies, B.A._chunk4
# Add of existing embedding ID: Religious Studies, B.A._chunk4
# Insert of existing embedding ID: Slavic Languages and Literatures, B.A._chunk0
# Add of existing embedding ID: Slavic Languages and Literatures, B.A._chunk0
# Insert of existing embedding ID: Slavic Languages and Literatures, B.A._chunk1
# Add of existing embedding ID: Slavic Languages and Literatures, B.A._chunk1
# Insert of existing embedding ID: Slavic Languages and Literatures, B.A._chunk2
# Add of existing embedding ID: Slavic Languages and Literatures, B.A._chunk2
# Insert of existing embedding ID: Sociology, B.A._chunk0
# Add of existing embedding ID: Sociology, B.A._chunk0
# Insert of existing embedding ID: Sociology, B.A._chunk1
# Add of existing embedding ID: Sociology, B.A._chunk1
# Insert of existing embedding ID: Sociology, B.A._chunk2
# Add of existing embedding ID: Sociology, B.A._chunk2
# Insert of existing embedding ID: Sociology, B.A._chunk3
# Add of existing embedding ID: Sociology, B.A._chunk3
# Insert of existing embedding ID: Sociology, B.A._chunk4
# Add of existing embedding ID: Sociology, B.A._chunk4
# Insert of existing embedding ID: Sociology, B.A._chunk5
# Add of existing embedding ID: Sociology, B.A._chunk5
# Insert of existing embedding ID: Sociology, B.A._chunk6
# Add of existing embedding ID: Sociology, B.A._chunk6
# Insert of existing embedding ID: Sociology, B.A._chunk7
# Add of existing embedding ID: Sociology, B.A._chunk7
# Insert of existing embedding ID: Sociology, B.A._chunk8
# Add of existing embedding ID: Sociology, B.A._chunk8
# Insert of existing embedding ID: Spanish, B.A._chunk0
# Add of existing embedding ID: Spanish, B.A._chunk0
# Insert of existing embedding ID: Spanish, B.A._chunk1
# Add of existing embedding ID: Spanish, B.A._chunk1
# Insert of existing embedding ID: Spanish, B.A._chunk2
# Add of existing embedding ID: Spanish, B.A._chunk2
# Insert of existing embedding ID: Spanish, B.A._chunk3
# Add of existing embedding ID: Spanish, B.A._chunk3
# Insert of existing embedding ID: Spanish, B.A._chunk4
# Add of existing embedding ID: Spanish, B.A._chunk4
# Insert of existing embedding ID: Spanish, B.A._chunk5
# Add of existing embedding ID: Spanish, B.A._chunk5
# Insert of existing embedding ID: Spanish, B.A._chunk6
# Add of existing embedding ID: Spanish, B.A._chunk6
# Insert of existing embedding ID: Spanish, B.A._chunk7
# Add of existing embedding ID: Spanish, B.A._chunk7
# Insert of existing embedding ID: Spanish, B.A._chunk8
# Add of existing embedding ID: Spanish, B.A._chunk8
# Insert of existing embedding ID: Statistics, B.S._chunk0
# Add of existing embedding ID: Statistics, B.S._chunk0
# Insert of existing embedding ID: Statistics, B.S._chunk1
# Add of existing embedding ID: Statistics, B.S._chunk1
# Insert of existing embedding ID: Statistics, B.S._chunk2
# Add of existing embedding ID: Statistics, B.S._chunk2
# Insert of existing embedding ID: Statistics, B.S._chunk3
# Add of existing embedding ID: Statistics, B.S._chunk3
# Insert of existing embedding ID: Bachelor of Science in Commerce, B.S.C._chunk0
# Add of existing embedding ID: Bachelor of Science in Commerce, B.S.C._chunk0
# Insert of existing embedding ID: Bachelor of Science in Commerce, B.S.C._chunk1
# Add of existing embedding ID: Bachelor of Science in Commerce, B.S.C._chunk1
# Insert of existing embedding ID: Bachelor of Science in Commerce, B.S.C._chunk2
# Add of existing embedding ID: Bachelor of Science in Commerce, B.S.C._chunk2
# Insert of existing embedding ID: Bachelor of Science in Commerce, B.S.C._chunk3
# Add of existing embedding ID: Bachelor of Science in Commerce, B.S.C._chunk3
# Insert of existing embedding ID: Bachelor of Professional Studies in Health Sciences Management, B.P.S._chunk0
# Add of existing embedding ID: Bachelor of Professional Studies in Health Sciences Management, B.P.S._chunk0
# Insert of existing embedding ID: Bachelor of Professional Studies in Health Sciences Management, B.P.S._chunk1
# Add of existing embedding ID: Bachelor of Professional Studies in Health Sciences Management, B.P.S._chunk1
# Insert of existing embedding ID: Bachelor of Professional Studies in Health Sciences Management, B.P.S._chunk2
# Add of existing embedding ID: Bachelor of Professional Studies in Health Sciences Management, B.P.S._chunk2
# Insert of existing embedding ID: Bachelor of Professional Studies in Health Sciences Management, B.P.S._chunk3
# Add of existing embedding ID: Bachelor of Professional Studies in Health Sciences Management, B.P.S._chunk3
# Insert of existing embedding ID: Bachelor of Professional Studies in Health Sciences Management, B.P.S._chunk4
# Add of existing embedding ID: Bachelor of Professional Studies in Health Sciences Management, B.P.S._chunk4
# Insert of existing embedding ID: Bachelor of Professional Studies in Health Sciences Management, B.P.S._chunk5
# Add of existing embedding ID: Bachelor of Professional Studies in Health Sciences Management, B.P.S._chunk5
# Insert of existing embedding ID: Bachelor of Professional Studies in Health Sciences Management, B.P.S._chunk6
# Add of existing embedding ID: Bachelor of Professional Studies in Health Sciences Management, B.P.S._chunk6
# Insert of existing embedding ID: Bachelor of Professional Studies in Health Sciences Management, B.P.S._chunk7
# Add of existing embedding ID: Bachelor of Professional Studies in Health Sciences Management, B.P.S._chunk7
# Insert of existing embedding ID: Bachelor of Professional Studies in Health Sciences Management, B.P.S._chunk8
# Add of existing embedding ID: Bachelor of Professional Studies in Health Sciences Management, B.P.S._chunk8
# Insert of existing embedding ID: Bachelor of Professional Studies in Health Sciences Management, B.P.S._chunk9
# Add of existing embedding ID: Bachelor of Professional Studies in Health Sciences Management, B.P.S._chunk9
# Insert of existing embedding ID: Bachelor of Interdisciplinary Studies, B.I.S._chunk0
# Add of existing embedding ID: Bachelor of Interdisciplinary Studies, B.I.S._chunk0
# Insert of existing embedding ID: Bachelor of Interdisciplinary Studies, B.I.S._chunk1
# Add of existing embedding ID: Bachelor of Interdisciplinary Studies, B.I.S._chunk1
# Insert of existing embedding ID: Bachelor of Interdisciplinary Studies, B.I.S._chunk2
# Add of existing embedding ID: Bachelor of Interdisciplinary Studies, B.I.S._chunk2
# Insert of existing embedding ID: Bachelor of Interdisciplinary Studies, B.I.S._chunk3
# Add of existing embedding ID: Bachelor of Interdisciplinary Studies, B.I.S._chunk3
# Insert of existing embedding ID: Bachelor of Interdisciplinary Studies, B.I.S._chunk4
# Add of existing embedding ID: Bachelor of Interdisciplinary Studies, B.I.S._chunk4
# Insert of existing embedding ID: Bachelor of Interdisciplinary Studies, B.I.S._chunk5
# Add of existing embedding ID: Bachelor of Interdisciplinary Studies, B.I.S._chunk5
# Insert of existing embedding ID: Bachelor of Interdisciplinary Studies, B.I.S._chunk6
# Add of existing embedding ID: Bachelor of Interdisciplinary Studies, B.I.S._chunk6
# Insert of existing embedding ID: Bachelor of Interdisciplinary Studies, B.I.S._chunk7
# Add of existing embedding ID: Bachelor of Interdisciplinary Studies, B.I.S._chunk7
# Insert of existing embedding ID: Bachelor of Interdisciplinary Studies, B.I.S._chunk8
# Add of existing embedding ID: Bachelor of Interdisciplinary Studies, B.I.S._chunk8
# Insert of existing embedding ID: Bachelor of Interdisciplinary Studies, B.I.S._chunk9
# Add of existing embedding ID: Bachelor of Interdisciplinary Studies, B.I.S._chunk9
# Insert of existing embedding ID: Bachelor of Interdisciplinary Studies, B.I.S._chunk10
# Add of existing embedding ID: Bachelor of Interdisciplinary Studies, B.I.S._chunk10
# Insert of existing embedding ID: Bachelor of Interdisciplinary Studies, B.I.S._chunk11
# Add of existing embedding ID: Bachelor of Interdisciplinary Studies, B.I.S._chunk11
# Insert of existing embedding ID: Bachelor of Interdisciplinary Studies, B.I.S._chunk12
# Add of existing embedding ID: Bachelor of Interdisciplinary Studies, B.I.S._chunk12
# Insert of existing embedding ID: Bachelor of Interdisciplinary Studies, B.I.S._chunk13
# Add of existing embedding ID: Bachelor of Interdisciplinary Studies, B.I.S._chunk13
# Insert of existing embedding ID: Bachelor of Interdisciplinary Studies, B.I.S._chunk14
# Add of existing embedding ID: Bachelor of Interdisciplinary Studies, B.I.S._chunk14
# Insert of existing embedding ID: Bachelor of Interdisciplinary Studies, B.I.S._chunk15
# Add of existing embedding ID: Bachelor of Interdisciplinary Studies, B.I.S._chunk15
# Insert of existing embedding ID: Bachelor of Interdisciplinary Studies, B.I.S._chunk16
# Add of existing embedding ID: Bachelor of Interdisciplinary Studies, B.I.S._chunk16
# Insert of existing embedding ID: Bachelor of Interdisciplinary Studies, B.I.S._chunk17
# Add of existing embedding ID: Bachelor of Interdisciplinary Studies, B.I.S._chunk17
# Insert of existing embedding ID: Bachelor of Interdisciplinary Studies, B.I.S._chunk18
# Add of existing embedding ID: Bachelor of Interdisciplinary Studies, B.I.S._chunk18
# Insert of existing embedding ID: Bachelor of Interdisciplinary Studies, B.I.S._chunk19
# Add of existing embedding ID: Bachelor of Interdisciplinary Studies, B.I.S._chunk19
# Insert of existing embedding ID: Bachelor of Interdisciplinary Studies, B.I.S._chunk20
# Add of existing embedding ID: Bachelor of Interdisciplinary Studies, B.I.S._chunk20
# Insert of existing embedding ID: Bachelor of Interdisciplinary Studies, B.I.S._chunk21
# Add of existing embedding ID: Bachelor of Interdisciplinary Studies, B.I.S._chunk21
# Insert of existing embedding ID: Bachelor of Interdisciplinary Studies, B.I.S._chunk22
# Add of existing embedding ID: Bachelor of Interdisciplinary Studies, B.I.S._chunk22
# Insert of existing embedding ID: Bachelor of Interdisciplinary Studies, B.I.S._chunk23
# Add of existing embedding ID: Bachelor of Interdisciplinary Studies, B.I.S._chunk23
# Insert of existing embedding ID: Bachelor of Interdisciplinary Studies, B.I.S._chunk24
# Add of existing embedding ID: Bachelor of Interdisciplinary Studies, B.I.S._chunk24
# Insert of existing embedding ID: Bachelor of Interdisciplinary Studies, B.I.S._chunk25
# Add of existing embedding ID: Bachelor of Interdisciplinary Studies, B.I.S._chunk25
# Insert of existing embedding ID: Bachelor of Interdisciplinary Studies, B.I.S._chunk26
# Add of existing embedding ID: Bachelor of Interdisciplinary Studies, B.I.S._chunk26
# Insert of existing embedding ID: Bachelor of Interdisciplinary Studies, B.I.S._chunk27
# Add of existing embedding ID: Bachelor of Interdisciplinary Studies, B.I.S._chunk27
# Insert of existing embedding ID: Bachelor of Interdisciplinary Studies, B.I.S._chunk28
# Add of existing embedding ID: Bachelor of Interdisciplinary Studies, B.I.S._chunk28
# Insert of existing embedding ID: Bachelor of Interdisciplinary Studies, B.I.S._chunk29
# Add of existing embedding ID: Bachelor of Interdisciplinary Studies, B.I.S._chunk29
# Insert of existing embedding ID: Bachelor of Interdisciplinary Studies, B.I.S._chunk30
# Add of existing embedding ID: Bachelor of Interdisciplinary Studies, B.I.S._chunk30
# Insert of existing embedding ID: Bachelor of Interdisciplinary Studies, B.I.S._chunk31
# Add of existing embedding ID: Bachelor of Interdisciplinary Studies, B.I.S._chunk31
# Insert of existing embedding ID: Bachelor of Interdisciplinary Studies, B.I.S._chunk32
# Add of existing embedding ID: Bachelor of Interdisciplinary Studies, B.I.S._chunk32
# Insert of existing embedding ID: Bachelor of Interdisciplinary Studies, B.I.S._chunk33
# Add of existing embedding ID: Bachelor of Interdisciplinary Studies, B.I.S._chunk33
# Insert of existing embedding ID: Bachelor of Interdisciplinary Studies, B.I.S._chunk34
# Add of existing embedding ID: Bachelor of Interdisciplinary Studies, B.I.S._chunk34
# Insert of existing embedding ID: Bachelor of Interdisciplinary Studies, B.I.S._chunk35
# Add of existing embedding ID: Bachelor of Interdisciplinary Studies, B.I.S._chunk35
# Insert of existing embedding ID: Bachelor of Interdisciplinary Studies, B.I.S._chunk36
# Add of existing embedding ID: Bachelor of Interdisciplinary Studies, B.I.S._chunk36
# Insert of existing embedding ID: Bachelor of Interdisciplinary Studies, B.I.S._chunk37
# Add of existing embedding ID: Bachelor of Interdisciplinary Studies, B.I.S._chunk37
# Insert of existing embedding ID: Bachelor of Interdisciplinary Studies, B.I.S._chunk38
# Add of existing embedding ID: Bachelor of Interdisciplinary Studies, B.I.S._chunk38
# Insert of existing embedding ID: Bachelor of Interdisciplinary Studies, B.I.S._chunk39
# Add of existing embedding ID: Bachelor of Interdisciplinary Studies, B.I.S._chunk39
# Insert of existing embedding ID: Bachelor of Interdisciplinary Studies, B.I.S._chunk40
# Add of existing embedding ID: Bachelor of Interdisciplinary Studies, B.I.S._chunk40
# Insert of existing embedding ID: Bachelor of Interdisciplinary Studies, B.I.S._chunk41
# Add of existing embedding ID: Bachelor of Interdisciplinary Studies, B.I.S._chunk41
# Insert of existing embedding ID: Data Science, B.S._chunk0
# Add of existing embedding ID: Data Science, B.S._chunk0
# Insert of existing embedding ID: Data Science, B.S._chunk1
# Add of existing embedding ID: Data Science, B.S._chunk1
# Insert of existing embedding ID: Data Science, B.S._chunk2
# Add of existing embedding ID: Data Science, B.S._chunk2
# Insert of existing embedding ID: Data Science, B.S._chunk3
# Add of existing embedding ID: Data Science, B.S._chunk3
# Insert of existing embedding ID: Data Science, B.S._chunk4
# Add of existing embedding ID: Data Science, B.S._chunk4
# Insert of existing embedding ID: Elementary Education , B.S.Ed._chunk0
# Add of existing embedding ID: Elementary Education , B.S.Ed._chunk0
# Insert of existing embedding ID: Elementary Education , B.S.Ed._chunk1
# Add of existing embedding ID: Elementary Education , B.S.Ed._chunk1
# Insert of existing embedding ID: Elementary Education , B.S.Ed._chunk2
# Add of existing embedding ID: Elementary Education , B.S.Ed._chunk2
# Insert of existing embedding ID: Elementary Education , B.S.Ed._chunk3
# Add of existing embedding ID: Elementary Education , B.S.Ed._chunk3
# Insert of existing embedding ID: Early Childhood Education , B.S.Ed._chunk0
# Add of existing embedding ID: Early Childhood Education , B.S.Ed._chunk0
# Insert of existing embedding ID: Early Childhood Education , B.S.Ed._chunk1
# Add of existing embedding ID: Early Childhood Education , B.S.Ed._chunk1
# Insert of existing embedding ID: Early Childhood Education , B.S.Ed._chunk2
# Add of existing embedding ID: Early Childhood Education , B.S.Ed._chunk2
# Insert of existing embedding ID: Early Childhood Education , B.S.Ed._chunk3
# Add of existing embedding ID: Early Childhood Education , B.S.Ed._chunk3
# Insert of existing embedding ID: Early Childhood Education , B.S.Ed._chunk4
# Add of existing embedding ID: Early Childhood Education , B.S.Ed._chunk4
# Insert of existing embedding ID: Special Education, B.S.Ed._chunk0
# Add of existing embedding ID: Special Education, B.S.Ed._chunk0
# Insert of existing embedding ID: Special Education, B.S.Ed._chunk1
# Add of existing embedding ID: Special Education, B.S.Ed._chunk1
# Insert of existing embedding ID: Special Education, B.S.Ed._chunk2
# Add of existing embedding ID: Special Education, B.S.Ed._chunk2
# Insert of existing embedding ID: Special Education, B.S.Ed._chunk3
# Add of existing embedding ID: Special Education, B.S.Ed._chunk3
# Insert of existing embedding ID: Kinesiology, B.S.Ed._chunk0
# Add of existing embedding ID: Kinesiology, B.S.Ed._chunk0
# Insert of existing embedding ID: Kinesiology, B.S.Ed._chunk1
# Add of existing embedding ID: Kinesiology, B.S.Ed._chunk1
# Insert of existing embedding ID: Kinesiology, B.S.Ed._chunk2
# Add of existing embedding ID: Kinesiology, B.S.Ed._chunk2
# Insert of existing embedding ID: Kinesiology, B.S.Ed._chunk3
# Add of existing embedding ID: Kinesiology, B.S.Ed._chunk3
# Insert of existing embedding ID: Speech Communication Disorders, B.S.Ed._chunk0
# Add of existing embedding ID: Speech Communication Disorders, B.S.Ed._chunk0
# Insert of existing embedding ID: Speech Communication Disorders, B.S.Ed._chunk1
# Add of existing embedding ID: Speech Communication Disorders, B.S.Ed._chunk1
# Insert of existing embedding ID: Speech Communication Disorders, B.S.Ed._chunk2
# Add of existing embedding ID: Speech Communication Disorders, B.S.Ed._chunk2
# Insert of existing embedding ID: Speech Communication Disorders, B.S.Ed._chunk3
# Add of existing embedding ID: Speech Communication Disorders, B.S.Ed._chunk3
# Insert of existing embedding ID: Youth and Social Innovation, B.S.Ed._chunk0
# Add of existing embedding ID: Youth and Social Innovation, B.S.Ed._chunk0
# Insert of existing embedding ID: Youth and Social Innovation, B.S.Ed._chunk1
# Add of existing embedding ID: Youth and Social Innovation, B.S.Ed._chunk1
# Insert of existing embedding ID: Youth and Social Innovation, B.S.Ed._chunk2
# Add of existing embedding ID: Youth and Social Innovation, B.S.Ed._chunk2
# Insert of existing embedding ID: Youth and Social Innovation, B.S.Ed._chunk3
# Add of existing embedding ID: Youth and Social Innovation, B.S.Ed._chunk3
# Insert of existing embedding ID: Youth and Social Innovation, B.S.Ed._chunk4
# Add of existing embedding ID: Youth and Social Innovation, B.S.Ed._chunk4
# Insert of existing embedding ID: Aerospace Engineering, B.S._chunk0
# Add of existing embedding ID: Aerospace Engineering, B.S._chunk0
# Insert of existing embedding ID: Aerospace Engineering, B.S._chunk1
# Add of existing embedding ID: Aerospace Engineering, B.S._chunk1
# Insert of existing embedding ID: Aerospace Engineering, B.S._chunk2
# Add of existing embedding ID: Aerospace Engineering, B.S._chunk2
# Insert of existing embedding ID: Aerospace Engineering, B.S._chunk3
# Add of existing embedding ID: Aerospace Engineering, B.S._chunk3
# Insert of existing embedding ID: Biomedical Engineering, B.S._chunk0
# Add of existing embedding ID: Biomedical Engineering, B.S._chunk0
# Insert of existing embedding ID: Biomedical Engineering, B.S._chunk1
# Add of existing embedding ID: Biomedical Engineering, B.S._chunk1
# Insert of existing embedding ID: Biomedical Engineering, B.S._chunk2
# Add of existing embedding ID: Biomedical Engineering, B.S._chunk2
# Insert of existing embedding ID: Biomedical Engineering, B.S._chunk3
# Add of existing embedding ID: Biomedical Engineering, B.S._chunk3
# Insert of existing embedding ID: Biomedical Engineering, B.S._chunk4
# Add of existing embedding ID: Biomedical Engineering, B.S._chunk4
# Insert of existing embedding ID: Chemical Engineering, B.S._chunk0
# Add of existing embedding ID: Chemical Engineering, B.S._chunk0
# Insert of existing embedding ID: Chemical Engineering, B.S._chunk1
# Add of existing embedding ID: Chemical Engineering, B.S._chunk1
# Insert of existing embedding ID: Chemical Engineering, B.S._chunk2
# Add of existing embedding ID: Chemical Engineering, B.S._chunk2
# Insert of existing embedding ID: Chemical Engineering, B.S._chunk3
# Add of existing embedding ID: Chemical Engineering, B.S._chunk3
# Insert of existing embedding ID: Chemical Engineering, B.S._chunk4
# Add of existing embedding ID: Chemical Engineering, B.S._chunk4
# Insert of existing embedding ID: Chemical Engineering, B.S._chunk5
# Add of existing embedding ID: Chemical Engineering, B.S._chunk5
# Insert of existing embedding ID: Chemical Engineering, B.S._chunk6
# Add of existing embedding ID: Chemical Engineering, B.S._chunk6
# Insert of existing embedding ID: Civil Engineering, B.S._chunk0
# Add of existing embedding ID: Civil Engineering, B.S._chunk0
# Insert of existing embedding ID: Civil Engineering, B.S._chunk1
# Add of existing embedding ID: Civil Engineering, B.S._chunk1
# Insert of existing embedding ID: Civil Engineering, B.S._chunk2
# Add of existing embedding ID: Civil Engineering, B.S._chunk2
# Insert of existing embedding ID: Civil Engineering, B.S._chunk3
# Add of existing embedding ID: Civil Engineering, B.S._chunk3
# Insert of existing embedding ID: Civil Engineering, B.S._chunk4
# Add of existing embedding ID: Civil Engineering, B.S._chunk4
# Insert of existing embedding ID: Civil Engineering, B.S._chunk5
# Add of existing embedding ID: Civil Engineering, B.S._chunk5
# Insert of existing embedding ID: Civil Engineering, B.S._chunk6
# Add of existing embedding ID: Civil Engineering, B.S._chunk6
# Insert of existing embedding ID: Computer Engineering, B.S._chunk0
# Add of existing embedding ID: Computer Engineering, B.S._chunk0
# Insert of existing embedding ID: Computer Engineering, B.S._chunk1
# Add of existing embedding ID: Computer Engineering, B.S._chunk1
# Insert of existing embedding ID: Computer Engineering, B.S._chunk2
# Add of existing embedding ID: Computer Engineering, B.S._chunk2
# Insert of existing embedding ID: Computer Engineering, B.S._chunk3
# Add of existing embedding ID: Computer Engineering, B.S._chunk3
# Insert of existing embedding ID: Computer Engineering, B.S._chunk4
# Add of existing embedding ID: Computer Engineering, B.S._chunk4
# Insert of existing embedding ID: Computer Engineering, B.S._chunk5
# Add of existing embedding ID: Computer Engineering, B.S._chunk5
# Insert of existing embedding ID: Computer Science, B.S._chunk0
# Add of existing embedding ID: Computer Science, B.S._chunk0
# Insert of existing embedding ID: Computer Science, B.S._chunk1
# Add of existing embedding ID: Computer Science, B.S._chunk1
# Insert of existing embedding ID: Computer Science, B.S._chunk2
# Add of existing embedding ID: Computer Science, B.S._chunk2
# Insert of existing embedding ID: Computer Science, B.S._chunk3
# Add of existing embedding ID: Computer Science, B.S._chunk3
# Insert of existing embedding ID: Computer Science, B.S._chunk4
# Add of existing embedding ID: Computer Science, B.S._chunk4
# Insert of existing embedding ID: Electrical Engineering, B.S._chunk0
# Add of existing embedding ID: Electrical Engineering, B.S._chunk0
# Insert of existing embedding ID: Electrical Engineering, B.S._chunk1
# Add of existing embedding ID: Electrical Engineering, B.S._chunk1
# Insert of existing embedding ID: Electrical Engineering, B.S._chunk2
# Add of existing embedding ID: Electrical Engineering, B.S._chunk2
# Insert of existing embedding ID: Electrical Engineering, B.S._chunk3
# Add of existing embedding ID: Electrical Engineering, B.S._chunk3
# Insert of existing embedding ID: Electrical Engineering, B.S._chunk4
# Add of existing embedding ID: Electrical Engineering, B.S._chunk4
# Insert of existing embedding ID: Electrical Engineering, B.S._chunk5
# Add of existing embedding ID: Electrical Engineering, B.S._chunk5
# Insert of existing embedding ID: Electrical Engineering, B.S._chunk6
# Add of existing embedding ID: Electrical Engineering, B.S._chunk6
# Insert of existing embedding ID: Engineering Science, B.S._chunk0
# Add of existing embedding ID: Engineering Science, B.S._chunk0
# Insert of existing embedding ID: Engineering Science, B.S._chunk1
# Add of existing embedding ID: Engineering Science, B.S._chunk1
# Insert of existing embedding ID: Engineering Science, B.S._chunk2
# Add of existing embedding ID: Engineering Science, B.S._chunk2
# Insert of existing embedding ID: Engineering Science, B.S._chunk3
# Add of existing embedding ID: Engineering Science, B.S._chunk3
# Insert of existing embedding ID: Materials Science and Engineering, B.S._chunk0
# Add of existing embedding ID: Materials Science and Engineering, B.S._chunk0
# Insert of existing embedding ID: Materials Science and Engineering, B.S._chunk1
# Add of existing embedding ID: Materials Science and Engineering, B.S._chunk1
# Insert of existing embedding ID: Materials Science and Engineering, B.S._chunk2
# Add of existing embedding ID: Materials Science and Engineering, B.S._chunk2
# Insert of existing embedding ID: Materials Science and Engineering, B.S._chunk3
# Add of existing embedding ID: Materials Science and Engineering, B.S._chunk3
# Insert of existing embedding ID: Materials Science and Engineering, B.S._chunk4
# Add of existing embedding ID: Materials Science and Engineering, B.S._chunk4
# Insert of existing embedding ID: Materials Science and Engineering, B.S._chunk5
# Add of existing embedding ID: Materials Science and Engineering, B.S._chunk5
# Insert of existing embedding ID: Materials Science and Engineering, B.S._chunk6
# Add of existing embedding ID: Materials Science and Engineering, B.S._chunk6
# Insert of existing embedding ID: Materials Science and Engineering, B.S._chunk7
# Add of existing embedding ID: Materials Science and Engineering, B.S._chunk7
# Insert of existing embedding ID: Materials Science and Engineering, B.S._chunk8
# Add of existing embedding ID: Materials Science and Engineering, B.S._chunk8
# Insert of existing embedding ID: Mechanical Engineering, B.S._chunk0
# Add of existing embedding ID: Mechanical Engineering, B.S._chunk0
# Insert of existing embedding ID: Mechanical Engineering, B.S._chunk1
# Add of existing embedding ID: Mechanical Engineering, B.S._chunk1
# Insert of existing embedding ID: Mechanical Engineering, B.S._chunk2
# Add of existing embedding ID: Mechanical Engineering, B.S._chunk2
# Insert of existing embedding ID: Mechanical Engineering, B.S._chunk3
# Add of existing embedding ID: Mechanical Engineering, B.S._chunk3
# Insert of existing embedding ID: Mechanical Engineering, B.S._chunk4
# Add of existing embedding ID: Mechanical Engineering, B.S._chunk4
# Insert of existing embedding ID: Systems Engineering, B.S._chunk0
# Add of existing embedding ID: Systems Engineering, B.S._chunk0
# Insert of existing embedding ID: Systems Engineering, B.S._chunk1
# Add of existing embedding ID: Systems Engineering, B.S._chunk1
# Insert of existing embedding ID: Systems Engineering, B.S._chunk2
# Add of existing embedding ID: Systems Engineering, B.S._chunk2
# Insert of existing embedding ID: Systems Engineering, B.S._chunk3
# Add of existing embedding ID: Systems Engineering, B.S._chunk3
# Insert of existing embedding ID: Systems Engineering, B.S._chunk4
# Add of existing embedding ID: Systems Engineering, B.S._chunk4
# Insert of existing embedding ID: Public Policy and Leadership, B.A._chunk0
# Add of existing embedding ID: Public Policy and Leadership, B.A._chunk0
# Insert of existing embedding ID: Public Policy and Leadership, B.A._chunk1
# Add of existing embedding ID: Public Policy and Leadership, B.A._chunk1
# Insert of existing embedding ID: Public Policy and Leadership, B.A._chunk2
# Add of existing embedding ID: Public Policy and Leadership, B.A._chunk2
# Insert of existing embedding ID: Nursing, B.S.N._chunk0
# Add of existing embedding ID: Nursing, B.S.N._chunk0
# Insert of existing embedding ID: Nursing, B.S.N._chunk1
# Add of existing embedding ID: Nursing, B.S.N._chunk1
# Insert of existing embedding ID: Nursing, B.S.N._chunk2
# Add of existing embedding ID: Nursing, B.S.N._chunk2
# Insert of existing embedding ID: Nursing, B.S.N._chunk3
# Add of existing embedding ID: Nursing, B.S.N._chunk3
# Insert of existing embedding ID: Nursing, B.S.N._chunk4
# Add of existing embedding ID: Nursing, B.S.N._chunk4
# Insert of existing embedding ID: Nursing, B.S.N._chunk5
# Add of existing embedding ID: Nursing, B.S.N._chunk5
# Insert of existing embedding ID: Nursing, B.S.N._chunk6
# Add of existing embedding ID: Nursing, B.S.N._chunk6
# Insert of existing embedding ID: Nursing, B.S.N._chunk7
# Add of existing embedding ID: Nursing, B.S.N._chunk7
# Insert of existing embedding ID: Nursing, B.S.N._chunk8
# Add of existing embedding ID: Nursing, B.S.N._chunk8
# Insert of existing embedding ID: Nursing, B.S.N._chunk9
# Add of existing embedding ID: Nursing, B.S.N._chunk9
# Chunked course descriptions stored in ChromaDB!

# %%
# Store chunked schools data
for course in schools_dict:
    chunks = chunk_text(course["Text"])
    for i, chunk in enumerate(chunks):
        embedding = model.encode(chunk).tolist()  # Convert to list for ChromaDB
        collection.add(
            ids=[f"{course['School']}_chunk{i}"],  
            embeddings=[embedding],  
            metadatas=[{
                "School": course["School"],
                "chunk_index": i,
                "Text": chunk
            }]
        )

print("Chunked schools stored in ChromaDB!")
# Out:
# Insert of existing embedding ID: School of Architecture_chunk0
# Add of existing embedding ID: School of Architecture_chunk0
# Insert of existing embedding ID: School of Architecture_chunk1
# Add of existing embedding ID: School of Architecture_chunk1
# Insert of existing embedding ID: School of Architecture_chunk2
# Add of existing embedding ID: School of Architecture_chunk2
# Insert of existing embedding ID: School of Architecture_chunk3
# Add of existing embedding ID: School of Architecture_chunk3
# Insert of existing embedding ID: School of Architecture_chunk4
# Add of existing embedding ID: School of Architecture_chunk4
# Insert of existing embedding ID: School of Architecture_chunk5
# Add of existing embedding ID: School of Architecture_chunk5
# Insert of existing embedding ID: School of Architecture_chunk6
# Add of existing embedding ID: School of Architecture_chunk6
# Insert of existing embedding ID: School of Architecture_chunk7
# Add of existing embedding ID: School of Architecture_chunk7
# Insert of existing embedding ID: School of Architecture_chunk8
# Add of existing embedding ID: School of Architecture_chunk8
# Insert of existing embedding ID: School of Architecture_chunk9
# Add of existing embedding ID: School of Architecture_chunk9
# Insert of existing embedding ID: School of Architecture_chunk10
# Add of existing embedding ID: School of Architecture_chunk10
# Insert of existing embedding ID: School of Architecture_chunk11
# Add of existing embedding ID: School of Architecture_chunk11
# Insert of existing embedding ID: School of Architecture_chunk12
# Add of existing embedding ID: School of Architecture_chunk12
# Insert of existing embedding ID: College of Arts & Sciences_chunk0
# Add of existing embedding ID: College of Arts & Sciences_chunk0
# Insert of existing embedding ID: College of Arts & Sciences_chunk1
# Add of existing embedding ID: College of Arts & Sciences_chunk1
# Insert of existing embedding ID: College of Arts & Sciences_chunk2
# Add of existing embedding ID: College of Arts & Sciences_chunk2
# Insert of existing embedding ID: College of Arts & Sciences_chunk3
# Add of existing embedding ID: College of Arts & Sciences_chunk3
# Insert of existing embedding ID: College of Arts & Sciences_chunk4
# Add of existing embedding ID: College of Arts & Sciences_chunk4
# Insert of existing embedding ID: College of Arts & Sciences_chunk5
# Add of existing embedding ID: College of Arts & Sciences_chunk5
# Insert of existing embedding ID: College of Arts & Sciences_chunk6
# Add of existing embedding ID: College of Arts & Sciences_chunk6
# Insert of existing embedding ID: College of Arts & Sciences_chunk7
# Add of existing embedding ID: College of Arts & Sciences_chunk7
# Insert of existing embedding ID: College of Arts & Sciences_chunk8
# Add of existing embedding ID: College of Arts & Sciences_chunk8
# Insert of existing embedding ID: College of Arts & Sciences_chunk9
# Add of existing embedding ID: College of Arts & Sciences_chunk9
# Insert of existing embedding ID: College of Arts & Sciences_chunk10
# Add of existing embedding ID: College of Arts & Sciences_chunk10
# Insert of existing embedding ID: College of Arts & Sciences_chunk11
# Add of existing embedding ID: College of Arts & Sciences_chunk11
# Insert of existing embedding ID: College of Arts & Sciences_chunk12
# Add of existing embedding ID: College of Arts & Sciences_chunk12
# Insert of existing embedding ID: College of Arts & Sciences_chunk13
# Add of existing embedding ID: College of Arts & Sciences_chunk13
# Insert of existing embedding ID: College of Arts & Sciences_chunk14
# Add of existing embedding ID: College of Arts & Sciences_chunk14
# Insert of existing embedding ID: College of Arts & Sciences_chunk15
# Add of existing embedding ID: College of Arts & Sciences_chunk15
# Insert of existing embedding ID: College of Arts & Sciences_chunk16
# Add of existing embedding ID: College of Arts & Sciences_chunk16
# Insert of existing embedding ID: College of Arts & Sciences_chunk17
# Add of existing embedding ID: College of Arts & Sciences_chunk17
# Insert of existing embedding ID: College of Arts & Sciences_chunk18
# Add of existing embedding ID: College of Arts & Sciences_chunk18
# Insert of existing embedding ID: College of Arts & Sciences_chunk19
# Add of existing embedding ID: College of Arts & Sciences_chunk19
# Insert of existing embedding ID: College of Arts & Sciences_chunk20
# Add of existing embedding ID: College of Arts & Sciences_chunk20
# Insert of existing embedding ID: College of Arts & Sciences_chunk21
# Add of existing embedding ID: College of Arts & Sciences_chunk21
# Insert of existing embedding ID: College of Arts & Sciences_chunk22
# Add of existing embedding ID: College of Arts & Sciences_chunk22
# Insert of existing embedding ID: College of Arts & Sciences_chunk23
# Add of existing embedding ID: College of Arts & Sciences_chunk23
# Insert of existing embedding ID: College of Arts & Sciences_chunk24
# Add of existing embedding ID: College of Arts & Sciences_chunk24
# Insert of existing embedding ID: College of Arts & Sciences_chunk25
# Add of existing embedding ID: College of Arts & Sciences_chunk25
# Insert of existing embedding ID: College of Arts & Sciences_chunk26
# Add of existing embedding ID: College of Arts & Sciences_chunk26
# Insert of existing embedding ID: College of Arts & Sciences_chunk27
# Add of existing embedding ID: College of Arts & Sciences_chunk27
# Insert of existing embedding ID: College of Arts & Sciences_chunk28
# Add of existing embedding ID: College of Arts & Sciences_chunk28
# Insert of existing embedding ID: College of Arts & Sciences_chunk29
# Add of existing embedding ID: College of Arts & Sciences_chunk29
# Insert of existing embedding ID: College of Arts & Sciences_chunk30
# Add of existing embedding ID: College of Arts & Sciences_chunk30
# Insert of existing embedding ID: College of Arts & Sciences_chunk31
# Add of existing embedding ID: College of Arts & Sciences_chunk31
# Insert of existing embedding ID: College of Arts & Sciences_chunk32
# Add of existing embedding ID: College of Arts & Sciences_chunk32
# Insert of existing embedding ID: College of Arts & Sciences_chunk33
# Add of existing embedding ID: College of Arts & Sciences_chunk33
# Insert of existing embedding ID: College of Arts & Sciences_chunk34
# Add of existing embedding ID: College of Arts & Sciences_chunk34
# Insert of existing embedding ID: College of Arts & Sciences_chunk35
# Add of existing embedding ID: College of Arts & Sciences_chunk35
# Insert of existing embedding ID: College of Arts & Sciences_chunk36
# Add of existing embedding ID: College of Arts & Sciences_chunk36
# Insert of existing embedding ID: College of Arts & Sciences_chunk37
# Add of existing embedding ID: College of Arts & Sciences_chunk37
# Insert of existing embedding ID: College of Arts & Sciences_chunk38
# Add of existing embedding ID: College of Arts & Sciences_chunk38
# Insert of existing embedding ID: McIntire School of Commerce_chunk0
# Add of existing embedding ID: McIntire School of Commerce_chunk0
# Insert of existing embedding ID: McIntire School of Commerce_chunk1
# Add of existing embedding ID: McIntire School of Commerce_chunk1
# Insert of existing embedding ID: McIntire School of Commerce_chunk2
# Add of existing embedding ID: McIntire School of Commerce_chunk2
# Insert of existing embedding ID: McIntire School of Commerce_chunk3
# Add of existing embedding ID: McIntire School of Commerce_chunk3
# Insert of existing embedding ID: McIntire School of Commerce_chunk4
# Add of existing embedding ID: McIntire School of Commerce_chunk4
# Insert of existing embedding ID: McIntire School of Commerce_chunk5
# Add of existing embedding ID: McIntire School of Commerce_chunk5
# Insert of existing embedding ID: McIntire School of Commerce_chunk6
# Add of existing embedding ID: McIntire School of Commerce_chunk6
# Insert of existing embedding ID: McIntire School of Commerce_chunk7
# Add of existing embedding ID: McIntire School of Commerce_chunk7
# Insert of existing embedding ID: McIntire School of Commerce_chunk8
# Add of existing embedding ID: McIntire School of Commerce_chunk8
# Insert of existing embedding ID: McIntire School of Commerce_chunk9
# Add of existing embedding ID: McIntire School of Commerce_chunk9
# Insert of existing embedding ID: McIntire School of Commerce_chunk10
# Add of existing embedding ID: McIntire School of Commerce_chunk10
# Insert of existing embedding ID: McIntire School of Commerce_chunk11
# Add of existing embedding ID: McIntire School of Commerce_chunk11
# Insert of existing embedding ID: McIntire School of Commerce_chunk12
# Add of existing embedding ID: McIntire School of Commerce_chunk12
# Insert of existing embedding ID: McIntire School of Commerce_chunk13
# Add of existing embedding ID: McIntire School of Commerce_chunk13
# Insert of existing embedding ID: School of Continuing and Professional Studies_chunk0
# Add of existing embedding ID: School of Continuing and Professional Studies_chunk0
# Insert of existing embedding ID: School of Continuing and Professional Studies_chunk1
# Add of existing embedding ID: School of Continuing and Professional Studies_chunk1
# Insert of existing embedding ID: School of Continuing and Professional Studies_chunk2
# Add of existing embedding ID: School of Continuing and Professional Studies_chunk2
# Insert of existing embedding ID: School of Continuing and Professional Studies_chunk3
# Add of existing embedding ID: School of Continuing and Professional Studies_chunk3
# Insert of existing embedding ID: School of Continuing and Professional Studies_chunk4
# Add of existing embedding ID: School of Continuing and Professional Studies_chunk4
# Insert of existing embedding ID: School of Continuing and Professional Studies_chunk5
# Add of existing embedding ID: School of Continuing and Professional Studies_chunk5
# Insert of existing embedding ID: School of Continuing and Professional Studies_chunk6
# Add of existing embedding ID: School of Continuing and Professional Studies_chunk6
# Insert of existing embedding ID: School of Continuing and Professional Studies_chunk7
# Add of existing embedding ID: School of Continuing and Professional Studies_chunk7
# Insert of existing embedding ID: School of Continuing and Professional Studies_chunk8
# Add of existing embedding ID: School of Continuing and Professional Studies_chunk8
# Insert of existing embedding ID: School of Continuing and Professional Studies_chunk9
# Add of existing embedding ID: School of Continuing and Professional Studies_chunk9
# Insert of existing embedding ID: School of Continuing and Professional Studies_chunk10
# Add of existing embedding ID: School of Continuing and Professional Studies_chunk10
# Insert of existing embedding ID: School of Continuing and Professional Studies_chunk11
# Add of existing embedding ID: School of Continuing and Professional Studies_chunk11
# Insert of existing embedding ID: School of Continuing and Professional Studies_chunk12
# Add of existing embedding ID: School of Continuing and Professional Studies_chunk12
# Insert of existing embedding ID: School of Continuing and Professional Studies_chunk13
# Add of existing embedding ID: School of Continuing and Professional Studies_chunk13
# Insert of existing embedding ID: School of Continuing and Professional Studies_chunk14
# Add of existing embedding ID: School of Continuing and Professional Studies_chunk14
# Insert of existing embedding ID: School of Data Science_chunk0
# Add of existing embedding ID: School of Data Science_chunk0
# Insert of existing embedding ID: School of Data Science_chunk1
# Add of existing embedding ID: School of Data Science_chunk1
# Insert of existing embedding ID: School of Data Science_chunk2
# Add of existing embedding ID: School of Data Science_chunk2
# Insert of existing embedding ID: School of Data Science_chunk3
# Add of existing embedding ID: School of Data Science_chunk3
# Insert of existing embedding ID: School of Data Science_chunk4
# Add of existing embedding ID: School of Data Science_chunk4
# Insert of existing embedding ID: School of Data Science_chunk5
# Add of existing embedding ID: School of Data Science_chunk5
# Insert of existing embedding ID: School of Data Science_chunk6
# Add of existing embedding ID: School of Data Science_chunk6
# Insert of existing embedding ID: School of Data Science_chunk7
# Add of existing embedding ID: School of Data Science_chunk7
# Insert of existing embedding ID: School of Data Science_chunk8
# Add of existing embedding ID: School of Data Science_chunk8
# Insert of existing embedding ID: School of Data Science_chunk9
# Add of existing embedding ID: School of Data Science_chunk9
# Insert of existing embedding ID: School of Data Science_chunk10
# Add of existing embedding ID: School of Data Science_chunk10
# Insert of existing embedding ID: School of Data Science_chunk11
# Add of existing embedding ID: School of Data Science_chunk11
# Insert of existing embedding ID: School of Education and Human Development_chunk0
# Add of existing embedding ID: School of Education and Human Development_chunk0
# Insert of existing embedding ID: School of Education and Human Development_chunk1
# Add of existing embedding ID: School of Education and Human Development_chunk1
# Insert of existing embedding ID: School of Education and Human Development_chunk2
# Add of existing embedding ID: School of Education and Human Development_chunk2
# Insert of existing embedding ID: School of Education and Human Development_chunk3
# Add of existing embedding ID: School of Education and Human Development_chunk3
# Insert of existing embedding ID: School of Education and Human Development_chunk4
# Add of existing embedding ID: School of Education and Human Development_chunk4
# Insert of existing embedding ID: School of Education and Human Development_chunk5
# Add of existing embedding ID: School of Education and Human Development_chunk5
# Insert of existing embedding ID: School of Education and Human Development_chunk6
# Add of existing embedding ID: School of Education and Human Development_chunk6
# Insert of existing embedding ID: School of Education and Human Development_chunk7
# Add of existing embedding ID: School of Education and Human Development_chunk7
# Insert of existing embedding ID: School of Education and Human Development_chunk8
# Add of existing embedding ID: School of Education and Human Development_chunk8
# Insert of existing embedding ID: School of Education and Human Development_chunk9
# Add of existing embedding ID: School of Education and Human Development_chunk9
# Insert of existing embedding ID: School of Education and Human Development_chunk10
# Add of existing embedding ID: School of Education and Human Development_chunk10
# Insert of existing embedding ID: School of Education and Human Development_chunk11
# Add of existing embedding ID: School of Education and Human Development_chunk11
# Insert of existing embedding ID: School of Education and Human Development_chunk12
# Add of existing embedding ID: School of Education and Human Development_chunk12
# Insert of existing embedding ID: School of Education and Human Development_chunk13
# Add of existing embedding ID: School of Education and Human Development_chunk13
# Insert of existing embedding ID: School of Education and Human Development_chunk14
# Add of existing embedding ID: School of Education and Human Development_chunk14
# Insert of existing embedding ID: School of Education and Human Development_chunk15
# Add of existing embedding ID: School of Education and Human Development_chunk15
# Insert of existing embedding ID: School of Education and Human Development_chunk16
# Add of existing embedding ID: School of Education and Human Development_chunk16
# Insert of existing embedding ID: School of Engineering and Applied Science_chunk0
# Add of existing embedding ID: School of Engineering and Applied Science_chunk0
# Insert of existing embedding ID: School of Engineering and Applied Science_chunk1
# Add of existing embedding ID: School of Engineering and Applied Science_chunk1
# Insert of existing embedding ID: School of Engineering and Applied Science_chunk2
# Add of existing embedding ID: School of Engineering and Applied Science_chunk2
# Insert of existing embedding ID: School of Engineering and Applied Science_chunk3
# Add of existing embedding ID: School of Engineering and Applied Science_chunk3
# Insert of existing embedding ID: School of Engineering and Applied Science_chunk4
# Add of existing embedding ID: School of Engineering and Applied Science_chunk4
# Insert of existing embedding ID: School of Engineering and Applied Science_chunk5
# Add of existing embedding ID: School of Engineering and Applied Science_chunk5
# Insert of existing embedding ID: School of Engineering and Applied Science_chunk6
# Add of existing embedding ID: School of Engineering and Applied Science_chunk6
# Insert of existing embedding ID: School of Engineering and Applied Science_chunk7
# Add of existing embedding ID: School of Engineering and Applied Science_chunk7
# Insert of existing embedding ID: School of Engineering and Applied Science_chunk8
# Add of existing embedding ID: School of Engineering and Applied Science_chunk8
# Insert of existing embedding ID: School of Engineering and Applied Science_chunk9
# Add of existing embedding ID: School of Engineering and Applied Science_chunk9
# Insert of existing embedding ID: School of Engineering and Applied Science_chunk10
# Add of existing embedding ID: School of Engineering and Applied Science_chunk10
# Insert of existing embedding ID: School of Engineering and Applied Science_chunk11
# Add of existing embedding ID: School of Engineering and Applied Science_chunk11
# Insert of existing embedding ID: School of Engineering and Applied Science_chunk12
# Add of existing embedding ID: School of Engineering and Applied Science_chunk12
# Insert of existing embedding ID: School of Engineering and Applied Science_chunk13
# Add of existing embedding ID: School of Engineering and Applied Science_chunk13
# Insert of existing embedding ID: School of Engineering and Applied Science_chunk14
# Add of existing embedding ID: School of Engineering and Applied Science_chunk14
# Insert of existing embedding ID: Frank Batten School of Leadership and Public Policy_chunk0
# Add of existing embedding ID: Frank Batten School of Leadership and Public Policy_chunk0
# Insert of existing embedding ID: Frank Batten School of Leadership and Public Policy_chunk1
# Add of existing embedding ID: Frank Batten School of Leadership and Public Policy_chunk1
# Insert of existing embedding ID: Frank Batten School of Leadership and Public Policy_chunk2
# Add of existing embedding ID: Frank Batten School of Leadership and Public Policy_chunk2
# Insert of existing embedding ID: Frank Batten School of Leadership and Public Policy_chunk3
# Add of existing embedding ID: Frank Batten School of Leadership and Public Policy_chunk3
# Insert of existing embedding ID: Frank Batten School of Leadership and Public Policy_chunk4
# Add of existing embedding ID: Frank Batten School of Leadership and Public Policy_chunk4
# Insert of existing embedding ID: Frank Batten School of Leadership and Public Policy_chunk5
# Add of existing embedding ID: Frank Batten School of Leadership and Public Policy_chunk5
# Insert of existing embedding ID: Frank Batten School of Leadership and Public Policy_chunk6
# Add of existing embedding ID: Frank Batten School of Leadership and Public Policy_chunk6
# Insert of existing embedding ID: Frank Batten School of Leadership and Public Policy_chunk7
# Add of existing embedding ID: Frank Batten School of Leadership and Public Policy_chunk7
# Insert of existing embedding ID: Frank Batten School of Leadership and Public Policy_chunk8
# Add of existing embedding ID: Frank Batten School of Leadership and Public Policy_chunk8
# Insert of existing embedding ID: Frank Batten School of Leadership and Public Policy_chunk9
# Add of existing embedding ID: Frank Batten School of Leadership and Public Policy_chunk9
# Insert of existing embedding ID: Frank Batten School of Leadership and Public Policy_chunk10
# Add of existing embedding ID: Frank Batten School of Leadership and Public Policy_chunk10
# Insert of existing embedding ID: Frank Batten School of Leadership and Public Policy_chunk11
# Add of existing embedding ID: Frank Batten School of Leadership and Public Policy_chunk11
# Insert of existing embedding ID: Frank Batten School of Leadership and Public Policy_chunk12
# Add of existing embedding ID: Frank Batten School of Leadership and Public Policy_chunk12
# Insert of existing embedding ID: Frank Batten School of Leadership and Public Policy_chunk13
# Add of existing embedding ID: Frank Batten School of Leadership and Public Policy_chunk13
# Insert of existing embedding ID: Frank Batten School of Leadership and Public Policy_chunk14
# Add of existing embedding ID: Frank Batten School of Leadership and Public Policy_chunk14
# Insert of existing embedding ID: Frank Batten School of Leadership and Public Policy_chunk15
# Add of existing embedding ID: Frank Batten School of Leadership and Public Policy_chunk15
# Insert of existing embedding ID: Frank Batten School of Leadership and Public Policy_chunk16
# Add of existing embedding ID: Frank Batten School of Leadership and Public Policy_chunk16
# Insert of existing embedding ID: Frank Batten School of Leadership and Public Policy_chunk17
# Add of existing embedding ID: Frank Batten School of Leadership and Public Policy_chunk17
# Insert of existing embedding ID: Frank Batten School of Leadership and Public Policy_chunk18
# Add of existing embedding ID: Frank Batten School of Leadership and Public Policy_chunk18
# Insert of existing embedding ID: Frank Batten School of Leadership and Public Policy_chunk19
# Add of existing embedding ID: Frank Batten School of Leadership and Public Policy_chunk19
# Insert of existing embedding ID: Frank Batten School of Leadership and Public Policy_chunk20
# Add of existing embedding ID: Frank Batten School of Leadership and Public Policy_chunk20
# Insert of existing embedding ID: School of Nursing_chunk0
# Add of existing embedding ID: School of Nursing_chunk0
# Insert of existing embedding ID: School of Nursing_chunk1
# Add of existing embedding ID: School of Nursing_chunk1
# Insert of existing embedding ID: School of Nursing_chunk2
# Add of existing embedding ID: School of Nursing_chunk2
# Insert of existing embedding ID: School of Nursing_chunk3
# Add of existing embedding ID: School of Nursing_chunk3
# Insert of existing embedding ID: School of Nursing_chunk4
# Add of existing embedding ID: School of Nursing_chunk4
# Insert of existing embedding ID: School of Nursing_chunk5
# Add of existing embedding ID: School of Nursing_chunk5
# Insert of existing embedding ID: School of Nursing_chunk6
# Add of existing embedding ID: School of Nursing_chunk6
# Insert of existing embedding ID: School of Nursing_chunk7
# Add of existing embedding ID: School of Nursing_chunk7
# Insert of existing embedding ID: School of Nursing_chunk8
# Add of existing embedding ID: School of Nursing_chunk8
# Insert of existing embedding ID: School of Nursing_chunk9
# Add of existing embedding ID: School of Nursing_chunk9
# Insert of existing embedding ID: School of Nursing_chunk10
# Add of existing embedding ID: School of Nursing_chunk10
# Insert of existing embedding ID: School of Nursing_chunk11
# Add of existing embedding ID: School of Nursing_chunk11
# Insert of existing embedding ID: School of Nursing_chunk12
# Add of existing embedding ID: School of Nursing_chunk12
# Insert of existing embedding ID: School of Nursing_chunk13
# Add of existing embedding ID: School of Nursing_chunk13
# Insert of existing embedding ID: School of Nursing_chunk14
# Add of existing embedding ID: School of Nursing_chunk14
# Insert of existing embedding ID: School of Nursing_chunk15
# Add of existing embedding ID: School of Nursing_chunk15
# Insert of existing embedding ID: School of Nursing_chunk16
# Add of existing embedding ID: School of Nursing_chunk16
# Insert of existing embedding ID: School of Nursing_chunk17
# Add of existing embedding ID: School of Nursing_chunk17
# Chunked schools stored in ChromaDB!

# %% [markdown]
# add course number, section, semester, year, etc
# this might improve

# %%
#store classes in collection
for course in classes_dict:
    embedding = model.encode(course["Description"]).tolist()  # Convert to list for ChromaDB
    collection_classes.add(
        ids=[f"{course['ClassNumber']}_{course['Mnemonic']}_{course['Number']}_{course['Section']}"],  
        embeddings=[embedding],  
        metadatas=[{
            "Code": course["Mnemonic"],
            "Number": course["Number"],
            "Section": course["Section"],
            "Type": course["Type"],
            "Units": course["Units"],
            "Instructor": course["Instructor"],
            "Days": course["Days"],
            "Room": course["Room"],
            "Title": course["Title"],
            'Semester': course['semester'],
            'Year': course['year'], 
            "Type": 'Class',
            "Description": course["Description"],
            "Department": course["descr"]
        }]
    )

print("Classes data stored in ChromaDB!")
# Out:
# Add of existing embedding ID: 10003_AAS_1010_100
# Insert of existing embedding ID: 10003_AAS_1010_100
# Add of existing embedding ID: 12774_AAS_1010_101
# Insert of existing embedding ID: 12774_AAS_1010_101
# Add of existing embedding ID: 10006_AAS_1010_102
# Insert of existing embedding ID: 10006_AAS_1010_102
# Add of existing embedding ID: 10004_AAS_1010_103
# Insert of existing embedding ID: 10004_AAS_1010_103
# Add of existing embedding ID: 10005_AAS_1010_104
# Insert of existing embedding ID: 10005_AAS_1010_104
# Add of existing embedding ID: 10007_AAS_1010_105
# Insert of existing embedding ID: 10007_AAS_1010_105
# Add of existing embedding ID: 10008_AAS_1010_106
# Insert of existing embedding ID: 10008_AAS_1010_106
# Add of existing embedding ID: 11700_AAS_1010_107
# Insert of existing embedding ID: 11700_AAS_1010_107
# Add of existing embedding ID: 11701_AAS_1010_108
# Insert of existing embedding ID: 11701_AAS_1010_108
# Add of existing embedding ID: 11702_AAS_1010_109
# Insert of existing embedding ID: 11702_AAS_1010_109
# Add of existing embedding ID: 19866_AAS_2210_001
# Insert of existing embedding ID: 19866_AAS_2210_001
# Add of existing embedding ID: 19843_AAS_2220_001
# Insert of existing embedding ID: 19843_AAS_2220_001
# Add of existing embedding ID: 19842_AAS_2240_001
# Insert of existing embedding ID: 19842_AAS_2240_001
# Add of existing embedding ID: 13334_AAS_2500_001
# Insert of existing embedding ID: 13334_AAS_2500_001
# Add of existing embedding ID: 12773_AAS_2500_002
# Insert of existing embedding ID: 12773_AAS_2500_002
# Add of existing embedding ID: 13335_AAS_2500_003
# Insert of existing embedding ID: 13335_AAS_2500_003
# Add of existing embedding ID: 13336_AAS_2500_004
# Insert of existing embedding ID: 13336_AAS_2500_004
# Add of existing embedding ID: 20235_AAS_2657_001
# Insert of existing embedding ID: 20235_AAS_2657_001
# Add of existing embedding ID: 19847_AAS_3310_001
# Insert of existing embedding ID: 19847_AAS_3310_001
# Add of existing embedding ID: 13230_AAS_3500_001
# Insert of existing embedding ID: 13230_AAS_3500_001
# Add of existing embedding ID: 20410_AAS_3500_002
# Insert of existing embedding ID: 20410_AAS_3500_002
# Add of existing embedding ID: 13759_AAS_3500_003
# Insert of existing embedding ID: 13759_AAS_3500_003
# Add of existing embedding ID: 19858_AAS_3559_001
# Insert of existing embedding ID: 19858_AAS_3559_001
# Add of existing embedding ID: 19849_AAS_3745_001
# Insert of existing embedding ID: 19849_AAS_3745_001
# Add of existing embedding ID: 19841_AAS_3750_001
# Insert of existing embedding ID: 19841_AAS_3750_001
# Add of existing embedding ID: 19859_AAS_3770_001
# Insert of existing embedding ID: 19859_AAS_3770_001
# Add of existing embedding ID: 19856_AAS_3810_001
# Insert of existing embedding ID: 19856_AAS_3810_001
# Add of existing embedding ID: 13222_AAS_3853_001
# Insert of existing embedding ID: 13222_AAS_3853_001
# Add of existing embedding ID: 13223_AAS_3853_101
# Insert of existing embedding ID: 13223_AAS_3853_101
# Add of existing embedding ID: 13224_AAS_3853_102
# Insert of existing embedding ID: 13224_AAS_3853_102
# Add of existing embedding ID: 13225_AAS_3853_103
# Insert of existing embedding ID: 13225_AAS_3853_103
# Add of existing embedding ID: 13226_AAS_3853_104
# Insert of existing embedding ID: 13226_AAS_3853_104
# Add of existing embedding ID: 13227_AAS_3853_105
# Insert of existing embedding ID: 13227_AAS_3853_105
# Add of existing embedding ID: 13228_AAS_3853_106
# Insert of existing embedding ID: 13228_AAS_3853_106
# Add of existing embedding ID: 14042_AAS_3853_107
# Insert of existing embedding ID: 14042_AAS_3853_107
# Add of existing embedding ID: 10929_AAS_4070_001
# Insert of existing embedding ID: 10929_AAS_4070_001
# Add of existing embedding ID: 13742_AAS_4501_001
# Insert of existing embedding ID: 13742_AAS_4501_001
# Add of existing embedding ID: 13744_AAS_4570_001
# Insert of existing embedding ID: 13744_AAS_4570_001
# Add of existing embedding ID: 12451_AAS_9710_001
# Insert of existing embedding ID: 12451_AAS_9710_001
# Add of existing embedding ID: 14596_AIRS_100_001
# Insert of existing embedding ID: 14596_AIRS_100_001
# Add of existing embedding ID: 14591_AIRS_1100_001
# Insert of existing embedding ID: 14591_AIRS_1100_001
# Add of existing embedding ID: 14592_AIRS_1100_002
# Insert of existing embedding ID: 14592_AIRS_1100_002
# Add of existing embedding ID: 14593_AIRS_2100_001
# Insert of existing embedding ID: 14593_AIRS_2100_001
# Add of existing embedding ID: 14594_AIRS_2100_002
# Insert of existing embedding ID: 14594_AIRS_2100_002
# Add of existing embedding ID: 14597_AIRS_3100_001
# Insert of existing embedding ID: 14597_AIRS_3100_001
# Add of existing embedding ID: 14598_AIRS_3100_002
# Insert of existing embedding ID: 14598_AIRS_3100_002
# Add of existing embedding ID: 14595_AIRS_4100_001
# Insert of existing embedding ID: 14595_AIRS_4100_001
# Add of existing embedding ID: 14599_AIRS_4100_002
# Insert of existing embedding ID: 14599_AIRS_4100_002
# Add of existing embedding ID: 17802_ALAR_5203_001
# Insert of existing embedding ID: 17802_ALAR_5203_001
# Add of existing embedding ID: 17801_ALAR_5403_001
# Insert of existing embedding ID: 17801_ALAR_5403_001
# Add of existing embedding ID: 17598_ALAR_8010_001
# Insert of existing embedding ID: 17598_ALAR_8010_001
# Add of existing embedding ID: 17726_ALAR_8100_001
# Insert of existing embedding ID: 17726_ALAR_8100_001
# Add of existing embedding ID: 10546_AMST_2001_100
# Insert of existing embedding ID: 10546_AMST_2001_100
# Add of existing embedding ID: 11100_AMST_2001_101
# Insert of existing embedding ID: 11100_AMST_2001_101
# Add of existing embedding ID: 11101_AMST_2001_102
# Insert of existing embedding ID: 11101_AMST_2001_102
# Add of existing embedding ID: 11668_AMST_2001_103
# Insert of existing embedding ID: 11668_AMST_2001_103
# Add of existing embedding ID: 11669_AMST_2001_104
# Insert of existing embedding ID: 11669_AMST_2001_104
# Add of existing embedding ID: 11298_AMST_2001_105
# Insert of existing embedding ID: 11298_AMST_2001_105
# Add of existing embedding ID: 11299_AMST_2001_106
# Insert of existing embedding ID: 11299_AMST_2001_106
# Add of existing embedding ID: 11670_AMST_2001_107
# Insert of existing embedding ID: 11670_AMST_2001_107
# Add of existing embedding ID: 11671_AMST_2001_108
# Insert of existing embedding ID: 11671_AMST_2001_108
# Add of existing embedding ID: 11099_AMST_2001_109
# Insert of existing embedding ID: 11099_AMST_2001_109
# Add of existing embedding ID: 11300_AMST_2001_110
# Insert of existing embedding ID: 11300_AMST_2001_110
# Add of existing embedding ID: 11672_AMST_2001_111
# Insert of existing embedding ID: 11672_AMST_2001_111
# Add of existing embedding ID: 11673_AMST_2001_112
# Insert of existing embedding ID: 11673_AMST_2001_112
# Add of existing embedding ID: 13896_AMST_2130_001
# Insert of existing embedding ID: 13896_AMST_2130_001
# Add of existing embedding ID: 19334_AMST_2130_002
# Insert of existing embedding ID: 19334_AMST_2130_002
# Add of existing embedding ID: 20037_AMST_2559_001
# Insert of existing embedding ID: 20037_AMST_2559_001
# Add of existing embedding ID: 11417_AMST_3001_001
# Insert of existing embedding ID: 11417_AMST_3001_001
# Add of existing embedding ID: 19290_AMST_3001_002
# Insert of existing embedding ID: 19290_AMST_3001_002
# Add of existing embedding ID: 19163_AMST_3200_001
# Insert of existing embedding ID: 19163_AMST_3200_001
# Add of existing embedding ID: 19483_AMST_3326_001
# Insert of existing embedding ID: 19483_AMST_3326_001
# Add of existing embedding ID: 19484_AMST_3472_001
# Insert of existing embedding ID: 19484_AMST_3472_001
# Add of existing embedding ID: 20065_AMST_3500_001
# Insert of existing embedding ID: 20065_AMST_3500_001
# Add of existing embedding ID: 20421_AMST_3500_002
# Insert of existing embedding ID: 20421_AMST_3500_002
# Add of existing embedding ID: 20522_AMST_3500_110
# Insert of existing embedding ID: 20522_AMST_3500_110
# Add of existing embedding ID: 19292_AMST_3559_001
# Insert of existing embedding ID: 19292_AMST_3559_001
# Add of existing embedding ID: 20215_AMST_3559_002
# Insert of existing embedding ID: 20215_AMST_3559_002
# Add of existing embedding ID: 19161_AMST_4500_001
# Insert of existing embedding ID: 19161_AMST_4500_001
# Add of existing embedding ID: 19293_AMST_4559_001
# Insert of existing embedding ID: 19293_AMST_4559_001
# Add of existing embedding ID: 19294_AMST_4559_002
# Insert of existing embedding ID: 19294_AMST_4559_002
# Add of existing embedding ID: 19295_AMST_4559_003
# Insert of existing embedding ID: 19295_AMST_4559_003
# Add of existing embedding ID: 12939_AMST_4893_001
# Insert of existing embedding ID: 12939_AMST_4893_001
# Add of existing embedding ID: 12948_AMST_4993_001
# Insert of existing embedding ID: 12948_AMST_4993_001
# Add of existing embedding ID: 14325_AMST_4998_001
# Insert of existing embedding ID: 14325_AMST_4998_001
# Add of existing embedding ID: 14326_AMST_4998_002
# Insert of existing embedding ID: 14326_AMST_4998_002
# Add of existing embedding ID: 14327_AMST_4998_003
# Insert of existing embedding ID: 14327_AMST_4998_003
# Add of existing embedding ID: 14328_AMST_4998_004
# Insert of existing embedding ID: 14328_AMST_4998_004
# Add of existing embedding ID: 20099_AMST_4999_001
# Insert of existing embedding ID: 20099_AMST_4999_001
# Add of existing embedding ID: 14056_AMST_8993_001
# Insert of existing embedding ID: 14056_AMST_8993_001
# Add of existing embedding ID: 10009_ANTH_1010_001
# Insert of existing embedding ID: 10009_ANTH_1010_001
# Add of existing embedding ID: 13958_ANTH_2160_100
# Insert of existing embedding ID: 13958_ANTH_2160_100
# Add of existing embedding ID: 13990_ANTH_2160_101
# Insert of existing embedding ID: 13990_ANTH_2160_101
# Add of existing embedding ID: 13991_ANTH_2160_102
# Insert of existing embedding ID: 13991_ANTH_2160_102
# Add of existing embedding ID: 13992_ANTH_2160_103
# Insert of existing embedding ID: 13992_ANTH_2160_103
# Add of existing embedding ID: 11247_ANTH_2280_100
# Insert of existing embedding ID: 11247_ANTH_2280_100
# Add of existing embedding ID: 11872_ANTH_2280_101
# Insert of existing embedding ID: 11872_ANTH_2280_101
# Add of existing embedding ID: 11873_ANTH_2280_102
# Insert of existing embedding ID: 11873_ANTH_2280_102
# Add of existing embedding ID: 11874_ANTH_2280_103
# Insert of existing embedding ID: 11874_ANTH_2280_103
# Add of existing embedding ID: 13009_ANTH_2280_104
# Insert of existing embedding ID: 13009_ANTH_2280_104
# Add of existing embedding ID: 13010_ANTH_2280_105
# Insert of existing embedding ID: 13010_ANTH_2280_105
# Add of existing embedding ID: 13011_ANTH_2280_106
# Insert of existing embedding ID: 13011_ANTH_2280_106
# Add of existing embedding ID: 13296_ANTH_2280_107
# Insert of existing embedding ID: 13296_ANTH_2280_107
# Add of existing embedding ID: 13579_ANTH_2280_108
# Insert of existing embedding ID: 13579_ANTH_2280_108
# Add of existing embedding ID: 13580_ANTH_2280_109
# Insert of existing embedding ID: 13580_ANTH_2280_109
# Add of existing embedding ID: 20489_ANTH_2280_110
# Insert of existing embedding ID: 20489_ANTH_2280_110
# Add of existing embedding ID: 20490_ANTH_2280_111
# Insert of existing embedding ID: 20490_ANTH_2280_111
# Add of existing embedding ID: 20491_ANTH_2280_112
# Insert of existing embedding ID: 20491_ANTH_2280_112
# Add of existing embedding ID: 12222_ANTH_2400_100
# Insert of existing embedding ID: 12222_ANTH_2400_100
# Add of existing embedding ID: 12387_ANTH_2400_101
# Insert of existing embedding ID: 12387_ANTH_2400_101
# Add of existing embedding ID: 12388_ANTH_2400_102
# Insert of existing embedding ID: 12388_ANTH_2400_102
# Add of existing embedding ID: 12389_ANTH_2400_103
# Insert of existing embedding ID: 12389_ANTH_2400_103
# Add of existing embedding ID: 12690_ANTH_2410_001
# Insert of existing embedding ID: 12690_ANTH_2410_001
# Add of existing embedding ID: 19379_ANTH_2415_100
# Insert of existing embedding ID: 19379_ANTH_2415_100
# Add of existing embedding ID: 19382_ANTH_2415_101
# Insert of existing embedding ID: 19382_ANTH_2415_101
# Add of existing embedding ID: 19383_ANTH_2415_102
# Insert of existing embedding ID: 19383_ANTH_2415_102
# Add of existing embedding ID: 19384_ANTH_2415_103
# Insert of existing embedding ID: 19384_ANTH_2415_103
# Add of existing embedding ID: 19385_ANTH_2450_100
# Insert of existing embedding ID: 19385_ANTH_2450_100
# Add of existing embedding ID: 19386_ANTH_2450_101
# Insert of existing embedding ID: 19386_ANTH_2450_101
# Add of existing embedding ID: 19387_ANTH_2450_102
# Insert of existing embedding ID: 19387_ANTH_2450_102
# Add of existing embedding ID: 19388_ANTH_2450_103
# Insert of existing embedding ID: 19388_ANTH_2450_103
# Add of existing embedding ID: 19447_ANTH_2470_001
# Insert of existing embedding ID: 19447_ANTH_2470_001
# Add of existing embedding ID: 19390_ANTH_2620_100
# Insert of existing embedding ID: 19390_ANTH_2620_100
# Add of existing embedding ID: 10010_ANTH_2800_001
# Insert of existing embedding ID: 10010_ANTH_2800_001
# Add of existing embedding ID: 11503_ANTH_2800_101
# Insert of existing embedding ID: 11503_ANTH_2800_101
# Add of existing embedding ID: 11504_ANTH_2800_102
# Insert of existing embedding ID: 11504_ANTH_2800_102
# Add of existing embedding ID: 13276_ANTH_2800_103
# Insert of existing embedding ID: 13276_ANTH_2800_103
# Add of existing embedding ID: 20420_ANTH_2830_001
# Insert of existing embedding ID: 20420_ANTH_2830_001
# Add of existing embedding ID: 12680_ANTH_3010_001
# Insert of existing embedding ID: 12680_ANTH_3010_001
# Add of existing embedding ID: 12805_ANTH_3152_001
# Insert of existing embedding ID: 12805_ANTH_3152_001
# Add of existing embedding ID: 11653_ANTH_3290_001
# Insert of existing embedding ID: 11653_ANTH_3290_001
# Add of existing embedding ID: 19433_ANTH_3325_001
# Insert of existing embedding ID: 19433_ANTH_3325_001
# Add of existing embedding ID: 20034_ANTH_3332_001
# Insert of existing embedding ID: 20034_ANTH_3332_001
# Add of existing embedding ID: 19434_ANTH_3344_001
# Insert of existing embedding ID: 19434_ANTH_3344_001
# Add of existing embedding ID: 20036_ANTH_3430_001
# Insert of existing embedding ID: 20036_ANTH_3430_001
# Add of existing embedding ID: 13582_ANTH_3450_001
# Insert of existing embedding ID: 13582_ANTH_3450_001
# Add of existing embedding ID: 19437_ANTH_3589_001
# Insert of existing embedding ID: 19437_ANTH_3589_001
# Add of existing embedding ID: 19439_ANTH_3590_002
# Insert of existing embedding ID: 19439_ANTH_3590_002
# Add of existing embedding ID: 20216_ANTH_3590_003
# Insert of existing embedding ID: 20216_ANTH_3590_003
# Add of existing embedding ID: 13583_ANTH_3679_001
# Insert of existing embedding ID: 13583_ANTH_3679_001
# Add of existing embedding ID: 19440_ANTH_3840_001
# Insert of existing embedding ID: 19440_ANTH_3840_001
# Add of existing embedding ID: 11599_ANTH_4591_001
# Insert of existing embedding ID: 11599_ANTH_4591_001
# Add of existing embedding ID: 12385_ANTH_4591_002
# Insert of existing embedding ID: 12385_ANTH_4591_002
# Add of existing embedding ID: 10011_ANTH_4993_001
# Insert of existing embedding ID: 10011_ANTH_4993_001
# Add of existing embedding ID: 12016_ANTH_4993_002
# Insert of existing embedding ID: 12016_ANTH_4993_002
# Add of existing embedding ID: 13275_ANTH_4993_003
# Insert of existing embedding ID: 13275_ANTH_4993_003
# Add of existing embedding ID: 11688_ANTH_4998_001
# Insert of existing embedding ID: 11688_ANTH_4998_001
# Add of existing embedding ID: 12043_ANTH_4998_002
# Insert of existing embedding ID: 12043_ANTH_4998_002
# Add of existing embedding ID: 12226_ANTH_4998_003
# Insert of existing embedding ID: 12226_ANTH_4998_003
# Add of existing embedding ID: 12486_ANTH_4998_004
# Insert of existing embedding ID: 12486_ANTH_4998_004
# Add of existing embedding ID: 11551_ANTH_4998_005
# Insert of existing embedding ID: 11551_ANTH_4998_005
# Add of existing embedding ID: 12807_ANTH_4998_006
# Insert of existing embedding ID: 12807_ANTH_4998_006
# Add of existing embedding ID: 14359_ANTH_4998_007
# Insert of existing embedding ID: 14359_ANTH_4998_007
# Add of existing embedding ID: 14360_ANTH_4998_008
# Insert of existing embedding ID: 14360_ANTH_4998_008
# Add of existing embedding ID: 14366_ANTH_4998_009
# Insert of existing embedding ID: 14366_ANTH_4998_009
# Add of existing embedding ID: 20419_ANTH_5252_001
# Insert of existing embedding ID: 20419_ANTH_5252_001
# Add of existing embedding ID: 19441_ANTH_5528_001
# Insert of existing embedding ID: 19441_ANTH_5528_001
# Add of existing embedding ID: 19442_ANTH_5589_001
# Insert of existing embedding ID: 19442_ANTH_5589_001
# Add of existing embedding ID: 19444_ANTH_7040_001
# Insert of existing embedding ID: 19444_ANTH_7040_001
# Add of existing embedding ID: 20417_ANTH_7330_001
# Insert of existing embedding ID: 20417_ANTH_7330_001
# Add of existing embedding ID: 19445_ANTH_7344_001
# Insert of existing embedding ID: 19445_ANTH_7344_001
# Add of existing embedding ID: 20416_ANTH_7430_001
# Insert of existing embedding ID: 20416_ANTH_7430_001
# Add of existing embedding ID: 13589_ANTH_7450_001
# Insert of existing embedding ID: 13589_ANTH_7450_001
# Add of existing embedding ID: 10012_ANTH_8998_001
# Insert of existing embedding ID: 10012_ANTH_8998_001
# Add of existing embedding ID: 12231_ANTH_8998_002
# Insert of existing embedding ID: 12231_ANTH_8998_002
# Add of existing embedding ID: 10930_ANTH_8998_003
# Insert of existing embedding ID: 10930_ANTH_8998_003
# Add of existing embedding ID: 10931_ANTH_8998_004
# Insert of existing embedding ID: 10931_ANTH_8998_004
# Add of existing embedding ID: 10932_ANTH_8998_005
# Insert of existing embedding ID: 10932_ANTH_8998_005
# Add of existing embedding ID: 10933_ANTH_8998_006
# Insert of existing embedding ID: 10933_ANTH_8998_006
# Add of existing embedding ID: 10934_ANTH_8998_007
# Insert of existing embedding ID: 10934_ANTH_8998_007
# Add of existing embedding ID: 10935_ANTH_8998_008
# Insert of existing embedding ID: 10935_ANTH_8998_008
# Add of existing embedding ID: 10936_ANTH_8998_009
# Insert of existing embedding ID: 10936_ANTH_8998_009
# Add of existing embedding ID: 11577_ANTH_8998_010
# Insert of existing embedding ID: 11577_ANTH_8998_010
# Add of existing embedding ID: 10937_ANTH_8998_011
# Insert of existing embedding ID: 10937_ANTH_8998_011
# Add of existing embedding ID: 11578_ANTH_8998_012
# Insert of existing embedding ID: 11578_ANTH_8998_012
# Add of existing embedding ID: 11993_ANTH_8998_013
# Insert of existing embedding ID: 11993_ANTH_8998_013
# Add of existing embedding ID: 10013_ANTH_8999_001
# Insert of existing embedding ID: 10013_ANTH_8999_001
# Add of existing embedding ID: 10742_ANTH_8999_002
# Insert of existing embedding ID: 10742_ANTH_8999_002
# Add of existing embedding ID: 10743_ANTH_8999_003
# Insert of existing embedding ID: 10743_ANTH_8999_003
# Add of existing embedding ID: 12039_ANTH_8999_004
# Insert of existing embedding ID: 12039_ANTH_8999_004
# Add of existing embedding ID: 10744_ANTH_8999_005
# Insert of existing embedding ID: 10744_ANTH_8999_005
# Add of existing embedding ID: 10745_ANTH_8999_006
# Insert of existing embedding ID: 10745_ANTH_8999_006
# Add of existing embedding ID: 11114_ANTH_8999_007
# Insert of existing embedding ID: 11114_ANTH_8999_007
# Add of existing embedding ID: 11994_ANTH_8999_008
# Insert of existing embedding ID: 11994_ANTH_8999_008
# Add of existing embedding ID: 12526_ANTH_8999_009
# Insert of existing embedding ID: 12526_ANTH_8999_009
# Add of existing embedding ID: 12530_ANTH_8999_010
# Insert of existing embedding ID: 12530_ANTH_8999_010
# Add of existing embedding ID: 11741_ANTH_9010_001
# Insert of existing embedding ID: 11741_ANTH_9010_001
# Add of existing embedding ID: 11773_ANTH_9010_002
# Insert of existing embedding ID: 11773_ANTH_9010_002
# Add of existing embedding ID: 11916_ANTH_9010_003
# Insert of existing embedding ID: 11916_ANTH_9010_003
# Add of existing embedding ID: 11778_ANTH_9010_004
# Insert of existing embedding ID: 11778_ANTH_9010_004
# Add of existing embedding ID: 12457_ANTH_9010_005
# Insert of existing embedding ID: 12457_ANTH_9010_005
# Add of existing embedding ID: 12056_ANTH_9010_006
# Insert of existing embedding ID: 12056_ANTH_9010_006
# Add of existing embedding ID: 12471_ANTH_9010_007
# Insert of existing embedding ID: 12471_ANTH_9010_007
# Add of existing embedding ID: 12480_ANTH_9010_008
# Insert of existing embedding ID: 12480_ANTH_9010_008
# Add of existing embedding ID: 12921_ANTH_9010_009
# Insert of existing embedding ID: 12921_ANTH_9010_009
# Add of existing embedding ID: 13399_ANTH_9010_010
# Insert of existing embedding ID: 13399_ANTH_9010_010
# Add of existing embedding ID: 13400_ANTH_9010_011
# Insert of existing embedding ID: 13400_ANTH_9010_011
# Add of existing embedding ID: 13419_ANTH_9010_012
# Insert of existing embedding ID: 13419_ANTH_9010_012
# Add of existing embedding ID: 13442_ANTH_9010_013
# Insert of existing embedding ID: 13442_ANTH_9010_013
# Add of existing embedding ID: 12472_ANTH_9020_001
# Insert of existing embedding ID: 12472_ANTH_9020_001
# Add of existing embedding ID: 12481_ANTH_9020_002
# Insert of existing embedding ID: 12481_ANTH_9020_002
# Add of existing embedding ID: 12900_ANTH_9020_003
# Insert of existing embedding ID: 12900_ANTH_9020_003
# Add of existing embedding ID: 12048_ANTH_9050_001
# Insert of existing embedding ID: 12048_ANTH_9050_001
# Add of existing embedding ID: 11687_ANTH_9050_002
# Insert of existing embedding ID: 11687_ANTH_9050_002
# Add of existing embedding ID: 12033_ANTH_9050_003
# Insert of existing embedding ID: 12033_ANTH_9050_003
# Add of existing embedding ID: 12837_ANTH_9050_004
# Insert of existing embedding ID: 12837_ANTH_9050_004
# Add of existing embedding ID: 14342_ANTH_9050_005
# Insert of existing embedding ID: 14342_ANTH_9050_005
# Add of existing embedding ID: 10014_ANTH_9998_001
# Insert of existing embedding ID: 10014_ANTH_9998_001
# Add of existing embedding ID: 12002_ANTH_9998_002
# Insert of existing embedding ID: 12002_ANTH_9998_002
# Add of existing embedding ID: 12500_ANTH_9998_003
# Insert of existing embedding ID: 12500_ANTH_9998_003
# Add of existing embedding ID: 10938_ANTH_9998_004
# Insert of existing embedding ID: 10938_ANTH_9998_004
# Add of existing embedding ID: 10939_ANTH_9998_005
# Insert of existing embedding ID: 10939_ANTH_9998_005
# Add of existing embedding ID: 10940_ANTH_9998_006
# Insert of existing embedding ID: 10940_ANTH_9998_006
# Add of existing embedding ID: 10941_ANTH_9998_007
# Insert of existing embedding ID: 10941_ANTH_9998_007
# Add of existing embedding ID: 10942_ANTH_9998_008
# Insert of existing embedding ID: 10942_ANTH_9998_008
# Add of existing embedding ID: 10943_ANTH_9998_009
# Insert of existing embedding ID: 10943_ANTH_9998_009
# Add of existing embedding ID: 10944_ANTH_9998_010
# Insert of existing embedding ID: 10944_ANTH_9998_010
# Add of existing embedding ID: 10945_ANTH_9998_011
# Insert of existing embedding ID: 10945_ANTH_9998_011
# Add of existing embedding ID: 12034_ANTH_9998_012
# Insert of existing embedding ID: 12034_ANTH_9998_012
# Add of existing embedding ID: 12437_ANTH_9998_013
# Insert of existing embedding ID: 12437_ANTH_9998_013
# Add of existing embedding ID: 10015_ANTH_9999_001
# Insert of existing embedding ID: 10015_ANTH_9999_001
# Add of existing embedding ID: 10567_ANTH_9999_002
# Insert of existing embedding ID: 10567_ANTH_9999_002
# Add of existing embedding ID: 10568_ANTH_9999_003
# Insert of existing embedding ID: 10568_ANTH_9999_003
# Add of existing embedding ID: 10582_ANTH_9999_004
# Insert of existing embedding ID: 10582_ANTH_9999_004
# Add of existing embedding ID: 10583_ANTH_9999_005
# Insert of existing embedding ID: 10583_ANTH_9999_005
# Add of existing embedding ID: 10584_ANTH_9999_006
# Insert of existing embedding ID: 10584_ANTH_9999_006
# Add of existing embedding ID: 10585_ANTH_9999_007
# Insert of existing embedding ID: 10585_ANTH_9999_007
# Add of existing embedding ID: 10738_ANTH_9999_008
# Insert of existing embedding ID: 10738_ANTH_9999_008
# Add of existing embedding ID: 10739_ANTH_9999_009
# Insert of existing embedding ID: 10739_ANTH_9999_009
# Add of existing embedding ID: 10741_ANTH_9999_010
# Insert of existing embedding ID: 10741_ANTH_9999_010
# Add of existing embedding ID: 11450_ANTH_9999_011
# Insert of existing embedding ID: 11450_ANTH_9999_011
# Add of existing embedding ID: 11963_ANTH_9999_012
# Insert of existing embedding ID: 11963_ANTH_9999_012
# Add of existing embedding ID: 12035_ANTH_9999_013
# Insert of existing embedding ID: 12035_ANTH_9999_013
# Add of existing embedding ID: 12511_ANTH_9999_014
# Insert of existing embedding ID: 12511_ANTH_9999_014
# Add of existing embedding ID: 12438_ANTH_9999_015
# Insert of existing embedding ID: 12438_ANTH_9999_015
# Add of existing embedding ID: 12917_ANTH_9999_016
# Insert of existing embedding ID: 12917_ANTH_9999_016
# Add of existing embedding ID: 12918_ANTH_9999_017
# Insert of existing embedding ID: 12918_ANTH_9999_017
# Add of existing embedding ID: 14354_ANTH_9999_018
# Insert of existing embedding ID: 14354_ANTH_9999_018
# Add of existing embedding ID: 14932_APMA_1090_001
# Insert of existing embedding ID: 14932_APMA_1090_001
# Add of existing embedding ID: 15331_APMA_1090_002
# Insert of existing embedding ID: 15331_APMA_1090_002
# Add of existing embedding ID: 15651_APMA_1090_003
# Insert of existing embedding ID: 15651_APMA_1090_003
# Add of existing embedding ID: 15691_APMA_1090_004
# Insert of existing embedding ID: 15691_APMA_1090_004
# Add of existing embedding ID: 15924_APMA_1090_005
# Insert of existing embedding ID: 15924_APMA_1090_005
# Add of existing embedding ID: 14662_APMA_1110_001
# Insert of existing embedding ID: 14662_APMA_1110_001
# Add of existing embedding ID: 14663_APMA_1110_002
# Insert of existing embedding ID: 14663_APMA_1110_002
# Add of existing embedding ID: 14660_APMA_1110_003
# Insert of existing embedding ID: 14660_APMA_1110_003
# Add of existing embedding ID: 14661_APMA_1110_004
# Insert of existing embedding ID: 14661_APMA_1110_004
# Add of existing embedding ID: 15295_APMA_1110_005
# Insert of existing embedding ID: 15295_APMA_1110_005
# Add of existing embedding ID: 16179_APMA_1110_006
# Insert of existing embedding ID: 16179_APMA_1110_006
# Add of existing embedding ID: 14666_APMA_2120_001
# Insert of existing embedding ID: 14666_APMA_2120_001
# Add of existing embedding ID: 14664_APMA_2120_002
# Insert of existing embedding ID: 14664_APMA_2120_002
# Add of existing embedding ID: 15057_APMA_2120_003
# Insert of existing embedding ID: 15057_APMA_2120_003
# Add of existing embedding ID: 14665_APMA_2120_004
# Insert of existing embedding ID: 14665_APMA_2120_004
# Add of existing embedding ID: 15040_APMA_2120_005
# Insert of existing embedding ID: 15040_APMA_2120_005
# Add of existing embedding ID: 15789_APMA_2120_006
# Insert of existing embedding ID: 15789_APMA_2120_006
# Add of existing embedding ID: 15844_APMA_2120_007
# Insert of existing embedding ID: 15844_APMA_2120_007
# Add of existing embedding ID: 14669_APMA_2130_001
# Insert of existing embedding ID: 14669_APMA_2130_001
# Add of existing embedding ID: 14670_APMA_2130_002
# Insert of existing embedding ID: 14670_APMA_2130_002
# Add of existing embedding ID: 14667_APMA_2130_003
# Insert of existing embedding ID: 14667_APMA_2130_003
# Add of existing embedding ID: 14763_APMA_2130_004
# Insert of existing embedding ID: 14763_APMA_2130_004
# Add of existing embedding ID: 15074_APMA_2130_005
# Insert of existing embedding ID: 15074_APMA_2130_005
# Add of existing embedding ID: 15132_APMA_2130_006
# Insert of existing embedding ID: 15132_APMA_2130_006
# Add of existing embedding ID: 16424_APMA_2501_001
# Insert of existing embedding ID: 16424_APMA_2501_001
# Add of existing embedding ID: 14671_APMA_3080_001
# Insert of existing embedding ID: 14671_APMA_3080_001
# Add of existing embedding ID: 14672_APMA_3080_002
# Insert of existing embedding ID: 14672_APMA_3080_002
# Add of existing embedding ID: 14673_APMA_3080_003
# Insert of existing embedding ID: 14673_APMA_3080_003
# Add of existing embedding ID: 15128_APMA_3080_004
# Insert of existing embedding ID: 15128_APMA_3080_004
# Add of existing embedding ID: 15596_APMA_3080_005
# Insert of existing embedding ID: 15596_APMA_3080_005
# Add of existing embedding ID: 15777_APMA_3100_001
# Insert of existing embedding ID: 15777_APMA_3100_001
# Add of existing embedding ID: 14674_APMA_3100_002
# Insert of existing embedding ID: 14674_APMA_3100_002
# Add of existing embedding ID: 14675_APMA_3100_003
# Insert of existing embedding ID: 14675_APMA_3100_003
# Add of existing embedding ID: 15597_APMA_3100_004
# Insert of existing embedding ID: 15597_APMA_3100_004
# Add of existing embedding ID: 15787_APMA_3100_005
# Insert of existing embedding ID: 15787_APMA_3100_005
# Add of existing embedding ID: 14677_APMA_3110_001
# Insert of existing embedding ID: 14677_APMA_3110_001
# Add of existing embedding ID: 14676_APMA_3110_002
# Insert of existing embedding ID: 14676_APMA_3110_002
# Add of existing embedding ID: 14678_APMA_3110_003
# Insert of existing embedding ID: 14678_APMA_3110_003
# Add of existing embedding ID: 14679_APMA_3120_001
# Insert of existing embedding ID: 14679_APMA_3120_001
# Add of existing embedding ID: 14680_APMA_3120_002
# Insert of existing embedding ID: 14680_APMA_3120_002
# Add of existing embedding ID: 15334_APMA_3120_003
# Insert of existing embedding ID: 15334_APMA_3120_003
# Add of existing embedding ID: 14681_APMA_3140_001
# Insert of existing embedding ID: 14681_APMA_3140_001
# Add of existing embedding ID: 15598_APMA_3140_002
# Insert of existing embedding ID: 15598_APMA_3140_002
# Add of existing embedding ID: 16180_APMA_3140_003
# Insert of existing embedding ID: 16180_APMA_3140_003
# Add of existing embedding ID: 15172_APMA_3150_001
# Insert of existing embedding ID: 15172_APMA_3150_001
# Add of existing embedding ID: 16027_APMA_3150_002
# Insert of existing embedding ID: 16027_APMA_3150_002
# Add of existing embedding ID: 16181_APMA_3150_003
# Insert of existing embedding ID: 16181_APMA_3150_003
# Add of existing embedding ID: 15275_APMA_3501_001
# Insert of existing embedding ID: 15275_APMA_3501_001
# Add of existing embedding ID: 15925_APMA_6410_001
# Insert of existing embedding ID: 15925_APMA_6410_001
# Add of existing embedding ID: 15276_APMA_6548_001
# Insert of existing embedding ID: 15276_APMA_6548_001
# Add of existing embedding ID: 11056_ARAB_1010_001
# Insert of existing embedding ID: 11056_ARAB_1010_001
# Add of existing embedding ID: 10016_ARAB_1010_002
# Insert of existing embedding ID: 10016_ARAB_1010_002
# Add of existing embedding ID: 10017_ARAB_1010_003
# Insert of existing embedding ID: 10017_ARAB_1010_003
# Add of existing embedding ID: 11171_ARAB_1010_004
# Insert of existing embedding ID: 11171_ARAB_1010_004
# Add of existing embedding ID: 14091_ARAB_1060_001
# Insert of existing embedding ID: 14091_ARAB_1060_001
# Add of existing embedding ID: 10019_ARAB_2010_001
# Insert of existing embedding ID: 10019_ARAB_2010_001
# Add of existing embedding ID: 10018_ARAB_2010_002
# Insert of existing embedding ID: 10018_ARAB_2010_002
# Add of existing embedding ID: 10666_ARAB_2010_003
# Insert of existing embedding ID: 10666_ARAB_2010_003
# Add of existing embedding ID: 10503_ARAB_3010_001
# Insert of existing embedding ID: 10503_ARAB_3010_001
# Add of existing embedding ID: 20290_ARAB_3430_001
# Insert of existing embedding ID: 20290_ARAB_3430_001
# Add of existing embedding ID: 19374_ARAB_3672_001
# Insert of existing embedding ID: 19374_ARAB_3672_001
# Add of existing embedding ID: 10899_ARAB_4010_001
# Insert of existing embedding ID: 10899_ARAB_4010_001
# Add of existing embedding ID: 20321_ARAB_5430_001
# Insert of existing embedding ID: 20321_ARAB_5430_001
# Add of existing embedding ID: 19375_ARAB_6672_001
# Insert of existing embedding ID: 19375_ARAB_6672_001
# Add of existing embedding ID: 11174_ARAD_3100_001
# Insert of existing embedding ID: 11174_ARAD_3100_001
# Add of existing embedding ID: 12832_ARAH_8051_001
# Insert of existing embedding ID: 12832_ARAH_8051_001
# Add of existing embedding ID: 13469_ARAH_8060_001
# Insert of existing embedding ID: 13469_ARAH_8060_001
# Add of existing embedding ID: 12004_ARAH_8695_001
# Insert of existing embedding ID: 12004_ARAH_8695_001
# Add of existing embedding ID: 12070_ARAH_8695_002
# Insert of existing embedding ID: 12070_ARAH_8695_002
# Add of existing embedding ID: 12536_ARAH_8695_003
# Insert of existing embedding ID: 12536_ARAH_8695_003
# Add of existing embedding ID: 12537_ARAH_8695_004
# Insert of existing embedding ID: 12537_ARAH_8695_004
# Add of existing embedding ID: 12739_ARAH_8695_005
# Insert of existing embedding ID: 12739_ARAH_8695_005
# Add of existing embedding ID: 12740_ARAH_8695_006
# Insert of existing embedding ID: 12740_ARAH_8695_006
# Add of existing embedding ID: 12741_ARAH_8695_007
# Insert of existing embedding ID: 12741_ARAH_8695_007
# Add of existing embedding ID: 12742_ARAH_8695_008
# Insert of existing embedding ID: 12742_ARAH_8695_008
# Add of existing embedding ID: 12743_ARAH_8695_009
# Insert of existing embedding ID: 12743_ARAH_8695_009
# Add of existing embedding ID: 12744_ARAH_8695_010
# Insert of existing embedding ID: 12744_ARAH_8695_010
# Add of existing embedding ID: 12745_ARAH_8695_011
# Insert of existing embedding ID: 12745_ARAH_8695_011
# Add of existing embedding ID: 12746_ARAH_8695_012
# Insert of existing embedding ID: 12746_ARAH_8695_012
# Add of existing embedding ID: 12747_ARAH_8695_013
# Insert of existing embedding ID: 12747_ARAH_8695_013
# Add of existing embedding ID: 12749_ARAH_8695_015
# Insert of existing embedding ID: 12749_ARAH_8695_015
# Add of existing embedding ID: 12915_ARAH_8695_016
# Insert of existing embedding ID: 12915_ARAH_8695_016
# Add of existing embedding ID: 14207_ARAH_8695_017
# Insert of existing embedding ID: 14207_ARAH_8695_017
# Add of existing embedding ID: 10020_ARAH_8998_001
# Insert of existing embedding ID: 10020_ARAH_8998_001
# Add of existing embedding ID: 10782_ARAH_8998_002
# Insert of existing embedding ID: 10782_ARAH_8998_002
# Add of existing embedding ID: 10792_ARAH_8998_003
# Insert of existing embedding ID: 10792_ARAH_8998_003
# Add of existing embedding ID: 10793_ARAH_8998_004
# Insert of existing embedding ID: 10793_ARAH_8998_004
# Add of existing embedding ID: 10794_ARAH_8998_005
# Insert of existing embedding ID: 10794_ARAH_8998_005
# Add of existing embedding ID: 10795_ARAH_8998_006
# Insert of existing embedding ID: 10795_ARAH_8998_006
# Add of existing embedding ID: 10953_ARAH_8998_008
# Insert of existing embedding ID: 10953_ARAH_8998_008
# Add of existing embedding ID: 10954_ARAH_8998_009
# Insert of existing embedding ID: 10954_ARAH_8998_009
# Add of existing embedding ID: 10955_ARAH_8998_010
# Insert of existing embedding ID: 10955_ARAH_8998_010
# Add of existing embedding ID: 10956_ARAH_8998_011
# Insert of existing embedding ID: 10956_ARAH_8998_011
# Add of existing embedding ID: 10957_ARAH_8998_012
# Insert of existing embedding ID: 10957_ARAH_8998_012
# Add of existing embedding ID: 10958_ARAH_8998_013
# Insert of existing embedding ID: 10958_ARAH_8998_013
# Add of existing embedding ID: 10959_ARAH_8998_014
# Insert of existing embedding ID: 10959_ARAH_8998_014
# Add of existing embedding ID: 11863_ARAH_8998_015
# Insert of existing embedding ID: 11863_ARAH_8998_015
# Add of existing embedding ID: 11865_ARAH_8998_017
# Insert of existing embedding ID: 11865_ARAH_8998_017
# Add of existing embedding ID: 10021_ARAH_8999_001
# Insert of existing embedding ID: 10021_ARAH_8999_001
# Add of existing embedding ID: 10781_ARAH_8999_002
# Insert of existing embedding ID: 10781_ARAH_8999_002
# Add of existing embedding ID: 10796_ARAH_8999_003
# Insert of existing embedding ID: 10796_ARAH_8999_003
# Add of existing embedding ID: 10797_ARAH_8999_004
# Insert of existing embedding ID: 10797_ARAH_8999_004
# Add of existing embedding ID: 10798_ARAH_8999_005
# Insert of existing embedding ID: 10798_ARAH_8999_005
# Add of existing embedding ID: 10960_ARAH_8999_006
# Insert of existing embedding ID: 10960_ARAH_8999_006
# Add of existing embedding ID: 10961_ARAH_8999_008
# Insert of existing embedding ID: 10961_ARAH_8999_008
# Add of existing embedding ID: 10962_ARAH_8999_009
# Insert of existing embedding ID: 10962_ARAH_8999_009
# Add of existing embedding ID: 10963_ARAH_8999_010
# Insert of existing embedding ID: 10963_ARAH_8999_010
# Add of existing embedding ID: 10964_ARAH_8999_011
# Insert of existing embedding ID: 10964_ARAH_8999_011
# Add of existing embedding ID: 10965_ARAH_8999_012
# Insert of existing embedding ID: 10965_ARAH_8999_012
# Add of existing embedding ID: 10966_ARAH_8999_013
# Insert of existing embedding ID: 10966_ARAH_8999_013
# Add of existing embedding ID: 10967_ARAH_8999_014
# Insert of existing embedding ID: 10967_ARAH_8999_014
# Add of existing embedding ID: 11068_ARAH_8999_015
# Insert of existing embedding ID: 11068_ARAH_8999_015
# Add of existing embedding ID: 11867_ARAH_8999_017
# Insert of existing embedding ID: 11867_ARAH_8999_017
# Add of existing embedding ID: 19153_ARAH_9565_001
# Insert of existing embedding ID: 19153_ARAH_9565_001
# Add of existing embedding ID: 12542_ARAH_9995_001
# Insert of existing embedding ID: 12542_ARAH_9995_001
# Add of existing embedding ID: 11868_ARAH_9998_001
# Insert of existing embedding ID: 11868_ARAH_9998_001
# Add of existing embedding ID: 11869_ARAH_9998_002
# Insert of existing embedding ID: 11869_ARAH_9998_002
# Add of existing embedding ID: 10569_ARAH_9998_003
# Insert of existing embedding ID: 10569_ARAH_9998_003
# Add of existing embedding ID: 10799_ARAH_9998_004
# Insert of existing embedding ID: 10799_ARAH_9998_004
# Add of existing embedding ID: 10800_ARAH_9998_005
# Insert of existing embedding ID: 10800_ARAH_9998_005
# Add of existing embedding ID: 11870_ARAH_9998_006
# Insert of existing embedding ID: 11870_ARAH_9998_006
# Add of existing embedding ID: 10801_ARAH_9998_008
# Insert of existing embedding ID: 10801_ARAH_9998_008
# Add of existing embedding ID: 10802_ARAH_9998_009
# Insert of existing embedding ID: 10802_ARAH_9998_009
# Add of existing embedding ID: 10968_ARAH_9998_010
# Insert of existing embedding ID: 10968_ARAH_9998_010
# Add of existing embedding ID: 10969_ARAH_9998_011
# Insert of existing embedding ID: 10969_ARAH_9998_011
# Add of existing embedding ID: 10970_ARAH_9998_012
# Insert of existing embedding ID: 10970_ARAH_9998_012
# Add of existing embedding ID: 10971_ARAH_9998_013
# Insert of existing embedding ID: 10971_ARAH_9998_013
# Add of existing embedding ID: 10972_ARAH_9998_014
# Insert of existing embedding ID: 10972_ARAH_9998_014
# Add of existing embedding ID: 10973_ARAH_9998_015
# Insert of existing embedding ID: 10973_ARAH_9998_015
# Add of existing embedding ID: 10975_ARAH_9998_017
# Insert of existing embedding ID: 10975_ARAH_9998_017
# Add of existing embedding ID: 13367_ARAH_9998_018
# Insert of existing embedding ID: 13367_ARAH_9998_018
# Add of existing embedding ID: 14206_ARAH_9998_019
# Insert of existing embedding ID: 14206_ARAH_9998_019
# Add of existing embedding ID: 10022_ARAH_9999_001
# Insert of existing embedding ID: 10022_ARAH_9999_001
# Add of existing embedding ID: 11727_ARAH_9999_002
# Insert of existing embedding ID: 11727_ARAH_9999_002
# Add of existing embedding ID: 10570_ARAH_9999_003
# Insert of existing embedding ID: 10570_ARAH_9999_003
# Add of existing embedding ID: 10571_ARAH_9999_004
# Insert of existing embedding ID: 10571_ARAH_9999_004
# Add of existing embedding ID: 10572_ARAH_9999_005
# Insert of existing embedding ID: 10572_ARAH_9999_005
# Add of existing embedding ID: 10573_ARAH_9999_006
# Insert of existing embedding ID: 10573_ARAH_9999_006
# Add of existing embedding ID: 10574_ARAH_9999_008
# Insert of existing embedding ID: 10574_ARAH_9999_008
# Add of existing embedding ID: 10575_ARAH_9999_009
# Insert of existing embedding ID: 10575_ARAH_9999_009
# Add of existing embedding ID: 10576_ARAH_9999_010
# Insert of existing embedding ID: 10576_ARAH_9999_010
# Add of existing embedding ID: 10803_ARAH_9999_011
# Insert of existing embedding ID: 10803_ARAH_9999_011
# Add of existing embedding ID: 10804_ARAH_9999_012
# Insert of existing embedding ID: 10804_ARAH_9999_012
# Add of existing embedding ID: 10805_ARAH_9999_013
# Insert of existing embedding ID: 10805_ARAH_9999_013
# Add of existing embedding ID: 10806_ARAH_9999_014
# Insert of existing embedding ID: 10806_ARAH_9999_014
# Add of existing embedding ID: 10807_ARAH_9999_015
# Insert of existing embedding ID: 10807_ARAH_9999_015
# Add of existing embedding ID: 11871_ARAH_9999_017
# Insert of existing embedding ID: 11871_ARAH_9999_017
# Add of existing embedding ID: 13368_ARAH_9999_018
# Insert of existing embedding ID: 13368_ARAH_9999_018
# Add of existing embedding ID: 14208_ARAH_9999_019
# Insert of existing embedding ID: 14208_ARAH_9999_019
# Add of existing embedding ID: 17625_ARCH_1010_100
# Insert of existing embedding ID: 17625_ARCH_1010_100
# Add of existing embedding ID: 17626_ARCH_1010_101
# Insert of existing embedding ID: 17626_ARCH_1010_101
# Add of existing embedding ID: 17627_ARCH_1010_102
# Insert of existing embedding ID: 17627_ARCH_1010_102
# Add of existing embedding ID: 17628_ARCH_1010_103
# Insert of existing embedding ID: 17628_ARCH_1010_103
# Add of existing embedding ID: 17629_ARCH_1010_104
# Insert of existing embedding ID: 17629_ARCH_1010_104
# Add of existing embedding ID: 17630_ARCH_1010_105
# Insert of existing embedding ID: 17630_ARCH_1010_105
# Add of existing embedding ID: 17631_ARCH_1010_106
# Insert of existing embedding ID: 17631_ARCH_1010_106
# Add of existing embedding ID: 17634_ARCH_1010_107
# Insert of existing embedding ID: 17634_ARCH_1010_107
# Add of existing embedding ID: 17758_ARCH_1010_108
# Insert of existing embedding ID: 17758_ARCH_1010_108
# Add of existing embedding ID: 17611_ARCH_1020_100
# Insert of existing embedding ID: 17611_ARCH_1020_100
# Add of existing embedding ID: 17612_ARCH_1020_101
# Insert of existing embedding ID: 17612_ARCH_1020_101
# Add of existing embedding ID: 17613_ARCH_1020_102
# Insert of existing embedding ID: 17613_ARCH_1020_102
# Add of existing embedding ID: 17614_ARCH_1020_103
# Insert of existing embedding ID: 17614_ARCH_1020_103
# Add of existing embedding ID: 17615_ARCH_1020_104
# Insert of existing embedding ID: 17615_ARCH_1020_104
# Add of existing embedding ID: 17616_ARCH_1020_105
# Insert of existing embedding ID: 17616_ARCH_1020_105
# Add of existing embedding ID: 17617_ARCH_1020_106
# Insert of existing embedding ID: 17617_ARCH_1020_106
# Add of existing embedding ID: 17618_ARCH_1020_107
# Insert of existing embedding ID: 17618_ARCH_1020_107
# Add of existing embedding ID: 17669_ARCH_1020_108
# Insert of existing embedding ID: 17669_ARCH_1020_108
# Add of existing embedding ID: 17610_ARCH_2010_100
# Insert of existing embedding ID: 17610_ARCH_2010_100
# Add of existing embedding ID: 20150_ARCH_2150_001
# Insert of existing embedding ID: 20150_ARCH_2150_001
# Add of existing embedding ID: 17600_ARCH_2710_100
# Insert of existing embedding ID: 17600_ARCH_2710_100
# Add of existing embedding ID: 17601_ARCH_2710_101
# Insert of existing embedding ID: 17601_ARCH_2710_101
# Add of existing embedding ID: 17602_ARCH_2710_102
# Insert of existing embedding ID: 17602_ARCH_2710_102
# Add of existing embedding ID: 17603_ARCH_2710_103
# Insert of existing embedding ID: 17603_ARCH_2710_103
# Add of existing embedding ID: 17582_ARCH_3010_001
# Insert of existing embedding ID: 17582_ARCH_3010_001
# Add of existing embedding ID: 17753_ARCH_3240_100
# Insert of existing embedding ID: 17753_ARCH_3240_100
# Add of existing embedding ID: 17754_ARCH_3240_101
# Insert of existing embedding ID: 17754_ARCH_3240_101
# Add of existing embedding ID: 17755_ARCH_3240_102
# Insert of existing embedding ID: 17755_ARCH_3240_102
# Add of existing embedding ID: 17756_ARCH_3240_103
# Insert of existing embedding ID: 17756_ARCH_3240_103
# Add of existing embedding ID: 17593_ARCH_4010_001
# Insert of existing embedding ID: 17593_ARCH_4010_001
# Add of existing embedding ID: 17632_ARCH_4100_001
# Insert of existing embedding ID: 17632_ARCH_4100_001
# Add of existing embedding ID: 17596_ARCH_4993_001
# Insert of existing embedding ID: 17596_ARCH_4993_001
# Add of existing embedding ID: 19787_ARCH_5342_001
# Insert of existing embedding ID: 19787_ARCH_5342_001
# Add of existing embedding ID: 17727_ARCH_5420_001
# Insert of existing embedding ID: 17727_ARCH_5420_001
# Add of existing embedding ID: 17743_ARCH_5500_001
# Insert of existing embedding ID: 17743_ARCH_5500_001
# Add of existing embedding ID: 20191_ARCH_5500_002
# Insert of existing embedding ID: 20191_ARCH_5500_002
# Add of existing embedding ID: 20192_ARCH_5500_003
# Insert of existing embedding ID: 20192_ARCH_5500_003
# Add of existing embedding ID: 17745_ARCH_5614_001
# Insert of existing embedding ID: 17745_ARCH_5614_001
# Add of existing embedding ID: 17583_ARCH_5993_001
# Insert of existing embedding ID: 17583_ARCH_5993_001
# Add of existing embedding ID: 17591_ARCH_6010_001
# Insert of existing embedding ID: 17591_ARCH_6010_001
# Add of existing embedding ID: 17717_ARCH_6010_002
# Insert of existing embedding ID: 17717_ARCH_6010_002
# Add of existing embedding ID: 20152_ARCH_6011_001
# Insert of existing embedding ID: 20152_ARCH_6011_001
# Add of existing embedding ID: 20308_ARCH_6101_001
# Insert of existing embedding ID: 20308_ARCH_6101_001
# Add of existing embedding ID: 20153_ARCH_6711_001
# Insert of existing embedding ID: 20153_ARCH_6711_001
# Add of existing embedding ID: 17641_ARCH_7010_001
# Insert of existing embedding ID: 17641_ARCH_7010_001
# Add of existing embedding ID: 17645_ARCH_7120_001
# Insert of existing embedding ID: 17645_ARCH_7120_001
# Add of existing embedding ID: 17644_ARCH_7240_100
# Insert of existing embedding ID: 17644_ARCH_7240_100
# Add of existing embedding ID: 17647_ARCH_7240_101
# Insert of existing embedding ID: 17647_ARCH_7240_101
# Add of existing embedding ID: 17739_ARCH_7240_102
# Insert of existing embedding ID: 17739_ARCH_7240_102
# Add of existing embedding ID: 17640_ARCH_7250_001
# Insert of existing embedding ID: 17640_ARCH_7250_001
# Add of existing embedding ID: 17597_ARCH_7993_001
# Insert of existing embedding ID: 17597_ARCH_7993_001
# Add of existing embedding ID: 11746_ARCY_3993_001
# Insert of existing embedding ID: 11746_ARCY_3993_001
# Add of existing embedding ID: 12405_ARCY_3993_002
# Insert of existing embedding ID: 12405_ARCY_3993_002
# Add of existing embedding ID: 12806_ARCY_3993_003
# Insert of existing embedding ID: 12806_ARCY_3993_003
# Add of existing embedding ID: 11536_ARCY_4998_001
# Insert of existing embedding ID: 11536_ARCY_4998_001
# Add of existing embedding ID: 11537_ARCY_4998_002
# Insert of existing embedding ID: 11537_ARCY_4998_002
# Add of existing embedding ID: 11692_ARCY_4998_003
# Insert of existing embedding ID: 11692_ARCY_4998_003
# Add of existing embedding ID: 14344_ARCY_4998_004
# Insert of existing embedding ID: 14344_ARCY_4998_004
# Add of existing embedding ID: 11697_ARCY_4998_005
# Insert of existing embedding ID: 11697_ARCY_4998_005
# Add of existing embedding ID: 17571_ARH_1010_100
# Insert of existing embedding ID: 17571_ARH_1010_100
# Add of existing embedding ID: 17577_ARH_1010_101
# Insert of existing embedding ID: 17577_ARH_1010_101
# Add of existing embedding ID: 17572_ARH_1010_102
# Insert of existing embedding ID: 17572_ARH_1010_102
# Add of existing embedding ID: 17575_ARH_1010_103
# Insert of existing embedding ID: 17575_ARH_1010_103
# Add of existing embedding ID: 17576_ARH_1010_104
# Insert of existing embedding ID: 17576_ARH_1010_104
# Add of existing embedding ID: 17573_ARH_1010_105
# Insert of existing embedding ID: 17573_ARH_1010_105
# Add of existing embedding ID: 17574_ARH_1010_106
# Insert of existing embedding ID: 17574_ARH_1010_106
# Add of existing embedding ID: 17578_ARH_1010_107
# Insert of existing embedding ID: 17578_ARH_1010_107
# Add of existing embedding ID: 17734_ARH_1010_108
# Insert of existing embedding ID: 17734_ARH_1010_108
# Add of existing embedding ID: 17579_ARH_1010_109
# Insert of existing embedding ID: 17579_ARH_1010_109
# Add of existing embedding ID: 17789_ARH_3500_001
# Insert of existing embedding ID: 17789_ARH_3500_001
# Add of existing embedding ID: 19784_ARH_3500_002
# Insert of existing embedding ID: 19784_ARH_3500_002
# Add of existing embedding ID: 17809_ARH_3608_001
# Insert of existing embedding ID: 17809_ARH_3608_001
# Add of existing embedding ID: 17724_ARH_3618_001
# Insert of existing embedding ID: 17724_ARH_3618_001
# Add of existing embedding ID: 19785_ARH_3701_001
# Insert of existing embedding ID: 19785_ARH_3701_001
# Add of existing embedding ID: 17784_ARH_4993_001
# Insert of existing embedding ID: 17784_ARH_4993_001
# Add of existing embedding ID: 17580_ARH_4999_001
# Insert of existing embedding ID: 17580_ARH_4999_001
# Add of existing embedding ID: 17675_ARH_4999_002
# Insert of existing embedding ID: 17675_ARH_4999_002
# Add of existing embedding ID: 17677_ARH_4999_003
# Insert of existing embedding ID: 17677_ARH_4999_003
# Add of existing embedding ID: 17723_ARH_4999_004
# Insert of existing embedding ID: 17723_ARH_4999_004
# Add of existing embedding ID: 17759_ARH_4999_005
# Insert of existing embedding ID: 17759_ARH_4999_005
# ...
# Insert of existing embedding ID: 18195_GBUS_8999_043
# Add of existing embedding ID: 18196_GBUS_8999_044
# Insert of existing embedding ID: 18196_GBUS_8999_044
# Add of existing embedding ID: 18197_GBUS_8999_045
# Insert of existing embedding ID: 18197_GBUS_8999_045
# Add of existing embedding ID: 18171_GBUS_9854_001
# Insert of existing embedding ID: 18171_GBUS_9854_001
# Add of existing embedding ID: 18172_GBUS_9861_001
# Insert of existing embedding ID: 18172_GBUS_9861_001
# Add of existing embedding ID: 18174_GBUS_9865_001
# Insert of existing embedding ID: 18174_GBUS_9865_001
# Add of existing embedding ID: 18175_GBUS_9867_001
# Insert of existing embedding ID: 18175_GBUS_9867_001
# Add of existing embedding ID: 18061_GBUS_9999_001
# Insert of existing embedding ID: 18061_GBUS_9999_001
# Add of existing embedding ID: 12216_GCCS_3010_001
# Insert of existing embedding ID: 12216_GCCS_3010_001
# Add of existing embedding ID: 19719_GCCS_3100_001
# Insert of existing embedding ID: 19719_GCCS_3100_001
# Add of existing embedding ID: 17354_GCNL_5020_001
# Insert of existing embedding ID: 17354_GCNL_5020_001
# Add of existing embedding ID: 17311_GCNL_5110_001
# Insert of existing embedding ID: 17311_GCNL_5110_001
# Add of existing embedding ID: 17334_GCNL_5110_100
# Insert of existing embedding ID: 17334_GCNL_5110_100
# Add of existing embedding ID: 17332_GCNL_5110_101
# Insert of existing embedding ID: 17332_GCNL_5110_101
# Add of existing embedding ID: 17333_GCNL_5110_102
# Insert of existing embedding ID: 17333_GCNL_5110_102
# Add of existing embedding ID: 17344_GCNL_5110_103
# Insert of existing embedding ID: 17344_GCNL_5110_103
# Add of existing embedding ID: 17346_GCNL_5110_104
# Insert of existing embedding ID: 17346_GCNL_5110_104
# Add of existing embedding ID: 17395_GCNL_5110_105
# Insert of existing embedding ID: 17395_GCNL_5110_105
# Add of existing embedding ID: 17462_GCNL_5110_106
# Insert of existing embedding ID: 17462_GCNL_5110_106
# Add of existing embedding ID: 20254_GCNL_5110_107
# Insert of existing embedding ID: 20254_GCNL_5110_107
# Add of existing embedding ID: 20255_GCNL_5110_108
# Insert of existing embedding ID: 20255_GCNL_5110_108
# Add of existing embedding ID: 17312_GCNL_5160_001
# Insert of existing embedding ID: 17312_GCNL_5160_001
# Add of existing embedding ID: 17342_GCNL_5160_100
# Insert of existing embedding ID: 17342_GCNL_5160_100
# Add of existing embedding ID: 17340_GCNL_5160_102
# Insert of existing embedding ID: 17340_GCNL_5160_102
# Add of existing embedding ID: 17341_GCNL_5160_103
# Insert of existing embedding ID: 17341_GCNL_5160_103
# Add of existing embedding ID: 17396_GCNL_5160_104
# Insert of existing embedding ID: 17396_GCNL_5160_104
# Add of existing embedding ID: 17463_GCNL_5160_105
# Insert of existing embedding ID: 17463_GCNL_5160_105
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[23], line 3
#       1 #store classes in collection
#       2 for course in classes_dict:
# ----> 3     embedding = model.encode(course["Description"]).tolist()  # Convert to list for ChromaDB
#       4     collection_classes.add(
#       5         ids=[f"{course['ClassNumber']}_{course['Mnemonic']}_{course['Number']}_{course['Section']}"],
#       6         embeddings=[embedding],
#    (...)
#      22         }]
#      23     )
#      25 print("Classes data stored in ChromaDB!")
#
# File ~/miniconda3/lib/python3.12/site-packages/sentence_transformers/SentenceTransformer.py:371, in SentenceTransformer.encode(self, sentences, prompt_name, prompt, batch_size, show_progress_bar, output_value, precision, convert_to_numpy, convert_to_tensor, device, normalize_embeddings)
#     368 features.update(extra_features)
#     370 with torch.no_grad():
# --> 371     out_features = self.forward(features)
#     372     out_features["sentence_embedding"] = truncate_embeddings(
#     373         out_features["sentence_embedding"], self.truncate_dim
#     374     )
#     376     if output_value == "token_embeddings":
#
# File ~/miniconda3/lib/python3.12/site-packages/torch/nn/modules/container.py:250, in Sequential.forward(self, input)
#     248 def forward(self, input):
#     249     for module in self:
# --> 250         input = module(input)
#     251     return input
#
# File ~/miniconda3/lib/python3.12/site-packages/torch/nn/modules/module.py:1739, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1737     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1738 else:
# -> 1739     return self._call_impl(*args, **kwargs)
#
# File ~/miniconda3/lib/python3.12/site-packages/torch/nn/modules/module.py:1750, in Module._call_impl(self, *args, **kwargs)
#    1745 # If we don't have any hooks, we want to skip the rest of the logic in
#    1746 # this function, and just call forward.
#    1747 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1748         or _global_backward_pre_hooks or _global_backward_hooks
#    1749         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1750     return forward_call(*args, **kwargs)
#    1752 result = None
#    1753 called_always_called_hooks = set()
#
# File ~/miniconda3/lib/python3.12/site-packages/sentence_transformers/models/Transformer.py:98, in Transformer.forward(self, features)
#      95 if "token_type_ids" in features:
#      96     trans_features["token_type_ids"] = features["token_type_ids"]
# ---> 98 output_states = self.auto_model(**trans_features, return_dict=False)
#      99 output_tokens = output_states[0]
#     101 features.update({"token_embeddings": output_tokens, "attention_mask": features["attention_mask"]})
#
# File ~/miniconda3/lib/python3.12/site-packages/torch/nn/modules/module.py:1739, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1737     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1738 else:
# -> 1739     return self._call_impl(*args, **kwargs)
#
# File ~/miniconda3/lib/python3.12/site-packages/torch/nn/modules/module.py:1750, in Module._call_impl(self, *args, **kwargs)
#    1745 # If we don't have any hooks, we want to skip the rest of the logic in
#    1746 # this function, and just call forward.
#    1747 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1748         or _global_backward_pre_hooks or _global_backward_hooks
#    1749         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1750     return forward_call(*args, **kwargs)
#    1752 result = None
#    1753 called_always_called_hooks = set()
#
# File ~/miniconda3/lib/python3.12/site-packages/transformers/models/bert/modeling_bert.py:1142, in BertModel.forward(self, input_ids, attention_mask, token_type_ids, position_ids, head_mask, inputs_embeds, encoder_hidden_states, encoder_attention_mask, past_key_values, use_cache, output_attentions, output_hidden_states, return_dict)
#    1135 # Prepare head mask if needed
#    1136 # 1.0 in head_mask indicate we keep the head
#    1137 # attention_probs has shape bsz x n_heads x N x N
#    1138 # input head_mask has shape [num_heads] or [num_hidden_layers x num_heads]
#    1139 # and head_mask is converted to shape [num_hidden_layers x batch x num_heads x seq_length x seq_length]
#    1140 head_mask = self.get_head_mask(head_mask, self.config.num_hidden_layers)
# -> 1142 encoder_outputs = self.encoder(
#    1143     embedding_output,
#    1144     attention_mask=extended_attention_mask,
#    1145     head_mask=head_mask,
#    1146     encoder_hidden_states=encoder_hidden_states,
#    1147     encoder_attention_mask=encoder_extended_attention_mask,
#    1148     past_key_values=past_key_values,
#    1149     use_cache=use_cache,
#    1150     output_attentions=output_attentions,
#    1151     output_hidden_states=output_hidden_states,
#    1152     return_dict=return_dict,
#    1153 )
#    1154 sequence_output = encoder_outputs[0]
#    1155 pooled_output = self.pooler(sequence_output) if self.pooler is not None else None
#
# File ~/miniconda3/lib/python3.12/site-packages/torch/nn/modules/module.py:1739, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1737     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1738 else:
# -> 1739     return self._call_impl(*args, **kwargs)
#
# File ~/miniconda3/lib/python3.12/site-packages/torch/nn/modules/module.py:1750, in Module._call_impl(self, *args, **kwargs)
#    1745 # If we don't have any hooks, we want to skip the rest of the logic in
#    1746 # this function, and just call forward.
#    1747 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1748         or _global_backward_pre_hooks or _global_backward_hooks
#    1749         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1750     return forward_call(*args, **kwargs)
#    1752 result = None
#    1753 called_always_called_hooks = set()
#
# File ~/miniconda3/lib/python3.12/site-packages/transformers/models/bert/modeling_bert.py:695, in BertEncoder.forward(self, hidden_states, attention_mask, head_mask, encoder_hidden_states, encoder_attention_mask, past_key_values, use_cache, output_attentions, output_hidden_states, return_dict)
#     684     layer_outputs = self._gradient_checkpointing_func(
#     685         layer_module.__call__,
#     686         hidden_states,
#    (...)
#     692         output_attentions,
#     693     )
#     694 else:
# --> 695     layer_outputs = layer_module(
#     696         hidden_states,
#     697         attention_mask,
#     698         layer_head_mask,
#     699         encoder_hidden_states,
#     700         encoder_attention_mask,
#     701         past_key_value,
#     702         output_attentions,
#     703     )
#     705 hidden_states = layer_outputs[0]
#     706 if use_cache:
#
# File ~/miniconda3/lib/python3.12/site-packages/torch/nn/modules/module.py:1739, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1737     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1738 else:
# -> 1739     return self._call_impl(*args, **kwargs)
#
# File ~/miniconda3/lib/python3.12/site-packages/torch/nn/modules/module.py:1750, in Module._call_impl(self, *args, **kwargs)
#    1745 # If we don't have any hooks, we want to skip the rest of the logic in
#    1746 # this function, and just call forward.
#    1747 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1748         or _global_backward_pre_hooks or _global_backward_hooks
#    1749         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1750     return forward_call(*args, **kwargs)
#    1752 result = None
#    1753 called_always_called_hooks = set()
#
# File ~/miniconda3/lib/python3.12/site-packages/transformers/models/bert/modeling_bert.py:585, in BertLayer.forward(self, hidden_states, attention_mask, head_mask, encoder_hidden_states, encoder_attention_mask, past_key_value, output_attentions)
#     573 def forward(
#     574     self,
#     575     hidden_states: torch.Tensor,
#    (...)
#     582 ) -> Tuple[torch.Tensor]:
#     583     # decoder uni-directional self-attention cached key/values tuple is at positions 1,2
#     584     self_attn_past_key_value = past_key_value[:2] if past_key_value is not None else None
# --> 585     self_attention_outputs = self.attention(
#     586         hidden_states,
#     587         attention_mask,
#     588         head_mask,
#     589         output_attentions=output_attentions,
#     590         past_key_value=self_attn_past_key_value,
#     591     )
#     592     attention_output = self_attention_outputs[0]
#     594     # if decoder, the last output is tuple of self-attn cache
#
# File ~/miniconda3/lib/python3.12/site-packages/torch/nn/modules/module.py:1739, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1737     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1738 else:
# -> 1739     return self._call_impl(*args, **kwargs)
#
# File ~/miniconda3/lib/python3.12/site-packages/torch/nn/modules/module.py:1750, in Module._call_impl(self, *args, **kwargs)
#    1745 # If we don't have any hooks, we want to skip the rest of the logic in
#    1746 # this function, and just call forward.
#    1747 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1748         or _global_backward_pre_hooks or _global_backward_hooks
#    1749         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1750     return forward_call(*args, **kwargs)
#    1752 result = None
#    1753 called_always_called_hooks = set()
#
# File ~/miniconda3/lib/python3.12/site-packages/transformers/models/bert/modeling_bert.py:515, in BertAttention.forward(self, hidden_states, attention_mask, head_mask, encoder_hidden_states, encoder_attention_mask, past_key_value, output_attentions)
#     505 def forward(
#     506     self,
#     507     hidden_states: torch.Tensor,
#    (...)
#     513     output_attentions: Optional[bool] = False,
#     514 ) -> Tuple[torch.Tensor]:
# --> 515     self_outputs = self.self(
#     516         hidden_states,
#     517         attention_mask,
#     518         head_mask,
#     519         encoder_hidden_states,
#     520         encoder_attention_mask,
#     521         past_key_value,
#     522         output_attentions,
#     523     )
#     524     attention_output = self.output(self_outputs[0], hidden_states)
#     525     outputs = (attention_output,) + self_outputs[1:]  # add attentions if we output them
#
# File ~/miniconda3/lib/python3.12/site-packages/torch/nn/modules/module.py:1739, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1737     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1738 else:
# -> 1739     return self._call_impl(*args, **kwargs)
#
# File ~/miniconda3/lib/python3.12/site-packages/torch/nn/modules/module.py:1750, in Module._call_impl(self, *args, **kwargs)
#    1745 # If we don't have any hooks, we want to skip the rest of the logic in
#    1746 # this function, and just call forward.
#    1747 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1748         or _global_backward_pre_hooks or _global_backward_hooks
#    1749         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1750     return forward_call(*args, **kwargs)
#    1752 result = None
#    1753 called_always_called_hooks = set()
#
# File ~/miniconda3/lib/python3.12/site-packages/transformers/models/bert/modeling_bert.py:409, in BertSdpaSelfAttention.forward(self, hidden_states, attention_mask, head_mask, encoder_hidden_states, encoder_attention_mask, past_key_value, output_attentions)
#     407 else:
#     408     key_layer = self.transpose_for_scores(self.key(current_states))
# --> 409     value_layer = self.transpose_for_scores(self.value(current_states))
#     410     if past_key_value is not None and not is_cross_attention:
#     411         key_layer = torch.cat([past_key_value[0], key_layer], dim=2)
#
# File ~/miniconda3/lib/python3.12/site-packages/torch/nn/modules/module.py:1739, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1737     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1738 else:
# -> 1739     return self._call_impl(*args, **kwargs)
#
# File ~/miniconda3/lib/python3.12/site-packages/torch/nn/modules/module.py:1750, in Module._call_impl(self, *args, **kwargs)
#    1745 # If we don't have any hooks, we want to skip the rest of the logic in
#    1746 # this function, and just call forward.
#    1747 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1748         or _global_backward_pre_hooks or _global_backward_hooks
#    1749         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1750     return forward_call(*args, **kwargs)
#    1752 result = None
#    1753 called_always_called_hooks = set()
#
# File ~/miniconda3/lib/python3.12/site-packages/torch/nn/modules/linear.py:125, in Linear.forward(self, input)
#     124 def forward(self, input: Tensor) -> Tensor:
# --> 125     return F.linear(input, self.weight, self.bias)
#
# KeyboardInterrupt:

# %% [markdown]
# # Retrieval

# %%
# function for document retrieval
#user can input the number of major documents and number of school documents they want to retrieve
def retrieve_major_and_school_info(query, k_m=10, k_s = 2):
    # Step 1: Retrieve major-related chunks
    query_embedding = model.encode(query).tolist()

    results = collection.query(
        query_embeddings=[query_embedding],
        n_results=k_m
    )

    # Step 2: Extract major-specific results and school information
    major_info = []
    for i in range(len(results["ids"][0])):
        metadata = results["metadatas"][0][i]
        # If the metadata has 'major_name', this is a major document
        if metadata.get("Major"):
            major_info.append(metadata)

    # Step 3: Extract the school name from the major info
    schools_to_query = set([info["School"] for info in major_info])

    # Step 4: Retrieve relevant school descriptions based on the inferred school name
    school_info = []
    for school_name in schools_to_query:
        school_results = collection.query(
            query_embeddings=[query_embedding],
            where={"School": school_name},
            n_results=k_s
        )
        school_info.extend(school_results["metadatas"][0])

    return major_info, school_info

# %%
# Example search for "computer science"
query = "course schedule for computer science major"
major_info, school_info = retrieve_major_and_school_info(query, 10, 5)

# %%
major_info
# Out:
# [{'Major': 'Computer Science, B.S.',
#   'School': 'School of Engineering and Applied Science',
#   'Text': 'The 2000 level courses should be taken before the 3000 level courses and note that there are other prerequisites that govern the order that these courses should be taken. Example schedules can be found on the Computer Science Department webpage . CS 2100\xa0-\xa0Data Structures and Algorithms 1 Credits: 4 CS 2120\xa0-\xa0Discrete Mathematics and Theory 1 Credits: 3 CS 2130\xa0-\xa0Computer Systems and Organization 1 Credits: 4 CS 3100\xa0-\xa0Data Structures and Algorithms 2 Credits:          3 CS 3120\xa0-\xa0Discrete Mathematics and Theory 2 Credits: 3 CS 3130\xa0-\xa0Computer Systems and Organization 2 Credits: 4 CS 3140\xa0-\xa0Software Development Essentials Credits: 3 Upper-Level Required Courses BSCS majors must take one upper-level course in software engineering and one course to complete the SEAS senior thesis. CS 3240\xa0-\xa0Software Engineering Credits:          3 The senior thesis should be taken during the student’s last year and consists of the STS 4500/4600 sequence (see the General Requirements listed above) together with one of the following options: CS 4980\xa0-\xa0Capstone Research Credits: 1 to 3 CS 4991\xa0-\xa0Capstone Technical Report Credits: 0 AND a three-credit, graded CS 4000 course not used to fulfill any other CS degree requirement. Computer Science Electives BSCS majors must take fifteen (15) credits of CS courses at the 3000 level or higher. Courses from other disciplines will only be accepted under rare circumstances and by approval of the CS Undergraduate Curriculum Committee. Guidelines for CS Electives: Must have a CS mnemonic. Must be at the 3000 level or higher. Must not be a foundation course or upper-level required course. Second digit of course number must not be 0 or 9, except as noted below. Two electives with significant overlap of material cannot both count toward the CS degree. Up to three (3) credits of CS 4993 - Independent Study may count toward the CS elective requirement. Credits beyond this limit may be applied to the unrestricted elective requirement. Applied Mathematics Electives BSCS majors must take three (3) additional courses in Applied Mathematics beyond the SEAS General Requirements. Equivalent courses from the Department of Mathematics may be substituted for matching APMA courses.',
#   'chunk_index': 2},
#  {'Major': 'Computer Science, B.A.',
#   'School': 'College of Arts and Sciences',
#   'Text': 'Transfer students who have not completed courses equivalent to the degree’s pre-requisites described below before their first semester in residence cannot be accepted into the major until those are completed. We strongly recommend that students transferring to the University as third-years complete the equivalent of CS 2100 before coming to UVA. Due to prerequisite dependencies, it is difficult for students who do\xa0not complete\xa0CS 2100 or its equivalent by the end of their fifth semester to complete the BA in CS in the three remaining semesters. Prerequisites: 7 credit hours Introduction to Computer Science: Complete one of the following courses with a grade of C+ or higher: CS 1110\xa0-\xa0Introduction to Programming Credits:          3 CS 1111\xa0-\xa0Introduction to Programming Credits:          3 CS 1113\xa0-\xa0Introduction to Programming Credits:          3 CS 1120\xa0-\xa0Introduction to Computing: Explorations in Language, Logic, and Machines Credits: 3 And also complete\xa0the following with a grade of C+ or higher: CS 2100\xa0-\xa0Data Structures and Algorithms 1 Credits: 4 Program Requirements Required Courses: 20 credit hours CS 2120\xa0-\xa0Discrete Mathematics and Theory 1 Credits: 3 CS 2130\xa0-\xa0Computer Systems and Organization 1 Credits: 4 CS 3100\xa0-\xa0Data Structures and Algorithms 2 Credits:          3 CS 3120\xa0-\xa0Discrete Mathematics and Theory 2 Credits: 3 CS 3130\xa0-\xa0Computer Systems and Organization 2 Credits: 4 CS 3140\xa0-\xa0Software Development Essentials Credits: 3 Restricted Electives: 9 credit hours Students will select three courses from the following prescribed list. Note that at most three (3) credits of CS 4993, Independent Study, may count toward the CS restricted elective requirement.',
#   'chunk_index': 1},
#  {'Major': 'Computer Science, B.A.',
#   'School': 'College of Arts and Sciences',
#   'Text': 'degree requirements as well as a fourth year thesis project. For the thesis project, a student must enroll in the following course\xa0for two semesters. CS 4998\xa0-\xa0Distinguished BA Majors Research Credits: 3 The thesis project must be\xa0approved by two advisors, typically one from Computer Science and one from a department in the College of Arts and Sciences. Both advisors must approve the student’s plan of study, thesis proposal, and thesis report. The research project will require students to demonstrate a high level of innovative, independent research and analysis. Upon completion of the research paper, the faculty advisors will assign the work one of the following awards: Highest Distinction, High Distinction, Distinction. Additional Information For more information about the major of the Department of Computer Science,\xa0please see our website at http://www.cs.virginia.edu/ or call the CS office at 434-982-2200. Back to Top | Print-Friendly Page (opens a new window) All catalogs © 2025 University of Virginia. Powered by Modern Campus Catalog™ .',
#   'chunk_index': 5},
#  {'Major': 'Computer Science, B.A.',
#   'School': 'College of Arts and Sciences',
#   'Text': 'Computer Science, B.A. Print-Friendly Page (opens a new window) Return to: College of Arts & Sciences: Degree Programs The BA degree program in Computer Science\xa0provides students with a solid foundation in computer science theory and practice. An important goal of the program is give students the ability to apply computing to other disciplines in the arts and sciences (e.g., life and physical sciences, mathematics, social sciences, visual and performing arts). This idea of studying computer science in the context of a liberal arts education is what distinguishes the BA in Computer Science from computing degrees in the School of Engineering and Applied Sciences. Graduates of this program will be prepared to apply their technical knowledge to analyze and solve computing challenges in a wide range of problem areas, including those faced by today’s computing industry. Graduates will also be prepared for graduate study in computer science and other fields that require knowledge of computer science. Universal Curriculum Requirements To be awarded a degree from the (Add school name), students are required to complete universal curriculum requirements in addition to the program requirements provided below. The school universal curriculum requirements can be found on the school Degree Programs page . Declaring the Major and Application Process Students must have successfully completed the pre-requisites described below in order to declare the major. Due to prerequisite dependencies, it is difficult for students who have not completed CS 2100 by the end of their fifth semester\xa0to complete the major in their three remaining semesters. Ability to complete the degree in a timely manner is a factor in acceptance into the major. Second Majors: Because the goals of the degree are integrated with the study of the liberal arts, students from outside the College of Arts and Sciences who have not taken significant coursework in the College will not be allowed to declare the\xa0BA in CS degree as a second major. Students enrolled in the School of Engineernig and Applied Science are not allowed to declare the BACS as a second major. Transfer Students from Outside the University: Students transferring into the University from other institutions must apply to the department to be allowed to declare the BA in CS major. This should take place during the summer before a transfer student begins classes, and the overall process will be discussed during the summer orientation session. If an incoming transfer does not attend summer orientation, they must meet with a CS advisor before classes begin to discuss their request. Transfer students who start in the spring semester should contact the department when they begin to register for courses.',
#   'chunk_index': 0},
#  {'Major': 'Computer Science, B.S.',
#   'School': 'School of Engineering and Applied Science',
#   'Text': 'See the SEAS page regarding electives for more information. Additional Information For more information about the major or the Computer Science department, please see our website at http://www.cs.virginia.edu or call the CS office at 434.982.2200. Back to Top | Print-Friendly Page (opens a new window) All catalogs © 2025 University of Virginia. Powered by Modern Campus Catalog™ .',
#   'chunk_index': 4},
#  {'Major': 'Computer Science, B.S.',
#   'School': 'School of Engineering and Applied Science',
#   'Text': 'Computer Science B.S. Print-Friendly Page (opens a new window) Return to: School of Engineering and Applied Science: Degree Programs Accreditation The Bachelor of Science degree in Computer Science is accredited by the Computing Accreditation Commission of ABET - https://www.abet.org . Program Objectives Graduates of the Bachelor of Science in Computer Science program: Have the knowledge and skills that allow them to make tangible contributions in their profession. Have the knowledge and skills that allow them meet new technical challenges. Are\xa0able to contribute effectively to society. Are\xa0able to work effectively as team leaders and members. Have the ability to be innovators in the design, analysis and application of computer systems. GPA Requirement BSCS majors must have a 2.0 GPA average for CS courses in order to graduate. For courses that must be repeated due to a failing grade or not obtaining the needed grade as a prerequisite for a later course, all grades (including the original grade) count toward the CS GPA. Degree Requirements All students completing the Bachelor of Science degree in Computer Science must fulfill the following requirements. School of Engineering and Applied Science General Requirements BSCS students must complete the unified set of general requirements for all engineering majors. More information can be found on the SEAS Academic Rules\xa0page. These courses are often completed during the first two years in SEAS, with the exception of STS 4500 and 4600, which are taken during the fall and spring of the fourth year, respectively.',
#   'chunk_index': 0},
#  {'Major': 'Bachelor of Interdisciplinary Studies, B.I.S.',
#   'School': 'School of Continuing and Professional Studies',
#   'Text': 'The required Information Technology courses are: IT 3220 - Strategic Business Value of Information Technology IT 3230 - Basics of Web Design IT 3240 - Enterprise Systems Architecture & Design IT 3400 - Database Management & Business Intelligence/Analytics IT 4400 - Web Application Development - Building Dynamic Websites Elective IT Courses (3 credits) IT 3210 - Programming with Java IT 3350 - Agile Project Management IT 3600 - Data Analytics & Decision-Making SEC 3010 - Securing the Cyber World Degree Elective Courses (24-48 credits) Students in the IT concentration are also required to take twenty-four to forty-eight\xa0approved credit hours of degree electives outside of IT courses. These vary by semester and may include courses in disciplines such as anthropology, art, art history, architectural history, classics, drama, economics, history, literature, music, philosophy, politics, religion, and sociology. A minimum of nine credits of degree electives at the University must be in upper-division humanities/social sciences (e.g., 3000/4000 level ISSS or ISHU courses or approved courses from the College of Arts & Sciences). Capstone Project I (3 credits) The Capstone Project is the culminating activity of the B.I.S. Program in which students pursue independent research into a topic of their choice, based on their academic, or professional, or personal interests or some combination of these, and write a substantial paper that reflects a deep understanding of the topic. Students will present their research to an audience of faculty, students, and others at the end of the semester. This required course provides students an opportunity to strengthen their critical thinking, research, and communication skills while exploring the process of research and project design. Students will apply what they learn to develop a thoughtful proposal for their Information Technology Capstone Project. Before registering for Capstone Project I - ISCP 3991, the student must have successfully completed the Liberal Studies Seminars requirements, have completed at least 105 credits toward the B.I.S. degree, including most of the concentration courses, have removed all incompletes, and be in good academic standing, that is, not be on academic warning. Students also must have attended the Capstone information session and filed the Intent to Take Capstone Project I Form at least two months prior to the start of class.',
#   'chunk_index': 29},
#  {'Major': 'Data Science, B.S.',
#   'School': 'School of Data Science',
#   'Text': 'DS 1001\xa0-\xa0Foundation of Data Science Credits:          3 Programming Requirement There are multiple ways this requirement can be met. Enrollment in one of the following courses at UVA: DS 1002\xa0-\xa0Programming for Data Science Credits:          3 CS 1110\xa0-\xa0Introduction to Programming Credits:          3 CS 1111\xa0-\xa0Introduction to Programming Credits:          3 CS 1112\xa0-\xa0Introduction to Programming Credits:          3 CS 1113\xa0-\xa0Introduction to Programming Credits:          3 PHYS 1655\xa0-\xa0Introduction to Python for Scientists and Engineers Credits: 3 OR Test credit AP Computer Science A with a score if 4 or 5 IB HL Computer Science with a score of 5, 6, or 7 OR Passing the CS 1110 Place-Out Test Students who pass the test\xa0receive a notation in SIS. The School of Data Science encourages students to complete the place-out test in Python. Students must be proficient in Python prior to the start of classes. Program Requirements CREDIT/GPA MINIMUMS Number of DS Course Credits required: 49 Number of Credits required to be taken at UVA: 60 Minimum CUM GPA to graduate: 2.00 Total Credits required: 120 credits Core Curriculum (40 credits) Due to course sequencing and availability, students may not withdraw\xa0from a core course. Students must take courses for a letter grade and achieve a grade of D or better.',
#   'chunk_index': 1},
#  {'Major': 'Cognitive Science',
#   'School': 'College of Arts and Sciences',
#   'Text': 'CS 1501 courses are CR/NC grading which within the College of Arts and Sciences means they cannot be used to fulfill major credit hours. CS 3501 and 4501 Special Topics courses should only be taken for 3 credit hours if majors hope to fulfill one or both of the COGS concentration with these classes. ECE 2066 counts for credit but does not fill the CS area requirement. The list below is not comprehensive but does include courses\xa0typically taken by majors.',
#   'chunk_index': 3},
#  {'Major': 'Bachelor of Interdisciplinary Studies, B.I.S.',
#   'School': 'School of Continuing and Professional Studies',
#   'Text': 'The required courses are: SEC 3010:\xa0 Securing the Cyber World SEC 3020:\xa0 Cybersecurity Policy, Law\xa0and\xa0Ethics SEC 3030:\xa0 Human Factors in Cybersecurity SEC 3040:\xa0 Writing and Communications in a Technical Field Students will complete two elective courses in Cybersecurity Analysis from the following: SEC 4010:\xa0 Digital Forensics and Cybercrime SEC 4020:\xa0 Mobile Security and Forensics SEC 4030:\xa0\xa0Ethical Hacking IT 3500: Data Analytics and Decision-Making Degree Elective Courses (24-48 credits) Students will complete twenty-four to forty-eight approved elective credit hours to complete the 120 hours required for graduation. Elective courses can include those other than from the list of approved Cybersecurity Analysis concentration courses. A minimum of nine credits of degree electives at the University must be in upper-division humanities/social sciences (e.g., 3000/4000 level ISSS or ISHU courses or approved courses from the College of Arts & Sciences). Capstone Project I (3 credits) The Capstone Project is the culminating activity of the B.I.S. Program in which students pursue independent research into a topic of their choice, based on their academic, or professional, or personal interests or some combination of these, and write a substantial paper that reflects a deep understanding of the topic. Students will present their research to an audience of faculty, students, and others at the end of the semester. This required course provides students an opportunity to strengthen their critical thinking, research, and communication skills while exploring the process of research and project design. Students will apply what they learn to develop a thoughtful proposal for their individual Capstone Projects. Before registering for Capstone Project I - ISCP 3991, the student must have successfully completed the Liberal Studies Seminars requirements, have completed at least 105 credits toward the B.I.S. degree, including most of the concentration courses, have removed all incompletes, and be in good academic standing, that is, not be on academic warning. Students also must have attended the Capstone information session and filed the Intent to Take Capstone Project I Form at least two months prior to the start of class.',
#   'chunk_index': 19}]

# %%
school_info[0:2]
# Out:
# [{'Major': 'Data Science, B.S.',
#   'School': 'School of Data Science',
#   'Text': 'DS 1001\xa0-\xa0Foundation of Data Science Credits:          3 Programming Requirement There are multiple ways this requirement can be met. Enrollment in one of the following courses at UVA: DS 1002\xa0-\xa0Programming for Data Science Credits:          3 CS 1110\xa0-\xa0Introduction to Programming Credits:          3 CS 1111\xa0-\xa0Introduction to Programming Credits:          3 CS 1112\xa0-\xa0Introduction to Programming Credits:          3 CS 1113\xa0-\xa0Introduction to Programming Credits:          3 PHYS 1655\xa0-\xa0Introduction to Python for Scientists and Engineers Credits: 3 OR Test credit AP Computer Science A with a score if 4 or 5 IB HL Computer Science with a score of 5, 6, or 7 OR Passing the CS 1110 Place-Out Test Students who pass the test\xa0receive a notation in SIS. The School of Data Science encourages students to complete the place-out test in Python. Students must be proficient in Python prior to the start of classes. Program Requirements CREDIT/GPA MINIMUMS Number of DS Course Credits required: 49 Number of Credits required to be taken at UVA: 60 Minimum CUM GPA to graduate: 2.00 Total Credits required: 120 credits Core Curriculum (40 credits) Due to course sequencing and availability, students may not withdraw\xa0from a core course. Students must take courses for a letter grade and achieve a grade of D or better.',
#   'chunk_index': 1},
#  {'Major': 'Data Science, B.S.',
#   'School': 'School of Data Science',
#   'Text': 'Data Science, B.S. Print-Friendly Page (opens a new window) Return to: School of Data Science: Degree Programs The B.S. in Data Science (BSDS) will prepare students to serve in the public and private sectors across industries. Students will gain a strong foundation in core data science tools, methodologies\xa0and approaches, alongside a deep understanding of the ethical dimensions of data systems and solutions. The program will educate students in the four domains of data science, as defined by the School of Data Science: value, design, analytics, and systems. General Education Requirements (33 credits) The School of Data Science will accept students from any of the College of Arts & Sciences general education curricular programs (Echols Scholars Program, Engagements Pathway, Disciplines Plus Pathway or Forums curriculum) and any other school of enrollment at UVA. Search course attributes in SIS for a list of courses that count toward general education requirements. Courses from the Data Science core may also be used to satisfy general education requirements. The School of Data Science waives general education curricular requirements for Echols Scholars. Rhetoric for the 21st Century: 6 credits required DS 4022\xa0-\xa0Data Science Project - Major Credits:          3 Satifies the Second Writing Requirement. Quantification, Computation, and Data Analysis: 6 credits required DS 2026\xa0-\xa0Computational Probability Credits:          3 Satisfies 3 credits of the\xa0Quantification, Computation, and Data Analysis Requirement. Artistic, Interpretive, and Philosophical Inquiry: 3 credits required Chemical, Mathematical, and Physical Universe: 3 credits required Cultures and Societies of the World: 3 credits required Historical Perspectives: 3 credits required Living Systems: 3 credits required Social and Economic Systems: 3 credits required Science and Society: 3 credits required DS 1001\xa0-\xa0Foundation of Data Science Credits:          3 Satisfies the Science and Society Requirement. Prerequisites Completion of 24 credit hours at the University of Virginia by the end of the Spring of a student’s first year. This may include general education credits, credits toward another major or minor,\xa0 and electives. Foundation of Data Science Must be taken at UVA and completed with a grade of C- or higher.',
#   'chunk_index': 0}]

# %% [markdown]
# # Functions to transform output of retrieval to long string

# %%
#function to reformat major info into a long string
def format_major_info_string(major_info):
    formatted_texts = []
    for doc in major_info:
        school = doc.get('School', 'Unknown School') #get school or unknown school
        major = doc.get("Major", "Unknown Major")  # Get Major, or "Unknown Major" if missing
        text = doc.get("Text", "No Text Available")  # Get Text, or "No Text Available" if missing

        # Clean up newline characters and non-breaking spaces
        cleaned_text = text.replace("\n", " ").replace("\xa0", " ")

        formatted_texts.append(f"{school}: {major}: {cleaned_text}")

    context = "\n\n".join(formatted_texts)  # Join with double newlines for separation
    return context

# %%
#function to reformat school info into a long string
def format_school_info_string(school_info):
    formatted_texts = []
    for doc in school_info:
        school = doc.get('School', 'Unknown School') #get school or unknown school
        text = doc.get("Text", "No Text Available")  # Get Text, or "No Text Available" if missing

        # Clean up newline characters and non-breaking spaces
        cleaned_text = text.replace("\n", " ").replace("\xa0", " ")
        #cleaned_text = " ".join(text.split()) 

        formatted_texts.append(f"{school} \n {cleaned_text}")

    context = "\n\n".join(formatted_texts)  # Join with double newlines for separation
    return context

# %%
def format_class_info_string(class_info):
    formatted_texts = []
    for doc in class_info:
        code = doc.get("Code", "Unknown Code")  # Get Code, or "Unknown Code" if missing
        number = doc.get("Number", "Unknown Number")  # Get Number, or "Unknown Number" if missing
        section = doc.get("Section", "Unknown Section")  # Get Section, or "Unknown Section" if missing
        type = doc.get("Type", "Unknown Type")  # Get Type, or "Unknown Type" if missing
        units = doc.get("Units", "Unknown Units")  # Get Units, or "Unknown Units" if missing
        instructor = doc.get("Instructor", "Unknown Instructor")  # Get Instructor, or "Unknown Instructor" if missing
        days = doc.get("Days", "Unknown Days")  # Get Days, or "Unknown Days" if missing
        room = doc.get("Room", "Unknown Room")  # Get Room, or "Unknown Room" if missing
        title = doc.get("Title", "No Title Available")  # Get Title, or "No Title Available" if missing
        description = doc.get("Description", "No Description Available")  # Get Description, or "No Description Available" if missing
        semester = doc.get("Semester", "Unknown Semester")
        year = doc.get("Year", "Unknown Year")
        department = doc.get("Department", "Unknown Department")

        # Clean up newline characters and non-breaking spaces
        cleaned_description = description.replace("\n", " ").replace("\xa0", " ")

        formatted_texts.append(f"code:{code}, number: {number}, semester: {semester}, year:{year},section: {section}, units: {units}, type: {type} instructor: {instructor}, days: {days}, room: {room},department {department},  title: {title} course desrcription: {cleaned_description}")

    context = "\n\n".join(formatted_texts)  # Join with double newlines for separation
    return context

# %% [markdown]
# # Generation

# %%
#get token from .env file

# Load environment variables from .env file
load_dotenv()

# Retrieve the token
token = os.getenv("TOKEN")

# %%
# log into huggingface
login(token = token)

# %%
#set system prompt
SYSTEM_PROMPT_1 = """You are a University of Virginia undergraduate course scheduler. 
The output of this prompt will be used to search for classes, by looking for embedding similarities, in a ChromaDB vector database so make sure the output is clear, concise and under 500 tokens.
The classes database includes information on course times, descriptions, professors, and other relevant information.
As background information: You use retrieved documents to create a schedule for one semester. A full time student should have between 12-15 credits per semester. 
Do not make up any courses, only use information from the context.
Do not include any non relevant information like courses you aren't taking, or any other information that is not relevant to the course schedule.
The user will ask you to create a schedule for a specific major or school and year. Do not give a third or fourth year student all introductory classes and do not give a first year student all high level classes. The user may also provide possible additional information such as professors, days of the week, or specific courses.
"""

# %% [markdown]
# ## Using Llamma cpp package

# %%
#load 6-bit quantized mistral model
llm = Llama.from_pretrained(
	repo_id="bartowski/mistralai_Mistral-Small-3.1-24B-Instruct-2503-GGUF",
	filename="mistralai_Mistral-Small-3.1-24B-Instruct-2503-IQ3_XXS.gguf",
    n_ctx = 20000, #token size, might be excessive (about 75-100 pages of text)
    n_gpu_layers=-1,  # Use Metal GPU acceleration
    n_threads=8,
    verbose=True 
)
# Out:
# llama_model_load_from_file_impl: using device Metal (Apple M3 Max) - 26578 MiB free
# llama_model_loader: loaded meta data with 45 key-value pairs and 363 tensors from /Users/rfell/.cache/huggingface/hub/models--bartowski--mistralai_Mistral-Small-3.1-24B-Instruct-2503-GGUF/snapshots/6f1e0225e5ab39e4904d2ff2cc4e7805b416eff3/./mistralai_Mistral-Small-3.1-24B-Instruct-2503-IQ3_XXS.gguf (version GGUF V3 (latest))
# llama_model_loader: Dumping metadata keys/values. Note: KV overrides do not apply in this output.
# llama_model_loader: - kv   0:                       general.architecture str              = llama
# llama_model_loader: - kv   1:                               general.type str              = model
# llama_model_loader: - kv   2:                               general.name str              = Mistral Small 3.1 24B Instruct 2503
# llama_model_loader: - kv   3:                            general.version str              = 2503
# llama_model_loader: - kv   4:                           general.finetune str              = Instruct
# llama_model_loader: - kv   5:                           general.basename str              = Mistral-Small-3.1
# llama_model_loader: - kv   6:                         general.size_label str              = 24B
# llama_model_loader: - kv   7:                            general.license str              = apache-2.0
# llama_model_loader: - kv   8:                   general.base_model.count u32              = 1
# llama_model_loader: - kv   9:                  general.base_model.0.name str              = Mistral Small 3.1 24B Base 2503
# llama_model_loader: - kv  10:               general.base_model.0.version str              = 2503
# llama_model_loader: - kv  11:          general.base_model.0.organization str              = Mistralai
# llama_model_loader: - kv  12:              general.base_model.0.repo_url str              = https://huggingface.co/mistralai/Mist...
# llama_model_loader: - kv  13:                          general.languages arr[str,24]      = ["en", "fr", "de", "es", "pt", "it", ...
# llama_model_loader: - kv  14:                          llama.block_count u32              = 40
# llama_model_loader: - kv  15:                       llama.context_length u32              = 131072
# llama_model_loader: - kv  16:                     llama.embedding_length u32              = 5120
# llama_model_loader: - kv  17:                  llama.feed_forward_length u32              = 32768
# llama_model_loader: - kv  18:                 llama.attention.head_count u32              = 32
# llama_model_loader: - kv  19:              llama.attention.head_count_kv u32              = 8
# llama_model_loader: - kv  20:                       llama.rope.freq_base f32              = 1000000000.000000
# llama_model_loader: - kv  21:     llama.attention.layer_norm_rms_epsilon f32              = 0.000010
# llama_model_loader: - kv  22:                 llama.attention.key_length u32              = 128
# llama_model_loader: - kv  23:               llama.attention.value_length u32              = 128
# llama_model_loader: - kv  24:                           llama.vocab_size u32              = 131072
# llama_model_loader: - kv  25:                 llama.rope.dimension_count u32              = 128
# llama_model_loader: - kv  26:                       tokenizer.ggml.model str              = gpt2
# llama_model_loader: - kv  27:                         tokenizer.ggml.pre str              = tekken
# llama_model_loader: - kv  28:                      tokenizer.ggml.tokens arr[str,131072]  = ["<unk>", "<s>", "</s>", "[INST]", "[...
# llama_model_loader: - kv  29:                  tokenizer.ggml.token_type arr[i32,131072]  = [3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, ...
# Exception ignored on calling ctypes callback function: <function llama_log_callback at 0x3456f6660>
# Traceback (most recent call last):
#   File "/Users/rfell/miniconda3/lib/python3.12/site-packages/llama_cpp/_logger.py", line 39, in llama_log_callback
#     print(text.decode("utf-8"), end="", flush=True, file=sys.stderr)
#           ^^^^^^^^^^^^^^^^^^^^
# UnicodeDecodeError: 'utf-8' codec can't decode byte 0xc4 in position 128: invalid continuation byte
# llama_model_loader: - kv  31:                tokenizer.ggml.bos_token_id u32              = 1
# llama_model_loader: - kv  32:                tokenizer.ggml.eos_token_id u32              = 2
# llama_model_loader: - kv  33:            tokenizer.ggml.unknown_token_id u32              = 0
# llama_model_loader: - kv  34:            tokenizer.ggml.padding_token_id u32              = 11
# llama_model_loader: - kv  35:               tokenizer.ggml.add_bos_token bool             = true
# llama_model_loader: - kv  36:               tokenizer.ggml.add_eos_token bool             = false
# llama_model_loader: - kv  37:                    tokenizer.chat_template str              = {%- set default_system_message = "You...
# llama_model_loader: - kv  38:            tokenizer.ggml.add_space_prefix bool             = false
# llama_model_loader: - kv  39:               general.quantization_version u32              = 2
# llama_model_loader: - kv  40:                          general.file_type u32              = 23
# llama_model_loader: - kv  41:                      quantize.imatrix.file str              = /models_out/Mistral-Small-3.1-24B-Ins...
# llama_model_loader: - kv  42:                   quantize.imatrix.dataset str              = /training_dir/calibration_datav3.txt
# llama_model_loader: - kv  43:             quantize.imatrix.entries_count i32              = 280
# llama_model_loader: - kv  44:              quantize.imatrix.chunks_count i32              = 128
# llama_model_loader: - type  f32:   81 tensors
# llama_model_loader: - type q4_K:   40 tensors
# llama_model_loader: - type q5_K:    1 tensors
# llama_model_loader: - type iq3_xxs:  120 tensors
# llama_model_loader: - type iq3_s:   41 tensors
# llama_model_loader: - type iq2_s:   80 tensors
# print_info: file format = GGUF V3 (latest)
# print_info: file type   = IQ3_XXS - 3.0625 bpw
# print_info: file size   = 8.64 GiB (3.15 BPW)
# init_tokenizer: initializing tokenizer for type 2
# load: control token:    144 '<SPECIAL_144>' is not marked as EOG
# load: control token:    682 '<SPECIAL_682>' is not marked as EOG
# load: control token:    412 '<SPECIAL_412>' is not marked as EOG
# load: control token:    502 '<SPECIAL_502>' is not marked as EOG
# load: control token:    426 '<SPECIAL_426>' is not marked as EOG
# load: control token:     29 '<SPECIAL_29>' is not marked as EOG
# load: control token:    917 '<SPECIAL_917>' is not marked as EOG
# load: control token:    996 '<SPECIAL_996>' is not marked as EOG
# load: control token:    882 '<SPECIAL_882>' is not marked as EOG
# load: control token:    819 '<SPECIAL_819>' is not marked as EOG
# load: control token:    700 '<SPECIAL_700>' is not marked as EOG
# load: control token:    213 '<SPECIAL_213>' is not marked as EOG
# load: control token:    920 '<SPECIAL_920>' is not marked as EOG
# load: control token:    288 '<SPECIAL_288>' is not marked as EOG
# load: control token:    969 '<SPECIAL_969>' is not marked as EOG
# load: control token:    630 '<SPECIAL_630>' is not marked as EOG
# load: control token:    454 '<SPECIAL_454>' is not marked as EOG
# load: control token:    798 '<SPECIAL_798>' is not marked as EOG
# load: control token:    593 '<SPECIAL_593>' is not marked as EOG
# load: control token:    774 '<SPECIAL_774>' is not marked as EOG
# load: control token:    526 '<SPECIAL_526>' is not marked as EOG
# load: control token:    581 '<SPECIAL_581>' is not marked as EOG
# load: control token:    351 '<SPECIAL_351>' is not marked as EOG
# load: control token:    994 '<SPECIAL_994>' is not marked as EOG
# load: control token:    321 '<SPECIAL_321>' is not marked as EOG
# load: control token:    120 '<SPECIAL_120>' is not marked as EOG
# load: control token:    487 '<SPECIAL_487>' is not marked as EOG
# load: control token:    227 '<SPECIAL_227>' is not marked as EOG
# load: control token:    439 '<SPECIAL_439>' is not marked as EOG
# load: control token:    989 '<SPECIAL_989>' is not marked as EOG
# load: control token:    202 '<SPECIAL_202>' is not marked as EOG
# load: control token:    689 '<SPECIAL_689>' is not marked as EOG
# load: control token:    694 '<SPECIAL_694>' is not marked as EOG
# load: control token:     19 '[TOOL_CONTENT]' is not marked as EOG
# load: control token:    290 '<SPECIAL_290>' is not marked as EOG
# load: control token:     67 '<SPECIAL_67>' is not marked as EOG
# load: control token:    674 '<SPECIAL_674>' is not marked as EOG
# load: control token:    149 '<SPECIAL_149>' is not marked as EOG
# load: control token:    802 '<SPECIAL_802>' is not marked as EOG
# load: control token:    930 '<SPECIAL_930>' is not marked as EOG
# load: control token:    228 '<SPECIAL_228>' is not marked as EOG
# load: control token:    532 '<SPECIAL_532>' is not marked as EOG
# load: control token:    780 '<SPECIAL_780>' is not marked as EOG
# load: control token:    606 '<SPECIAL_606>' is not marked as EOG
# load: control token:    784 '<SPECIAL_784>' is not marked as EOG
# load: control token:    125 '<SPECIAL_125>' is not marked as EOG
# load: control token:     15 '[MIDDLE]' is not marked as EOG
# load: control token:    776 '<SPECIAL_776>' is not marked as EOG
# load: control token:    578 '<SPECIAL_578>' is not marked as EOG
# load: control token:    102 '<SPECIAL_102>' is not marked as EOG
# load: control token:    462 '<SPECIAL_462>' is not marked as EOG
# load: control token:    365 '<SPECIAL_365>' is not marked as EOG
# load: control token:    793 '<SPECIAL_793>' is not marked as EOG
# load: control token:    343 '<SPECIAL_343>' is not marked as EOG
# load: control token:    666 '<SPECIAL_666>' is not marked as EOG
# load: control token:    345 '<SPECIAL_345>' is not marked as EOG
# load: control token:    541 '<SPECIAL_541>' is not marked as EOG
# load: control token:    385 '<SPECIAL_385>' is not marked as EOG
# load: control token:    708 '<SPECIAL_708>' is not marked as EOG
# load: control token:    663 '<SPECIAL_663>' is not marked as EOG
# load: control token:    380 '<SPECIAL_380>' is not marked as EOG
# load: control token:    538 '<SPECIAL_538>' is not marked as EOG
# load: control token:     73 '<SPECIAL_73>' is not marked as EOG
# load: control token:    266 '<SPECIAL_266>' is not marked as EOG
# load: control token:    783 '<SPECIAL_783>' is not marked as EOG
# load: control token:    329 '<SPECIAL_329>' is not marked as EOG
# load: control token:    199 '<SPECIAL_199>' is not marked as EOG
# load: control token:    234 '<SPECIAL_234>' is not marked as EOG
# load: control token:    577 '<SPECIAL_577>' is not marked as EOG
# load: control token:    788 '<SPECIAL_788>' is not marked as EOG
# load: control token:    437 '<SPECIAL_437>' is not marked as EOG
# load: control token:    693 '<SPECIAL_693>' is not marked as EOG
# load: control token:    142 '<SPECIAL_142>' is not marked as EOG
# load: control token:    961 '<SPECIAL_961>' is not marked as EOG
# load: control token:    485 '<SPECIAL_485>' is not marked as EOG
# load: control token:    276 '<SPECIAL_276>' is not marked as EOG
# load: control token:    583 '<SPECIAL_583>' is not marked as EOG
# load: control token:     94 '<SPECIAL_94>' is not marked as EOG
# load: control token:    411 '<SPECIAL_411>' is not marked as EOG
# load: control token:     78 '<SPECIAL_78>' is not marked as EOG
# load: control token:    505 '<SPECIAL_505>' is not marked as EOG
# load: control token:    222 '<SPECIAL_222>' is not marked as EOG
# load: control token:    840 '<SPECIAL_840>' is not marked as EOG
# load: control token:    971 '<SPECIAL_971>' is not marked as EOG
# load: control token:    205 '<SPECIAL_205>' is not marked as EOG
# load: control token:    456 '<SPECIAL_456>' is not marked as EOG
# load: control token:    660 '<SPECIAL_660>' is not marked as EOG
# load: control token:    183 '<SPECIAL_183>' is not marked as EOG
# load: control token:     31 '<SPECIAL_31>' is not marked as EOG
# load: control token:    194 '<SPECIAL_194>' is not marked as EOG
# load: control token:    410 '<SPECIAL_410>' is not marked as EOG
# load: control token:    562 '<SPECIAL_562>' is not marked as EOG
# load: control token:    284 '<SPECIAL_284>' is not marked as EOG
# load: control token:     99 '<SPECIAL_99>' is not marked as EOG
# load: control token:    855 '<SPECIAL_855>' is not marked as EOG
# load: control token:    778 '<SPECIAL_778>' is not marked as EOG
# load: control token:    645 '<SPECIAL_645>' is not marked as EOG
# load: control token:    945 '<SPECIAL_945>' is not marked as EOG
# load: control token:    584 '<SPECIAL_584>' is not marked as EOG
# load: control token:    508 '<SPECIAL_508>' is not marked as EOG
# load: control token:     84 '<SPECIAL_84>' is not marked as EOG
# load: control token:    556 '<SPECIAL_556>' is not marked as EOG
# load: control token:    705 '<SPECIAL_705>' is not marked as EOG
# load: control token:    475 '<SPECIAL_475>' is not marked as EOG
# load: control token:    503 '<SPECIAL_503>' is not marked as EOG
# load: control token:    905 '<SPECIAL_905>' is not marked as EOG
# load: control token:    991 '<SPECIAL_991>' is not marked as EOG
# load: control token:    346 '<SPECIAL_346>' is not marked as EOG
# load: control token:    226 '<SPECIAL_226>' is not marked as EOG
# load: control token:    314 '<SPECIAL_314>' is not marked as EOG
# load: control token:    215 '<SPECIAL_215>' is not marked as EOG
# load: control token:    914 '<SPECIAL_914>' is not marked as EOG
# load: control token:    312 '<SPECIAL_312>' is not marked as EOG
# load: control token:    574 '<SPECIAL_574>' is not marked as EOG
# load: control token:    655 '<SPECIAL_655>' is not marked as EOG
# load: control token:    204 '<SPECIAL_204>' is not marked as EOG
# load: control token:      4 '[/INST]' is not marked as EOG
# load: control token:    427 '<SPECIAL_427>' is not marked as EOG
# load: control token:    632 '<SPECIAL_632>' is not marked as EOG
# load: control token:    976 '<SPECIAL_976>' is not marked as EOG
# load: control token:    441 '<SPECIAL_441>' is not marked as EOG
# load: control token:    671 '<SPECIAL_671>' is not marked as EOG
# load: control token:    614 '<SPECIAL_614>' is not marked as EOG
# load: control token:    957 '<SPECIAL_957>' is not marked as EOG
# load: control token:     89 '<SPECIAL_89>' is not marked as EOG
# load: control token:    547 '<SPECIAL_547>' is not marked as EOG
# load: control token:    939 '<SPECIAL_939>' is not marked as EOG
# load: control token:    334 '<SPECIAL_334>' is not marked as EOG
# load: control token:    637 '<SPECIAL_637>' is not marked as EOG
# load: control token:    307 '<SPECIAL_307>' is not marked as EOG
# load: control token:    265 '<SPECIAL_265>' is not marked as EOG
# load: control token:    331 '<SPECIAL_331>' is not marked as EOG
# load: control token:    313 '<SPECIAL_313>' is not marked as EOG
# load: control token:    711 '<SPECIAL_711>' is not marked as EOG
# load: control token:    697 '<SPECIAL_697>' is not marked as EOG
# load: control token:    495 '<SPECIAL_495>' is not marked as EOG
# load: control token:    631 '<SPECIAL_631>' is not marked as EOG
# load: control token:     69 '<SPECIAL_69>' is not marked as EOG
# load: control token:    877 '<SPECIAL_877>' is not marked as EOG
# load: control token:    506 '<SPECIAL_506>' is not marked as EOG
# load: control token:    298 '<SPECIAL_298>' is not marked as EOG
# load: control token:    582 '<SPECIAL_582>' is not marked as EOG
# load: control token:    510 '<SPECIAL_510>' is not marked as EOG
# load: control token:    231 '<SPECIAL_231>' is not marked as EOG
# load: control token:    308 '<SPECIAL_308>' is not marked as EOG
# load: control token:    299 '<SPECIAL_299>' is not marked as EOG
# load: control token:    922 '<SPECIAL_922>' is not marked as EOG
# load: control token:    846 '<SPECIAL_846>' is not marked as EOG
# load: control token:    241 '<SPECIAL_241>' is not marked as EOG
# load: control token:    347 '<SPECIAL_347>' is not marked as EOG
# load: control token:    119 '<SPECIAL_119>' is not marked as EOG
# load: control token:    368 '<SPECIAL_368>' is not marked as EOG
# load: control token:    764 '<SPECIAL_764>' is not marked as EOG
# load: control token:    648 '<SPECIAL_648>' is not marked as EOG
# load: control token:    555 '<SPECIAL_555>' is not marked as EOG
# load: control token:    910 '<SPECIAL_910>' is not marked as EOG
# load: control token:    927 '<SPECIAL_927>' is not marked as EOG
# load: control token:    318 '<SPECIAL_318>' is not marked as EOG
# load: control token:     41 '<SPECIAL_41>' is not marked as EOG
# load: control token:    369 '<SPECIAL_369>' is not marked as EOG
# load: control token:    865 '<SPECIAL_865>' is not marked as EOG
# load: control token:    979 '<SPECIAL_979>' is not marked as EOG
# load: control token:    592 '<SPECIAL_592>' is not marked as EOG
# load: control token:    647 '<SPECIAL_647>' is not marked as EOG
# load: control token:    279 '<SPECIAL_279>' is not marked as EOG
# load: control token:    198 '<SPECIAL_198>' is not marked as EOG
# load: control token:    835 '<SPECIAL_835>' is not marked as EOG
# load: control token:    282 '<SPECIAL_282>' is not marked as EOG
# load: control token:    573 '<SPECIAL_573>' is not marked as EOG
# load: control token:    172 '<SPECIAL_172>' is not marked as EOG
# load: control token:     55 '<SPECIAL_55>' is not marked as EOG
# load: control token:     76 '<SPECIAL_76>' is not marked as EOG
# load: control token:    773 '<SPECIAL_773>' is not marked as EOG
# load: control token:    580 '<SPECIAL_580>' is not marked as EOG
# load: control token:     95 '<SPECIAL_95>' is not marked as EOG
# load: control token:    847 '<SPECIAL_847>' is not marked as EOG
# load: control token:    216 '<SPECIAL_216>' is not marked as EOG
# load: control token:     45 '<SPECIAL_45>' is not marked as EOG
# load: control token:    358 '<SPECIAL_358>' is not marked as EOG
# load: control token:     68 '<SPECIAL_68>' is not marked as EOG
# load: control token:    792 '<SPECIAL_792>' is not marked as EOG
# load: control token:    710 '<SPECIAL_710>' is not marked as EOG
# load: control token:    501 '<SPECIAL_501>' is not marked as EOG
# load: control token:    272 '<SPECIAL_272>' is not marked as EOG
# load: control token:    163 '<SPECIAL_163>' is not marked as EOG
# load: control token:    348 '<SPECIAL_348>' is not marked as EOG
# load: control token:    285 '<SPECIAL_285>' is not marked as EOG
# load: control token:    177 '<SPECIAL_177>' is not marked as EOG
# load: control token:    300 '<SPECIAL_300>' is not marked as EOG
# load: control token:    786 '<SPECIAL_786>' is not marked as EOG
# load: control token:    768 '<SPECIAL_768>' is not marked as EOG
# load: control token:    908 '<SPECIAL_908>' is not marked as EOG
# load: control token:    978 '<SPECIAL_978>' is not marked as EOG
# load: control token:    990 '<SPECIAL_990>' is not marked as EOG
# load: control token:    898 '<SPECIAL_898>' is not marked as EOG
# load: control token:    915 '<SPECIAL_915>' is not marked as EOG
# load: control token:    658 '<SPECIAL_658>' is not marked as EOG
# load: control token:      7 '[TOOL_RESULTS]' is not marked as EOG
# load: control token:    951 '<SPECIAL_951>' is not marked as EOG
# load: control token:    327 '<SPECIAL_327>' is not marked as EOG
# load: control token:    603 '<SPECIAL_603>' is not marked as EOG
# load: control token:    688 '<SPECIAL_688>' is not marked as EOG
# load: control token:    277 '<SPECIAL_277>' is not marked as EOG
# load: control token:    747 '<SPECIAL_747>' is not marked as EOG
# load: control token:    273 '<SPECIAL_273>' is not marked as EOG
# load: control token:    317 '<SPECIAL_317>' is not marked as EOG
# load: control token:    853 '<SPECIAL_853>' is not marked as EOG
# load: control token:     70 '<SPECIAL_70>' is not marked as EOG
# load: control token:    570 '<SPECIAL_570>' is not marked as EOG
# load: control token:    256 '<SPECIAL_256>' is not marked as EOG
# load: control token:    535 '<SPECIAL_535>' is not marked as EOG
# load: control token:    822 '<SPECIAL_822>' is not marked as EOG
# load: control token:    929 '<SPECIAL_929>' is not marked as EOG
# load: control token:    540 '<SPECIAL_540>' is not marked as EOG
# load: control token:    696 '<SPECIAL_696>' is not marked as EOG
# load: control token:    208 '<SPECIAL_208>' is not marked as EOG
# load: control token:     18 '[/SYSTEM_PROMPT]' is not marked as EOG
# load: control token:    396 '<SPECIAL_396>' is not marked as EOG
# load: control token:    876 '<SPECIAL_876>' is not marked as EOG
# load: control token:    563 '<SPECIAL_563>' is not marked as EOG
# load: control token:    904 '<SPECIAL_904>' is not marked as EOG
# load: control token:    146 '<SPECIAL_146>' is not marked as EOG
# load: control token:    919 '<SPECIAL_919>' is not marked as EOG
# load: control token:    900 '<SPECIAL_900>' is not marked as EOG
# load: control token:     75 '<SPECIAL_75>' is not marked as EOG
# load: control token:    388 '<SPECIAL_388>' is not marked as EOG
# load: control token:    718 '<SPECIAL_718>' is not marked as EOG
# load: control token:    560 '<SPECIAL_560>' is not marked as EOG
# load: control token:    339 '<SPECIAL_339>' is not marked as EOG
# load: control token:    552 '<SPECIAL_552>' is not marked as EOG
# load: control token:    620 '<SPECIAL_620>' is not marked as EOG
# load: control token:    983 '<SPECIAL_983>' is not marked as EOG
# load: control token:    622 '<SPECIAL_622>' is not marked as EOG
# load: control token:    585 '<SPECIAL_585>' is not marked as EOG
# load: control token:    511 '<SPECIAL_511>' is not marked as EOG
# load: control token:    916 '<SPECIAL_916>' is not marked as EOG
# load: control token:    372 '<SPECIAL_372>' is not marked as EOG
# load: control token:    926 '<SPECIAL_926>' is not marked as EOG
# load: control token:    138 '<SPECIAL_138>' is not marked as EOG
# load: control token:    419 '<SPECIAL_419>' is not marked as EOG
# load: control token:    616 '<SPECIAL_616>' is not marked as EOG
# load: control token:    712 '<SPECIAL_712>' is not marked as EOG
# load: control token:    977 '<SPECIAL_977>' is not marked as EOG
# load: control token:    549 '<SPECIAL_549>' is not marked as EOG
# load: control token:    499 '<SPECIAL_499>' is not marked as EOG
# load: control token:    116 '<SPECIAL_116>' is not marked as EOG
# load: control token:    230 '<SPECIAL_230>' is not marked as EOG
# load: control token:    528 '<SPECIAL_528>' is not marked as EOG
# load: control token:    938 '<SPECIAL_938>' is not marked as EOG
# load: control token:    270 '<SPECIAL_270>' is not marked as EOG
# load: control token:    615 '<SPECIAL_615>' is not marked as EOG
# load: control token:    169 '<SPECIAL_169>' is not marked as EOG
# load: control token:    923 '<SPECIAL_923>' is not marked as EOG
# load: control token:    872 '<SPECIAL_872>' is not marked as EOG
# load: control token:    400 '<SPECIAL_400>' is not marked as EOG
# load: control token:    405 '<SPECIAL_405>' is not marked as EOG
# load: control token:    662 '<SPECIAL_662>' is not marked as EOG
# load: control token:    737 '<SPECIAL_737>' is not marked as EOG
# load: control token:    758 '<SPECIAL_758>' is not marked as EOG
# load: control token:    211 '<SPECIAL_211>' is not marked as EOG
# load: control token:    386 '<SPECIAL_386>' is not marked as EOG
# load: control token:    244 '<SPECIAL_244>' is not marked as EOG
# load: control token:    113 '<SPECIAL_113>' is not marked as EOG
# load: control token:    161 '<SPECIAL_161>' is not marked as EOG
# load: control token:    928 '<SPECIAL_928>' is not marked as EOG
# load: control token:    791 '<SPECIAL_791>' is not marked as EOG
# load: control token:    378 '<SPECIAL_378>' is not marked as EOG
# load: control token:    661 '<SPECIAL_661>' is not marked as EOG
# load: control token:    524 '<SPECIAL_524>' is not marked as EOG
# load: control token:    431 '<SPECIAL_431>' is not marked as EOG
# load: control token:    342 '<SPECIAL_342>' is not marked as EOG
# load: control token:    245 '<SPECIAL_245>' is not marked as EOG
# load: control token:    159 '<SPECIAL_159>' is not marked as EOG
# load: control token:    209 '<SPECIAL_209>' is not marked as EOG
# load: control token:      3 '[INST]' is not marked as EOG
# load: control token:    221 '<SPECIAL_221>' is not marked as EOG
# load: control token:    498 '<SPECIAL_498>' is not marked as EOG
# load: control token:    467 '<SPECIAL_467>' is not marked as EOG
# load: control token:    988 '<SPECIAL_988>' is not marked as EOG
# load: control token:    878 '<SPECIAL_878>' is not marked as EOG
# load: control token:    527 '<SPECIAL_527>' is not marked as EOG
# load: control token:    952 '<SPECIAL_952>' is not marked as EOG
# load: control token:    357 '<SPECIAL_357>' is not marked as EOG
# load: control token:    859 '<SPECIAL_859>' is not marked as EOG
# load: control token:    906 '<SPECIAL_906>' is not marked as EOG
# load: control token:    932 '<SPECIAL_932>' is not marked as EOG
# load: control token:    309 '<SPECIAL_309>' is not marked as EOG
# load: control token:     66 '<SPECIAL_66>' is not marked as EOG
# load: control token:    302 '<SPECIAL_302>' is not marked as EOG
# load: control token:    899 '<SPECIAL_899>' is not marked as EOG
# load: control token:    330 '<SPECIAL_330>' is not marked as EOG
# load: control token:    885 '<SPECIAL_885>' is not marked as EOG
# load: control token:    749 '<SPECIAL_749>' is not marked as EOG
# load: control token:    530 '<SPECIAL_530>' is not marked as EOG
# load: control token:    635 '<SPECIAL_635>' is not marked as EOG
# load: control token:    518 '<SPECIAL_518>' is not marked as EOG
# load: control token:    447 '<SPECIAL_447>' is not marked as EOG
# load: control token:    543 '<SPECIAL_543>' is not marked as EOG
# load: control token:    107 '<SPECIAL_107>' is not marked as EOG
# load: control token:    408 '<SPECIAL_408>' is not marked as EOG
# load: control token:    935 '<SPECIAL_935>' is not marked as EOG
# load: control token:    409 '<SPECIAL_409>' is not marked as EOG
# load: control token:    962 '<SPECIAL_962>' is not marked as EOG
# load: control token:    115 '<SPECIAL_115>' is not marked as EOG
# load: control token:    860 '<SPECIAL_860>' is not marked as EOG
# load: control token:    608 '<SPECIAL_608>' is not marked as EOG
# load: control token:    761 '<SPECIAL_761>' is not marked as EOG
# load: control token:    128 '<SPECIAL_128>' is not marked as EOG
# load: control token:    428 '<SPECIAL_428>' is not marked as EOG
# load: control token:    702 '<SPECIAL_702>' is not marked as EOG
# load: control token:    203 '<SPECIAL_203>' is not marked as EOG
# load: control token:    297 '<SPECIAL_297>' is not marked as EOG
# load: control token:    450 '<SPECIAL_450>' is not marked as EOG
# load: control token:    767 '<SPECIAL_767>' is not marked as EOG
# load: control token:    804 '<SPECIAL_804>' is not marked as EOG
# load: control token:    295 '<SPECIAL_295>' is not marked as EOG
# load: control token:    790 '<SPECIAL_790>' is not marked as EOG
# load: control token:    625 '<SPECIAL_625>' is not marked as EOG
# load: control token:    858 '<SPECIAL_858>' is not marked as EOG
# load: control token:    469 '<SPECIAL_469>' is not marked as EOG
# load: control token:    438 '<SPECIAL_438>' is not marked as EOG
# load: control token:    626 '<SPECIAL_626>' is not marked as EOG
# load: control token:    393 '<SPECIAL_393>' is not marked as EOG
# load: control token:    723 '<SPECIAL_723>' is not marked as EOG
# load: control token:    956 '<SPECIAL_956>' is not marked as EOG
# load: control token:    531 '<SPECIAL_531>' is not marked as EOG
# load: control token:    153 '<SPECIAL_153>' is not marked as EOG
# load: control token:    353 '<SPECIAL_353>' is not marked as EOG
# load: control token:    808 '<SPECIAL_808>' is not marked as EOG
# load: control token:    551 '<SPECIAL_551>' is not marked as EOG
# load: control token:    451 '<SPECIAL_451>' is not marked as EOG
# load: control token:    488 '<SPECIAL_488>' is not marked as EOG
# load: control token:    465 '<SPECIAL_465>' is not marked as EOG
# load: control token:    756 '<SPECIAL_756>' is not marked as EOG
# load: control token:    247 '<SPECIAL_247>' is not marked as EOG
# load: control token:    667 '<SPECIAL_667>' is not marked as EOG
# load: control token:    591 '<SPECIAL_591>' is not marked as EOG
# load: control token:    432 '<SPECIAL_432>' is not marked as EOG
# load: control token:    844 '<SPECIAL_844>' is not marked as EOG
# load: control token:    918 '<SPECIAL_918>' is not marked as EOG
# load: control token:    181 '<SPECIAL_181>' is not marked as EOG
# load: control token:    371 '<SPECIAL_371>' is not marked as EOG
# load: control token:    714 '<SPECIAL_714>' is not marked as EOG
# load: control token:    249 '<SPECIAL_249>' is not marked as EOG
# load: control token:     52 '<SPECIAL_52>' is not marked as EOG
# load: control token:    323 '<SPECIAL_323>' is not marked as EOG
# load: control token:    760 '<SPECIAL_760>' is not marked as EOG
# load: control token:    395 '<SPECIAL_395>' is not marked as EOG
# load: control token:    197 '<SPECIAL_197>' is not marked as EOG
# load: control token:     93 '<SPECIAL_93>' is not marked as EOG
# load: control token:    401 '<SPECIAL_401>' is not marked as EOG
# load: control token:    217 '<SPECIAL_217>' is not marked as EOG
# load: control token:    762 '<SPECIAL_762>' is not marked as EOG
# load: control token:    812 '<SPECIAL_812>' is not marked as EOG
# load: control token:    178 '<SPECIAL_178>' is not marked as EOG
# load: control token:    114 '<SPECIAL_114>' is not marked as EOG
# load: control token:    109 '<SPECIAL_109>' is not marked as EOG
# load: control token:    561 '<SPECIAL_561>' is not marked as EOG
# load: control token:    324 '<SPECIAL_324>' is not marked as EOG
# load: control token:    180 '<SPECIAL_180>' is not marked as EOG
# load: control token:    415 '<SPECIAL_415>' is not marked as EOG
# load: control token:    968 '<SPECIAL_968>' is not marked as EOG
# load: control token:    650 '<SPECIAL_650>' is not marked as EOG
# load: control token:    381 '<SPECIAL_381>' is not marked as EOG
# load: control token:    684 '<SPECIAL_684>' is not marked as EOG
# load: control token:    779 '<SPECIAL_779>' is not marked as EOG
# load: control token:     58 '<SPECIAL_58>' is not marked as EOG
# load: control token:    727 '<SPECIAL_727>' is not marked as EOG
# load: control token:    383 '<SPECIAL_383>' is not marked as EOG
# load: control token:    739 '<SPECIAL_739>' is not marked as EOG
# load: control token:    534 '<SPECIAL_534>' is not marked as EOG
# load: control token:    833 '<SPECIAL_833>' is not marked as EOG
# load: control token:    690 '<SPECIAL_690>' is not marked as EOG
# load: control token:     38 '<SPECIAL_38>' is not marked as EOG
# load: control token:    800 '<SPECIAL_800>' is not marked as EOG
# load: control token:    492 '<SPECIAL_492>' is not marked as EOG
# load: control token:    398 '<SPECIAL_398>' is not marked as EOG
# load: control token:    719 '<SPECIAL_719>' is not marked as EOG
# load: control token:    717 '<SPECIAL_717>' is not marked as EOG
# load: control token:    344 '<SPECIAL_344>' is not marked as EOG
# load: control token:    449 '<SPECIAL_449>' is not marked as EOG
# load: control token:    238 '<SPECIAL_238>' is not marked as EOG
# load: control token:    604 '<SPECIAL_604>' is not marked as EOG
# load: control token:    301 '<SPECIAL_301>' is not marked as EOG
# load: control token:    566 '<SPECIAL_566>' is not marked as EOG
# load: control token:    753 '<SPECIAL_753>' is not marked as EOG
# load: control token:    703 '<SPECIAL_703>' is not marked as EOG
# load: control token:    997 '<SPECIAL_997>' is not marked as EOG
# load: control token:    982 '<SPECIAL_982>' is not marked as EOG
# load: control token:    896 '<SPECIAL_896>' is not marked as EOG
# load: control token:    909 '<SPECIAL_909>' is not marked as EOG
# load: control token:    942 '<SPECIAL_942>' is not marked as EOG
# load: control token:     12 '[IMG_BREAK]' is not marked as EOG
# load: control token:    763 '<SPECIAL_763>' is not marked as EOG
# load: control token:    110 '<SPECIAL_110>' is not marked as EOG
# load: control token:    158 '<SPECIAL_158>' is not marked as EOG
# load: control token:    821 '<SPECIAL_821>' is not marked as EOG
# load: control token:    888 '<SPECIAL_888>' is not marked as EOG
# load: control token:    416 '<SPECIAL_416>' is not marked as EOG
# load: control token:    539 '<SPECIAL_539>' is not marked as EOG
# load: control token:     80 '<SPECIAL_80>' is not marked as EOG
# load: control token:    809 '<SPECIAL_809>' is not marked as EOG
# load: control token:    519 '<SPECIAL_519>' is not marked as EOG
# load: control token:    392 '<SPECIAL_392>' is not marked as EOG
# load: control token:    479 '<SPECIAL_479>' is not marked as EOG
# load: control token:    253 '<SPECIAL_253>' is not marked as EOG
# load: control token:     60 '<SPECIAL_60>' is not marked as EOG
# load: control token:    651 '<SPECIAL_651>' is not marked as EOG
# load: control token:    782 '<SPECIAL_782>' is not marked as EOG
# load: control token:    826 '<SPECIAL_826>' is not marked as EOG
# load: control token:    548 '<SPECIAL_548>' is not marked as EOG
# load: control token:    590 '<SPECIAL_590>' is not marked as EOG
# load: control token:    973 '<SPECIAL_973>' is not marked as EOG
# load: control token:    824 '<SPECIAL_824>' is not marked as EOG
# load: control token:    417 '<SPECIAL_417>' is not marked as EOG
# load: control token:    673 '<SPECIAL_673>' is not marked as EOG
# load: control token:    513 '<SPECIAL_513>' is not marked as EOG
# load: control token:    998 '<SPECIAL_998>' is not marked as EOG
# load: control token:    731 '<SPECIAL_731>' is not marked as EOG
# load: control token:    683 '<SPECIAL_683>' is not marked as EOG
# load: control token:    366 '<SPECIAL_366>' is not marked as EOG
# load: control token:    190 '<SPECIAL_190>' is not marked as EOG
# load: control token:    707 '<SPECIAL_707>' is not marked as EOG
# load: control token:    892 '<SPECIAL_892>' is not marked as EOG
# load: control token:    497 '<SPECIAL_497>' is not marked as EOG
# load: control token:    360 '<SPECIAL_360>' is not marked as EOG
# load: control token:     65 '<SPECIAL_65>' is not marked as EOG
# load: control token:     54 '<SPECIAL_54>' is not marked as EOG
# load: control token:     23 '<SPECIAL_23>' is not marked as EOG
# load: control token:    588 '<SPECIAL_588>' is not marked as EOG
# load: control token:    477 '<SPECIAL_477>' is not marked as EOG
# load: control token:    640 '<SPECIAL_640>' is not marked as EOG
# load: control token:    170 '<SPECIAL_170>' is not marked as EOG
# load: control token:    391 '<SPECIAL_391>' is not marked as EOG
# load: control token:    491 '<SPECIAL_491>' is not marked as EOG
# load: control token:    623 '<SPECIAL_623>' is not marked as EOG
# load: control token:    106 '<SPECIAL_106>' is not marked as EOG
# load: control token:    185 '<SPECIAL_185>' is not marked as EOG
# load: control token:    176 '<SPECIAL_176>' is not marked as EOG
# load: control token:    402 '<SPECIAL_402>' is not marked as EOG
# load: control token:     82 '<SPECIAL_82>' is not marked as EOG
# load: control token:    701 '<SPECIAL_701>' is not marked as EOG
# load: control token:    332 '<SPECIAL_332>' is not marked as EOG
# load: control token:    420 '<SPECIAL_420>' is not marked as EOG
# load: control token:    589 '<SPECIAL_589>' is not marked as EOG
# load: control token:    741 '<SPECIAL_741>' is not marked as EOG
# load: control token:    210 '<SPECIAL_210>' is not marked as EOG
# load: control token:    445 '<SPECIAL_445>' is not marked as EOG
# load: control token:     77 '<SPECIAL_77>' is not marked as EOG
# load: control token:    924 '<SPECIAL_924>' is not marked as EOG
# load: control token:    337 '<SPECIAL_337>' is not marked as EOG
# load: control token:    171 '<SPECIAL_171>' is not marked as EOG
# load: control token:    836 '<SPECIAL_836>' is not marked as EOG
# load: control token:    653 '<SPECIAL_653>' is not marked as EOG
# load: control token:    440 '<SPECIAL_440>' is not marked as EOG
# load: control token:    421 '<SPECIAL_421>' is not marked as EOG
# load: control token:    514 '<SPECIAL_514>' is not marked as EOG
# load: control token:    912 '<SPECIAL_912>' is not marked as EOG
# load: control token:    806 '<SPECIAL_806>' is not marked as EOG
# load: control token:    262 '<SPECIAL_262>' is not marked as EOG
# load: control token:     10 '[IMG]' is not marked as EOG
# load: control token:    310 '<SPECIAL_310>' is not marked as EOG
# load: control token:    695 '<SPECIAL_695>' is not marked as EOG
# load: control token:    494 '<SPECIAL_494>' is not marked as EOG
# load: control token:    827 '<SPECIAL_827>' is not marked as EOG
# load: control token:    387 '<SPECIAL_387>' is not marked as EOG
# load: control token:    670 '<SPECIAL_670>' is not marked as EOG
# load: control token:    724 '<SPECIAL_724>' is not marked as EOG
# load: control token:    765 '<SPECIAL_765>' is not marked as EOG
# load: control token:    214 '<SPECIAL_214>' is not marked as EOG
# load: control token:    646 '<SPECIAL_646>' is not marked as EOG
# load: control token:     44 '<SPECIAL_44>' is not marked as EOG
# load: control token:    143 '<SPECIAL_143>' is not marked as EOG
# load: control token:    720 '<SPECIAL_720>' is not marked as EOG
# load: control token:    687 '<SPECIAL_687>' is not marked as EOG
# load: control token:    545 '<SPECIAL_545>' is not marked as EOG
# load: control token:    182 '<SPECIAL_182>' is not marked as EOG
# load: control token:    869 '<SPECIAL_869>' is not marked as EOG
# load: control token:    777 '<SPECIAL_777>' is not marked as EOG
# load: control token:     37 '<SPECIAL_37>' is not marked as EOG
# load: control token:    425 '<SPECIAL_425>' is not marked as EOG
# load: control token:     98 '<SPECIAL_98>' is not marked as EOG
# load: control token:    810 '<SPECIAL_810>' is not marked as EOG
# load: control token:    461 '<SPECIAL_461>' is not marked as EOG
# load: control token:    340 '<SPECIAL_340>' is not marked as EOG
# load: control token:    133 '<SPECIAL_133>' is not marked as EOG
# load: control token:    725 '<SPECIAL_725>' is not marked as EOG
# load: control token:    691 '<SPECIAL_691>' is not marked as EOG
# load: control token:    950 '<SPECIAL_950>' is not marked as EOG
# load: control token:     11 '<pad>' is not marked as EOG
# load: control token:    575 '<SPECIAL_575>' is not marked as EOG
# load: control token:    934 '<SPECIAL_934>' is not marked as EOG
# load: control token:    141 '<SPECIAL_141>' is not marked as EOG
# load: control token:    897 '<SPECIAL_897>' is not marked as EOG
# load: control token:    656 '<SPECIAL_656>' is not marked as EOG
# load: control token:    600 '<SPECIAL_600>' is not marked as EOG
# load: control token:     57 '<SPECIAL_57>' is not marked as EOG
# load: control token:    509 '<SPECIAL_509>' is not marked as EOG
# load: control token:     56 '<SPECIAL_56>' is not marked as EOG
# load: control token:    754 '<SPECIAL_754>' is not marked as EOG
# load: control token:    755 '<SPECIAL_755>' is not marked as EOG
# load: control token:    887 '<SPECIAL_887>' is not marked as EOG
# load: control token:    533 '<SPECIAL_533>' is not marked as EOG
# load: control token:    911 '<SPECIAL_911>' is not marked as EOG
# load: control token:    732 '<SPECIAL_732>' is not marked as EOG
# load: control token:    713 '<SPECIAL_713>' is not marked as EOG
# load: control token:    698 '<SPECIAL_698>' is not marked as EOG
# load: control token:    974 '<SPECIAL_974>' is not marked as EOG
# load: control token:    624 '<SPECIAL_624>' is not marked as EOG
# load: control token:    730 '<SPECIAL_730>' is not marked as EOG
# load: control token:    659 '<SPECIAL_659>' is not marked as EOG
# load: control token:    607 '<SPECIAL_607>' is not marked as EOG
# load: control token:    999 '<SPECIAL_999>' is not marked as EOG
# load: control token:    407 '<SPECIAL_407>' is not marked as EOG
# load: control token:    384 '<SPECIAL_384>' is not marked as EOG
# load: control token:    379 '<SPECIAL_379>' is not marked as EOG
# load: control token:    664 '<SPECIAL_664>' is not marked as EOG
# load: control token:    685 '<SPECIAL_685>' is not marked as EOG
# load: control token:    480 '<SPECIAL_480>' is not marked as EOG
# load: control token:    482 '<SPECIAL_482>' is not marked as EOG
# load: control token:    875 '<SPECIAL_875>' is not marked as EOG
# load: control token:    744 '<SPECIAL_744>' is not marked as EOG
# load: control token:    955 '<SPECIAL_955>' is not marked as EOG
# load: control token:    669 '<SPECIAL_669>' is not marked as EOG
# load: control token:    629 '<SPECIAL_629>' is not marked as EOG
# load: control token:    200 '<SPECIAL_200>' is not marked as EOG
# load: control token:    597 '<SPECIAL_597>' is not marked as EOG
# load: control token:    965 '<SPECIAL_965>' is not marked as EOG
# load: control token:    733 '<SPECIAL_733>' is not marked as EOG
# load: control token:    644 '<SPECIAL_644>' is not marked as EOG
# load: control token:    861 '<SPECIAL_861>' is not marked as EOG
# load: control token:    363 '<SPECIAL_363>' is not marked as EOG
# load: control token:    537 '<SPECIAL_537>' is not marked as EOG
# load: control token:     85 '<SPECIAL_85>' is not marked as EOG
# load: control token:    856 '<SPECIAL_856>' is not marked as EOG
# load: control token:    879 '<SPECIAL_879>' is not marked as EOG
# load: control token:    264 '<SPECIAL_264>' is not marked as EOG
# load: control token:    404 '<SPECIAL_404>' is not marked as EOG
# load: control token:    612 '<SPECIAL_612>' is not marked as EOG
# load: control token:    772 '<SPECIAL_772>' is not marked as EOG
# load: control token:    817 '<SPECIAL_817>' is not marked as EOG
# load: control token:    834 '<SPECIAL_834>' is not marked as EOG
# load: control token:    829 '<SPECIAL_829>' is not marked as EOG
# load: control token:    559 '<SPECIAL_559>' is not marked as EOG
# load: control token:    960 '<SPECIAL_960>' is not marked as EOG
# load: control token:    605 '<SPECIAL_605>' is not marked as EOG
# load: control token:    893 '<SPECIAL_893>' is not marked as EOG
# load: control token:    140 '<SPECIAL_140>' is not marked as EOG
# load: control token:    568 '<SPECIAL_568>' is not marked as EOG
# load: control token:    489 '<SPECIAL_489>' is not marked as EOG
# load: control token:    271 '<SPECIAL_271>' is not marked as EOG
# load: control token:    130 '<SPECIAL_130>' is not marked as EOG
# load: control token:    775 '<SPECIAL_775>' is not marked as EOG
# load: control token:    522 '<SPECIAL_522>' is not marked as EOG
# load: control token:     26 '<SPECIAL_26>' is not marked as EOG
# load: control token:    188 '<SPECIAL_188>' is not marked as EOG
# load: control token:    617 '<SPECIAL_617>' is not marked as EOG
# load: control token:    162 '<SPECIAL_162>' is not marked as EOG
# load: control token:    830 '<SPECIAL_830>' is not marked as EOG
# load: control token:    470 '<SPECIAL_470>' is not marked as EOG
# load: control token:    736 '<SPECIAL_736>' is not marked as EOG
# load: control token:    389 '<SPECIAL_389>' is not marked as EOG
# load: control token:    678 '<SPECIAL_678>' is not marked as EOG
# load: control token:     40 '<SPECIAL_40>' is not marked as EOG
# load: control token:    184 '<SPECIAL_184>' is not marked as EOG
# load: control token:     87 '<SPECIAL_87>' is not marked as EOG
# load: control token:    987 '<SPECIAL_987>' is not marked as EOG
# load: control token:     48 '<SPECIAL_48>' is not marked as EOG
# load: control token:    894 '<SPECIAL_894>' is not marked as EOG
# load: control token:    686 '<SPECIAL_686>' is not marked as EOG
# load: control token:    127 '<SPECIAL_127>' is not marked as EOG
# load: control token:    586 '<SPECIAL_586>' is not marked as EOG
# load: control token:    223 '<SPECIAL_223>' is not marked as EOG
# load: control token:    452 '<SPECIAL_452>' is not marked as EOG
# load: control token:    627 '<SPECIAL_627>' is not marked as EOG
# load: control token:    944 '<SPECIAL_944>' is not marked as EOG
# load: control token:    239 '<SPECIAL_239>' is not marked as EOG
# load: control token:    287 '<SPECIAL_287>' is not marked as EOG
# load: control token:    108 '<SPECIAL_108>' is not marked as EOG
# load: control token:    862 '<SPECIAL_862>' is not marked as EOG
# load: control token:    218 '<SPECIAL_218>' is not marked as EOG
# load: control token:    397 '<SPECIAL_397>' is not marked as EOG
# load: control token:    193 '<SPECIAL_193>' is not marked as EOG
# load: control token:    455 '<SPECIAL_455>' is not marked as EOG
# load: control token:    263 '<SPECIAL_263>' is not marked as EOG
# load: control token:    460 '<SPECIAL_460>' is not marked as EOG
# load: control token:    377 '<SPECIAL_377>' is not marked as EOG
# load: control token:    811 '<SPECIAL_811>' is not marked as EOG
# load: control token:    771 '<SPECIAL_771>' is not marked as EOG
# load: control token:    946 '<SPECIAL_946>' is not marked as EOG
# load: control token:    414 '<SPECIAL_414>' is not marked as EOG
# load: control token:    100 '<SPECIAL_100>' is not marked as EOG
# load: control token:    813 '<SPECIAL_813>' is not marked as EOG
# load: control token:    963 '<SPECIAL_963>' is not marked as EOG
# load: control token:    816 '<SPECIAL_816>' is not marked as EOG
# load: control token:    179 '<SPECIAL_179>' is not marked as EOG
# load: control token:    716 '<SPECIAL_716>' is not marked as EOG
# load: control token:    966 '<SPECIAL_966>' is not marked as EOG
# load: control token:    275 '<SPECIAL_275>' is not marked as EOG
# load: control token:    150 '<SPECIAL_150>' is not marked as EOG
# load: control token:     43 '<SPECIAL_43>' is not marked as EOG
# load: control token:    837 '<SPECIAL_837>' is not marked as EOG
# load: control token:    349 '<SPECIAL_349>' is not marked as EOG
# load: control token:    943 '<SPECIAL_943>' is not marked as EOG
# load: control token:    457 '<SPECIAL_457>' is not marked as EOG
# load: control token:    123 '<SPECIAL_123>' is not marked as EOG
# load: control token:    866 '<SPECIAL_866>' is not marked as EOG
# load: control token:     32 '<SPECIAL_32>' is not marked as EOG
# load: control token:    598 '<SPECIAL_598>' is not marked as EOG
# load: control token:    515 '<SPECIAL_515>' is not marked as EOG
# load: control token:    338 '<SPECIAL_338>' is not marked as EOG
# load: control token:    820 '<SPECIAL_820>' is not marked as EOG
# load: control token:     22 '<SPECIAL_22>' is not marked as EOG
# load: control token:     21 '<SPECIAL_21>' is not marked as EOG
# load: control token:    311 '<SPECIAL_311>' is not marked as EOG
# load: control token:     71 '<SPECIAL_71>' is not marked as EOG
# load: control token:    571 '<SPECIAL_571>' is not marked as EOG
# load: control token:    156 '<SPECIAL_156>' is not marked as EOG
# load: control token:    399 '<SPECIAL_399>' is not marked as EOG
# load: control token:    832 '<SPECIAL_832>' is not marked as EOG
# load: control token:    993 '<SPECIAL_993>' is not marked as EOG
# load: control token:    436 '<SPECIAL_436>' is not marked as EOG
# load: control token:    444 '<SPECIAL_444>' is not marked as EOG
# load: control token:    706 '<SPECIAL_706>' is not marked as EOG
# load: control token:    668 '<SPECIAL_668>' is not marked as EOG
# load: control token:    448 '<SPECIAL_448>' is not marked as EOG
# load: control token:    433 '<SPECIAL_433>' is not marked as EOG
# load: control token:    280 '<SPECIAL_280>' is not marked as EOG
# load: control token:    903 '<SPECIAL_903>' is not marked as EOG
# load: control token:    521 '<SPECIAL_521>' is not marked as EOG
# load: control token:     51 '<SPECIAL_51>' is not marked as EOG
# load: control token:    304 '<SPECIAL_304>' is not marked as EOG
# load: control token:    335 '<SPECIAL_335>' is not marked as EOG
# load: control token:    507 '<SPECIAL_507>' is not marked as EOG
# load: control token:    867 '<SPECIAL_867>' is not marked as EOG
# load: control token:    852 '<SPECIAL_852>' is not marked as EOG
# load: control token:    738 '<SPECIAL_738>' is not marked as EOG
# load: control token:    814 '<SPECIAL_814>' is not marked as EOG
# load: control token:    769 '<SPECIAL_769>' is not marked as EOG
# load: control token:    268 '<SPECIAL_268>' is not marked as EOG
# load: control token:    933 '<SPECIAL_933>' is not marked as EOG
# load: control token:    628 '<SPECIAL_628>' is not marked as EOG
# load: control token:    967 '<SPECIAL_967>' is not marked as EOG
# load: control token:    292 '<SPECIAL_292>' is not marked as EOG
# load: control token:    550 '<SPECIAL_550>' is not marked as EOG
# load: control token:     33 '<SPECIAL_33>' is not marked as EOG
# ...
# ggml_metal_init: loaded kernel_flash_attn_ext_q5_1_h128               0x401386520 | th_max = 1024 | th_width =   32
# ggml_metal_init: loaded kernel_flash_attn_ext_q5_1_h256               0x40ddd55e0 | th_max = 1024 | th_width =   32
# ggml_metal_init: loaded kernel_flash_attn_ext_q8_0_h64                0x40e0897c0 | th_max = 1024 | th_width =   32
# ggml_metal_init: loaded kernel_flash_attn_ext_q8_0_h80                0x40164aab0 | th_max = 1024 | th_width =   32
# ggml_metal_init: loaded kernel_flash_attn_ext_q8_0_h96                0x4013872d0 | th_max = 1024 | th_width =   32
# ggml_metal_init: loaded kernel_flash_attn_ext_q8_0_h112               0x401387960 | th_max = 1024 | th_width =   32
# ggml_metal_init: loaded kernel_flash_attn_ext_q8_0_h128               0x40dfa11f0 | th_max = 1024 | th_width =   32
# ggml_metal_init: loaded kernel_flash_attn_ext_q8_0_h256               0x40a874f10 | th_max = 1024 | th_width =   32
# ggml_metal_init: loaded kernel_flash_attn_ext_vec_f16_h128            0x40e089a80 | th_max = 1024 | th_width =   32
# ggml_metal_init: skipping kernel_flash_attn_ext_vec_bf16_h128      (not supported)
# ggml_metal_init: loaded kernel_flash_attn_ext_vec_q4_0_h128           0x401386e80 | th_max = 1024 | th_width =   32
# ggml_metal_init: loaded kernel_flash_attn_ext_vec_q4_1_h128           0x40e089f30 | th_max = 1024 | th_width =   32
# ggml_metal_init: loaded kernel_flash_attn_ext_vec_q5_0_h128           0x40a9f4e30 | th_max = 1024 | th_width =   32
# ggml_metal_init: loaded kernel_flash_attn_ext_vec_q5_1_h128           0x40ddd4f90 | th_max = 1024 | th_width =   32
# ggml_metal_init: loaded kernel_flash_attn_ext_vec_q8_0_h128           0x40ddd5ab0 | th_max = 1024 | th_width =   32
# ggml_metal_init: loaded kernel_flash_attn_ext_vec_f16_h256            0x40dbe32b0 | th_max = 1024 | th_width =   32
# ggml_metal_init: skipping kernel_flash_attn_ext_vec_bf16_h256      (not supported)
# ggml_metal_init: loaded kernel_flash_attn_ext_vec_q4_0_h256           0x40a9f5600 | th_max = 1024 | th_width =   32
# ggml_metal_init: loaded kernel_flash_attn_ext_vec_q4_1_h256           0x40a9f6010 | th_max = 1024 | th_width =   32
# ggml_metal_init: loaded kernel_flash_attn_ext_vec_q5_0_h256           0x40ddd4960 | th_max = 1024 | th_width =   32
# ggml_metal_init: loaded kernel_flash_attn_ext_vec_q5_1_h256           0x40ddd6920 | th_max = 1024 | th_width =   32
# ggml_metal_init: loaded kernel_flash_attn_ext_vec_q8_0_h256           0x40a874130 | th_max = 1024 | th_width =   32
# ggml_metal_init: loaded kernel_set_f32                                0x40a875610 | th_max = 1024 | th_width =   32
# ggml_metal_init: loaded kernel_set_i32                                0x40dfa14b0 | th_max = 1024 | th_width =   32
# ggml_metal_init: loaded kernel_cpy_f32_f32                            0x40a875be0 | th_max = 1024 | th_width =   32
# ggml_metal_init: loaded kernel_cpy_f32_f16                            0x40164a160 | th_max = 1024 | th_width =   32
# ggml_metal_init: skipping kernel_cpy_f32_bf16                      (not supported)
# ggml_metal_init: loaded kernel_cpy_f16_f32                            0x400c8c070 | th_max = 1024 | th_width =   32
# ggml_metal_init: loaded kernel_cpy_f16_f16                            0x40a9f6680 | th_max = 1024 | th_width =   32
# ggml_metal_init: skipping kernel_cpy_bf16_f32                      (not supported)
# ggml_metal_init: skipping kernel_cpy_bf16_bf16                     (not supported)
# ggml_metal_init: loaded kernel_cpy_f32_q8_0                           0x40daaf1e0 | th_max = 1024 | th_width =   32
# ggml_metal_init: loaded kernel_cpy_f32_q4_0                           0x40daaf4a0 | th_max = 1024 | th_width =   32
# ggml_metal_init: loaded kernel_cpy_f32_q4_1                           0x40a874910 | th_max = 1024 | th_width =   32
# ggml_metal_init: loaded kernel_cpy_f32_q5_0                           0x40164b1f0 | th_max = 1024 | th_width =   32
# ggml_metal_init: loaded kernel_cpy_f32_q5_1                           0x40a9f6f00 | th_max = 1024 | th_width =   32
# ggml_metal_init: loaded kernel_cpy_f32_iq4_nl                         0x4013868a0 | th_max = 1024 | th_width =   32
# ggml_metal_init: loaded kernel_cpy_q4_0_f32                           0x40dbe3920 | th_max = 1024 | th_width =   32
# ggml_metal_init: loaded kernel_cpy_q4_0_f16                           0x40dbe3be0 | th_max = 1024 | th_width =   32
# ggml_metal_init: loaded kernel_cpy_q4_1_f32                           0x40dbd5a10 | th_max = 1024 | th_width =   32
# ggml_metal_init: loaded kernel_cpy_q4_1_f16                           0x40dbd89b0 | th_max = 1024 | th_width =   32
# ggml_metal_init: loaded kernel_cpy_q5_0_f32                           0x40a9f74a0 | th_max = 1024 | th_width =   32
# ggml_metal_init: loaded kernel_cpy_q5_0_f16                           0x40164b890 | th_max = 1024 | th_width =   32
# ggml_metal_init: loaded kernel_cpy_q5_1_f32                           0x40a876030 | th_max = 1024 | th_width =   32
# ggml_metal_init: loaded kernel_cpy_q5_1_f16                           0x40a876b10 | th_max = 1024 | th_width =   32
# ggml_metal_init: loaded kernel_cpy_q8_0_f32                           0x40e08b0d0 | th_max = 1024 | th_width =   32
# ggml_metal_init: loaded kernel_cpy_q8_0_f16                           0x40a8770a0 | th_max = 1024 | th_width =   32
# ggml_metal_init: loaded kernel_concat                                 0x40a8776a0 | th_max = 1024 | th_width =   32
# ggml_metal_init: loaded kernel_sqr                                    0x40dbdf790 | th_max = 1024 | th_width =   32
# ggml_metal_init: loaded kernel_sqrt                                   0x40dbd72e0 | th_max = 1024 | th_width =   32
# ggml_metal_init: loaded kernel_sin                                    0x40dbdfb00 | th_max = 1024 | th_width =   32
# ggml_metal_init: loaded kernel_cos                                    0x40dbd4020 | th_max = 1024 | th_width =   32
# ggml_metal_init: loaded kernel_sum_rows                               0x40a8763e0 | th_max = 1024 | th_width =   32
# ggml_metal_init: loaded kernel_argmax                                 0x40ddd6dc0 | th_max = 1024 | th_width =   32
# ggml_metal_init: loaded kernel_pool_2d_avg_f32                        0x40164bce0 | th_max = 1024 | th_width =   32
# ggml_metal_init: loaded kernel_pool_2d_max_f32                        0x40164c3a0 | th_max = 1024 | th_width =   32
# llama_kv_cache_init: kv_size = 20000, offload = 1, type_k = 'f16', type_v = 'f16', n_layer = 40, can_shift = 1
# llama_kv_cache_init: layer 0: n_embd_k_gqa = 1024, n_embd_v_gqa = 1024
# llama_kv_cache_init: layer 1: n_embd_k_gqa = 1024, n_embd_v_gqa = 1024
# llama_kv_cache_init: layer 2: n_embd_k_gqa = 1024, n_embd_v_gqa = 1024
# llama_kv_cache_init: layer 3: n_embd_k_gqa = 1024, n_embd_v_gqa = 1024
# llama_kv_cache_init: layer 4: n_embd_k_gqa = 1024, n_embd_v_gqa = 1024
# llama_kv_cache_init: layer 5: n_embd_k_gqa = 1024, n_embd_v_gqa = 1024
# llama_kv_cache_init: layer 6: n_embd_k_gqa = 1024, n_embd_v_gqa = 1024
# llama_kv_cache_init: layer 7: n_embd_k_gqa = 1024, n_embd_v_gqa = 1024
# llama_kv_cache_init: layer 8: n_embd_k_gqa = 1024, n_embd_v_gqa = 1024
# llama_kv_cache_init: layer 9: n_embd_k_gqa = 1024, n_embd_v_gqa = 1024
# llama_kv_cache_init: layer 10: n_embd_k_gqa = 1024, n_embd_v_gqa = 1024
# llama_kv_cache_init: layer 11: n_embd_k_gqa = 1024, n_embd_v_gqa = 1024
# llama_kv_cache_init: layer 12: n_embd_k_gqa = 1024, n_embd_v_gqa = 1024
# llama_kv_cache_init: layer 13: n_embd_k_gqa = 1024, n_embd_v_gqa = 1024
# llama_kv_cache_init: layer 14: n_embd_k_gqa = 1024, n_embd_v_gqa = 1024
# llama_kv_cache_init: layer 15: n_embd_k_gqa = 1024, n_embd_v_gqa = 1024
# llama_kv_cache_init: layer 16: n_embd_k_gqa = 1024, n_embd_v_gqa = 1024
# llama_kv_cache_init: layer 17: n_embd_k_gqa = 1024, n_embd_v_gqa = 1024
# llama_kv_cache_init: layer 18: n_embd_k_gqa = 1024, n_embd_v_gqa = 1024
# llama_kv_cache_init: layer 19: n_embd_k_gqa = 1024, n_embd_v_gqa = 1024
# llama_kv_cache_init: layer 20: n_embd_k_gqa = 1024, n_embd_v_gqa = 1024
# llama_kv_cache_init: layer 21: n_embd_k_gqa = 1024, n_embd_v_gqa = 1024
# llama_kv_cache_init: layer 22: n_embd_k_gqa = 1024, n_embd_v_gqa = 1024
# llama_kv_cache_init: layer 23: n_embd_k_gqa = 1024, n_embd_v_gqa = 1024
# llama_kv_cache_init: layer 24: n_embd_k_gqa = 1024, n_embd_v_gqa = 1024
# llama_kv_cache_init: layer 25: n_embd_k_gqa = 1024, n_embd_v_gqa = 1024
# llama_kv_cache_init: layer 26: n_embd_k_gqa = 1024, n_embd_v_gqa = 1024
# llama_kv_cache_init: layer 27: n_embd_k_gqa = 1024, n_embd_v_gqa = 1024
# llama_kv_cache_init: layer 28: n_embd_k_gqa = 1024, n_embd_v_gqa = 1024
# llama_kv_cache_init: layer 29: n_embd_k_gqa = 1024, n_embd_v_gqa = 1024
# llama_kv_cache_init: layer 30: n_embd_k_gqa = 1024, n_embd_v_gqa = 1024
# llama_kv_cache_init: layer 31: n_embd_k_gqa = 1024, n_embd_v_gqa = 1024
# llama_kv_cache_init: layer 32: n_embd_k_gqa = 1024, n_embd_v_gqa = 1024
# llama_kv_cache_init: layer 33: n_embd_k_gqa = 1024, n_embd_v_gqa = 1024
# llama_kv_cache_init: layer 34: n_embd_k_gqa = 1024, n_embd_v_gqa = 1024
# llama_kv_cache_init: layer 35: n_embd_k_gqa = 1024, n_embd_v_gqa = 1024
# llama_kv_cache_init: layer 36: n_embd_k_gqa = 1024, n_embd_v_gqa = 1024
# llama_kv_cache_init: layer 37: n_embd_k_gqa = 1024, n_embd_v_gqa = 1024
# llama_kv_cache_init: layer 38: n_embd_k_gqa = 1024, n_embd_v_gqa = 1024
# llama_kv_cache_init: layer 39: n_embd_k_gqa = 1024, n_embd_v_gqa = 1024
# llama_kv_cache_init:      Metal KV buffer size =  3125.00 MiB
# llama_init_from_model: KV self size  = 3125.00 MiB, K (f16): 1562.50 MiB, V (f16): 1562.50 MiB
# llama_init_from_model:        CPU  output buffer size =     0.50 MiB
# llama_init_from_model:      Metal compute buffer size =  1325.07 MiB
# llama_init_from_model:        CPU compute buffer size =    49.07 MiB
# llama_init_from_model: graph nodes  = 1286
# llama_init_from_model: graph splits = 2
# Metal : EMBED_LIBRARY = 1 | CPU : NEON = 1 | ARM_FMA = 1 | FP16_VA = 1 | MATMUL_INT8 = 1 | DOTPROD = 1 | ACCELERATE = 1 | AARCH64_REPACK = 1 |
# Model metadata: {'quantize.imatrix.file': '/models_out/Mistral-Small-3.1-24B-Instruct-2503-GGUF/mistralai_Mistral-Small-3.1-24B-Instruct-2503.imatrix', 'quantize.imatrix.chunks_count': '128', 'tokenizer.chat_template': '{%- set default_system_message = "You are Mistral Small 3, a Large Language Model (LLM) created by Mistral AI, a French startup headquartered in Paris.\\nYour knowledge base was last updated on 2023-10-01.\\n\\nWhen you\'re not sure about some information, you say that you don\'t have the information and don\'t make up anything.\\nIf the user\'s question is not clear, ambiguous, or does not provide enough context for you to accurately answer the question, you do not try to answer it right away and you rather ask the user to clarify their request (e.g. \\"What are some good restaurants around me?\\" => \\"Where are you?\\" or \\"When is the next flight to Tokyo\\" => \\"Where do you travel from?\\")" %}\n\n{{- bos_token }}\n\n{%- if messages[0][\'role\'] == \'system\' %}\n    {%- set system_message = messages[0][\'content\'] %}\n    {%- set loop_messages = messages[1:] %}\n{%- else %}\n    {%- set system_message = default_system_message %}\n    {%- set loop_messages = messages %}\n{%- endif %}\n{{- \'[SYSTEM_PROMPT]\' + system_message + \'[/SYSTEM_PROMPT]\' }}\n\n{%- for message in loop_messages %}\n    {%- if message[\'role\'] == \'user\' %}\n\t    {%- if message[\'content\'] is string %}\n            {{- \'[INST]\' + message[\'content\'] + \'[/INST]\' }}\n\t    {%- else %}\n\t\t    {{- \'[INST]\' }}\n\t\t    {%- for block in message[\'content\'] %}\n\t\t\t    {%- if block[\'type\'] == \'text\' %}\n\t\t\t\t    {{- block[\'text\'] }}\n\t\t\t    {%- elif block[\'type\'] == \'image\' or block[\'type\'] == \'image_url\' %}\n\t\t\t\t    {{- \'[IMG]\' }}\n\t\t\t\t{%- else %}\n\t\t\t\t    {{- raise_exception(\'Only text and image blocks are supported in message content!\') }}\n\t\t\t\t{%- endif %}\n\t\t\t{%- endfor %}\n\t\t    {{- \'[/INST]\' }}\n\t\t{%- endif %}\n    {%- elif message[\'role\'] == \'system\' %}\n        {{- \'[SYSTEM_PROMPT]\' + message[\'content\'] + \'[/SYSTEM_PROMPT]\' }}\n    {%- elif message[\'role\'] == \'assistant\' %}\n        {{- message[\'content\'] + eos_token }}\n    {%- else %}\n        {{- raise_exception(\'Only user, system and assistant roles are supported!\') }}\n    {%- endif %}\n{%- endfor %}', 'tokenizer.ggml.add_eos_token': 'false', 'tokenizer.ggml.add_bos_token': 'true', 'tokenizer.ggml.padding_token_id': '11', 'tokenizer.ggml.unknown_token_id': '0', 'tokenizer.ggml.eos_token_id': '2', 'tokenizer.ggml.pre': 'tekken', 'tokenizer.ggml.model': 'gpt2', 'llama.attention.head_count_kv': '8', 'llama.vocab_size': '131072', 'llama.embedding_length': '5120', 'general.base_model.0.name': 'Mistral Small 3.1 24B Base 2503', 'general.size_label': '24B', 'llama.block_count': '40', 'general.base_model.0.organization': 'Mistralai', 'general.basename': 'Mistral-Small-3.1', 'general.base_model.0.version': '2503', 'llama.attention.value_length': '128', 'llama.attention.head_count': '32', 'llama.attention.key_length': '128', 'general.base_model.count': '1', 'general.quantization_version': '2', 'llama.rope.dimension_count': '128', 'general.base_model.0.repo_url': 'https://huggingface.co/mistralai/Mistral-Small-3.1-24B-Base-2503', 'general.license': 'apache-2.0', 'llama.feed_forward_length': '32768', 'llama.attention.layer_norm_rms_epsilon': '0.000010', 'tokenizer.ggml.add_space_prefix': 'false', 'general.architecture': 'llama', 'tokenizer.ggml.bos_token_id': '1', 'general.type': 'model', 'general.version': '2503', 'llama.rope.freq_base': '1000000000.000000', 'quantize.imatrix.entries_count': '280', 'llama.context_length': '131072', 'general.file_type': '23', 'general.finetune': 'Instruct', 'quantize.imatrix.dataset': '/training_dir/calibration_datav3.txt', 'general.name': 'Mistral Small 3.1 24B Instruct 2503'}
# Available chat formats from metadata: chat_template.default
# Using gguf chat template: {%- set default_system_message = "You are Mistral Small 3, a Large Language Model (LLM) created by Mistral AI, a French startup headquartered in Paris.\nYour knowledge base was last updated on 2023-10-01.\n\nWhen you're not sure about some information, you say that you don't have the information and don't make up anything.\nIf the user's question is not clear, ambiguous, or does not provide enough context for you to accurately answer the question, you do not try to answer it right away and you rather ask the user to clarify their request (e.g. \"What are some good restaurants around me?\" => \"Where are you?\" or \"When is the next flight to Tokyo\" => \"Where do you travel from?\")" %}
#
# {{- bos_token }}
#
# {%- if messages[0]['role'] == 'system' %}
#     {%- set system_message = messages[0]['content'] %}
#     {%- set loop_messages = messages[1:] %}
# {%- else %}
#     {%- set system_message = default_system_message %}
#     {%- set loop_messages = messages %}
# {%- endif %}
# {{- '[SYSTEM_PROMPT]' + system_message + '[/SYSTEM_PROMPT]' }}
#
# {%- for message in loop_messages %}
#     {%- if message['role'] == 'user' %}
# 	    {%- if message['content'] is string %}
#             {{- '[INST]' + message['content'] + '[/INST]' }}
# 	    {%- else %}
# 		    {{- '[INST]' }}
# 		    {%- for block in message['content'] %}
# 			    {%- if block['type'] == 'text' %}
# 				    {{- block['text'] }}
# 			    {%- elif block['type'] == 'image' or block['type'] == 'image_url' %}
# 				    {{- '[IMG]' }}
# 				{%- else %}
# 				    {{- raise_exception('Only text and image blocks are supported in message content!') }}
# 				{%- endif %}
# 			{%- endfor %}
# 		    {{- '[/INST]' }}
# 		{%- endif %}
#     {%- elif message['role'] == 'system' %}
#         {{- '[SYSTEM_PROMPT]' + message['content'] + '[/SYSTEM_PROMPT]' }}
#     {%- elif message['role'] == 'assistant' %}
#         {{- message['content'] + eos_token }}
#     {%- else %}
#         {{- raise_exception('Only user, system and assistant roles are supported!') }}
#     {%- endif %}
# {%- endfor %}
# Using chat eos_token: </s>
# Using chat bos_token: <s>

# %% [markdown]
#  original model used:
#  repo_id="bartowski/mistralai_Mistral-Small-3.1-24B-Instruct-2503-GGUF",
# 	filename="mistralai_Mistral-Small-3.1-24B-Instruct-2503-IQ2_M.gguf",
#
# This is the 24 billion parameter mistral model, but i changed it out for the 7 billion parameter model. we could also use a more agressive quantization for the 24 b model if it is much more accurate, ex: IQ3_XXS instead of IQ2_M
#
# repo_id="MaziyarPanahi/Mistral-7B-Instruct-v0.3-GGUF",
# 	filename="Mistral-7B-Instruct-v0.3.IQ1_M.gguf

# %%
#function to generate response from LLM using llama-cpp-python library
def generate_response(major_info, school_info, system_promot, query, k_m, k_s):
    '''retrieve relevant documents from majors and schools and generate response to user query using mistral 3 model'''

    #get documents
    major_info, school_info = retrieve_major_and_school_info(query, k_m, k_s)
    major = format_major_info_string(major_info)
    school = format_school_info_string(school_info)
    context = major + school

    #construct prompt
    prompt = f"{system_promot}\n\nContext:\n{context}\n\nQuestion: {query}"

    #generate response using llama-cpp-python
    response = llm(
        prompt=prompt,
        max_tokens=500,  # Adjust max tokens as needed
        temperature=0.3,  # Adjust temperature as needed
        top_p=0.5       # Adjust top_p as needed
        #stop=["\n"]      # Define stop tokens if necessary
    )

    return response["choices"][0]["text"].strip()

# %% [markdown]
# ## Using transformers library

# %% [raw]
# #load model and tokenizer, reuqires linux os to work
# from transformers import LlamaTokenizer  # not AutoTokenizer
#
# tokenizer = LlamaTokenizer.from_pretrained(
#     "RedHatAI/Mistral-7B-Instruct-v0.3-GPTQ-4bit",
#     trust_remote_code=True
# )
# model = AutoModelForCausalLM.from_pretrained(
#     "RedHatAI/Mistral-7B-Instruct-v0.3-GPTQ-4bit",
#     trust_remote_code=True,
#     device_map="auto"  # will place model on GPU if available
# )

# %% [raw]
# #function to generate response from LLM using transformers library
# def generate_response(query, k_m, k_s):
#     '''retrieve relevant documents from majors and schools and generate response to user query using mistral 3 model'''
#
#     #get documents
#     major_info, school_info = retrieve_major_and_school_info(query, k_m, k_s)
#     major = format_major_info_string(major_info)
#     school = format_school_info_string(school_info)
#     context = major + school
#
#     #construct message
#     messages = [
#         {'role': 'system', 'content': SYSTEM_PROMPT},
#         {'role':'user', 'content' : f"Context:\n{context}\n\nQuestion: {query}"}
#     ]
#
#     #process input for mistral
#     text = processor.apply_chat_template(messages, tokenize = False, add_generation_prompt=True)
#     inputs = processor(text=text, return_tensors='pt').to(torch_device, dtype = torch.float32)
#
#     #generate response
#     generate_id = model.generate(**inputs, max_new_tokens = 200, do_sample = False)
#     decoded_output = processor.batch_decode(generate_id[:,inputs['input_ids'].shape[1]:], skip_special_tokens = True)[0]
#
#     return decoded_output
#
#
#
#     from transformers import AutoTokenizer, AutoModelForCausalLM
# import torch
#
# # Load the tokenizer and model for text generation
# tokenizer = AutoTokenizer.from_pretrained("gpt2")  # Replace "gpt2" with your model
# model = AutoModelForCausalLM.from_pretrained("gpt2").to("cuda" if torch.cuda.is_available() else "cpu")
#
# def two_step_retrieve_and_generate_response(system_prompt1, system_prompt2, query, k_m=10, k_s=5, k_c=20):
#     # Step 1: Retrieve major and school related documents
#     major_info, school_info = retrieve_major_and_school_info(query, k_m, k_s)
#
#     # Step 2: Generate response for major and school context
#     initial_prompt = f"{system_prompt1}\n\nMajor Context:\n{major_info}\n\nSchool Context:\n{school_info}\n\nUser Query: {query}"
#     inputs = tokenizer(initial_prompt, return_tensors="pt").to(model.device)
#     outputs = model.generate(inputs["input_ids"], max_length=200, temperature=0.3, top_p=0.5)
#     response = tokenizer.decode(outputs[0], skip_special_tokens=True)
#
#     # Step 3: Retrieve class-related documents using the initial response
#     response_embedding = model.encode(response).tolist()  # Replace with your embedding model
#     class_info = []
#     class_results = collection_classes.query(
#         query_embeddings=[response_embedding],
#         where={"Type": "Class"},  # Filter for class-related documents
#         n_results=k_c
#     )
#     class_info = class_results["metadatas"][0]
#
#     # Step 4: Feed class documents to the LLM along with previous context
#     class_context = format_class_info_string(class_info)
#     final_prompt = f"{system_prompt2}\n\nMajor Context:\n{major_info}\n\nSchool Context:\n{school_info}\n\nClass Context:\n{class_context}\n\nUser Query: {query}"
#     inputs = tokenizer(final_prompt, return_tensors="pt").to(model.device)
#     outputs = model.generate(inputs["input_ids"], max_length=2000, temperature=0.3, top_p=0.5)
#     final_response = tokenizer.decode(outputs[0], skip_special_tokens=True)
#
#     return final_response
#
#
# from transformers import AutoTokenizer, AutoModelForCausalLM
# import torch
#
# # Load the tokenizer and model for text generation
# tokenizer = AutoTokenizer.from_pretrained("RedHatAI/Mistral-7B-Instruct-v0.3-GPTQ-4bit")  # Replace with your model
# model = AutoModelForCausalLM.from_pretrained("RedHatAI/Mistral-7B-Instruct-v0.3-GPTQ-4bit").to("cuda" if torch.cuda.is_available() else "cpu")
#
# def two_step_retrieve_and_generate_response_transformers(system_prompt1, system_prompt2, query, k_m=10, k_s=5, k_c=20):
#     # Step 1: Retrieve major and school related documents
#     major_info, school_info = retrieve_major_and_school_info(query, k_m, k_s)
#
#     # Step 2: Generate response for major and school context
#     major_context = format_major_info_string(major_info)
#     school_context = format_school_info_string(school_info)
#     initial_prompt = f"{system_prompt1}\n\nMajor Context:\n{major_context}\n\nSchool Context:\n{school_context}\n\nUser Query: {query}"
#
#     # Tokenize and generate response
#     inputs = tokenizer(initial_prompt, return_tensors="pt").to(model.device)
#     outputs = model.generate(inputs["input_ids"], max_length=500, temperature=0.3, top_p=0.5)
#     response = tokenizer.decode(outputs[0], skip_special_tokens=True)
#
#     # Step 3: Retrieve class-related documents using the initial response
#     response_embedding = model.encode(response).tolist()  # Replace with your embedding model
#     class_results = collection_classes.query(
#         query_embeddings=[response_embedding],
#         where={"Type": "Class"},  # Filter for class-related documents
#         n_results=k_c
#     )
#     class_info = class_results["metadatas"][0]
#
#     # Step 4: Feed class documents to the LLM along with previous context
#     class_context = format_class_info_string(class_info)
#     final_prompt = f"{system_prompt2}\n\nMajor Context:\n{major_context}\n\nSchool Context:\n{school_context}\n\nClass Context:\n{class_context}\n\nUser Query: {query}"
#
#     # Tokenize and generate final response
#     inputs = tokenizer(final_prompt, return_tensors="pt").to(model.device)
#     outputs = model.generate(inputs["input_ids"], max_length=2000, temperature=0.3, top_p=0.5)
#     final_response = tokenizer.decode(outputs[0], skip_special_tokens=True)
#
#     return final_response

# %% [markdown]
# # 2nd Step of RAG
#
# here I will call previous functions that retrieve major and school info, generate a response and use that tho retrieve the classes and then generate a response again.

# %%
SYSTEM_PROMPT_2 = """
You are a University of Virginia undergraduate course scheduler.
Use the given context to create a course schedule based on the user query.
The schedule should include corse names, course numbers, required prerequisites, course times, instructors, room, units, and any other relevant information.
Make sure  the output is clear, concise and easy to read in a table format and make sure none of the times slots overlap.
If a class has more than one time, choose one that does not overlap with other classes.
A full time student should have between 12-15 credits per semester. No classes should be repeated on one schedule. When it comes to courses like Special Topics, Independent Study, or Research, please highlight that this is not a standard course.
A third or fourth year student should not be given all introductory classes and a first year or second year student should not have all high level classes.
The schedule should include optional courses, online/hybrid options, or specific time preferences.
The user may also ask for specific professors, days of the week, or specific courses.
Please use a professional tone and avoid any unnecessary information.

"""

# %%
def two_step_retrieve_and_generate_response(system_prompt1, system_prompt2, query, k_m=10, k_s=5, k_c=20):
    # Step 1: Retrieve major and school related documents
    major_info, school_info = retrieve_major_and_school_info(query, k_m, k_s)
    
    #Step 2: generate response
    response = generate_response(major_info, school_info, system_prompt1, query, k_m, k_s)


    # Step 3: Retrieve class-related documents using the initial response
    response_embedding = model.encode(response).tolist()
    class_info = []
    class_results = collection_classes.query(
        query_embeddings=[response_embedding],
        where={"Type": "Class"},  # Filter for class-related documents
        n_results=k_c
    )
    class_info = class_results["metadatas"][0]


    # Step 4: Feed class documents to the LLM along with previous
    class_context = format_class_info_string(class_info)
    final_prompt = f"{system_prompt2}\n\nMajor Context:\n{major_info}\n\nSchool Context :\n{school_info}\n\nClass Context:\n{class_context}\n\nUser Query: {query}\n\n. Generate a response."
    final_response = llm(
        prompt=final_prompt,
        max_tokens=2000,  # Adjust max tokens as needed
        temperature=0.3,  # Adjust temperature as needed
        top_p=0.5       # Adjust top_p as needed
        #stop=["\n"]      # Define stop tokens if necessary
    )

    return final_response

# %%
schedule = two_step_retrieve_and_generate_response(SYSTEM_PROMPT_1, SYSTEM_PROMPT_2, "second year biology major fall 2025", 10, 5, 20)
# Out:
# Llama.generate: 1 prefix-match hit, remaining 6081 prompt tokens to eval
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[56], line 1
# ----> 1 schedule = two_step_retrieve_and_generate_response(SYSTEM_PROMPT_1, SYSTEM_PROMPT_2, "second year biology major fall 2025", 10, 5, 20)
#
# Cell In[45], line 6, in two_step_retrieve_and_generate_response(system_prompt1, system_prompt2, query, k_m, k_s, k_c)
#       3 major_info, school_info = retrieve_major_and_school_info(query, k_m, k_s)
#       5 #Step 2: generate response
# ----> 6 response = generate_response(major_info, school_info, system_prompt1, query, k_m, k_s)
#       9 # Step 3: Retrieve class-related documents using the initial response
#      10 response_embedding = model.encode(response).tolist()
#
# Cell In[35], line 15, in generate_response(major_info, school_info, system_promot, query, k_m, k_s)
#      12 prompt = f"{system_promot}\n\nContext:\n{context}\n\nQuestion: {query}"
#      14 #generate response using llama-cpp-python
# ---> 15 response = llm(
#      16     prompt=prompt,
#      17     max_tokens=500,  # Adjust max tokens as needed
#      18     temperature=0.3,  # Adjust temperature as needed
#      19     top_p=0.5       # Adjust top_p as needed
#      20     #stop=["\n"]      # Define stop tokens if necessary
#      21 )
#      23 return response["choices"][0]["text"].strip()
#
# File ~/miniconda3/lib/python3.12/site-packages/llama_cpp/llama.py:1902, in Llama.__call__(self, prompt, suffix, max_tokens, temperature, top_p, min_p, typical_p, logprobs, echo, stop, frequency_penalty, presence_penalty, repeat_penalty, top_k, stream, seed, tfs_z, mirostat_mode, mirostat_tau, mirostat_eta, model, stopping_criteria, logits_processor, grammar, logit_bias)
#    1838 def __call__(
#    1839     self,
#    1840     prompt: str,
#    (...)
#    1864     logit_bias: Optional[Dict[int, float]] = None,
#    1865 ) -> Union[CreateCompletionResponse, Iterator[CreateCompletionStreamResponse]]:
#    1866     """Generate text from a prompt.
#    1867
#    1868     Args:
#    (...)
#    1900         Response object containing the generated text.
#    1901     """
# -> 1902     return self.create_completion(
#    1903         prompt=prompt,
#    1904         suffix=suffix,
#    1905         max_tokens=max_tokens,
#    1906         temperature=temperature,
#    1907         top_p=top_p,
#    1908         min_p=min_p,
#    1909         typical_p=typical_p,
#    1910         logprobs=logprobs,
#    1911         echo=echo,
#    1912         stop=stop,
#    1913         frequency_penalty=frequency_penalty,
#    1914         presence_penalty=presence_penalty,
#    1915         repeat_penalty=repeat_penalty,
#    1916         top_k=top_k,
#    1917         stream=stream,
#    1918         seed=seed,
#    1919         tfs_z=tfs_z,
#    1920         mirostat_mode=mirostat_mode,
#    1921         mirostat_tau=mirostat_tau,
#    1922         mirostat_eta=mirostat_eta,
#    1923         model=model,
#    1924         stopping_criteria=stopping_criteria,
#    1925         logits_processor=logits_processor,
#    1926         grammar=grammar,
#    1927         logit_bias=logit_bias,
#    1928     )
#
# File ~/miniconda3/lib/python3.12/site-packages/llama_cpp/llama.py:1835, in Llama.create_completion(self, prompt, suffix, max_tokens, temperature, top_p, min_p, typical_p, logprobs, echo, stop, frequency_penalty, presence_penalty, repeat_penalty, top_k, stream, seed, tfs_z, mirostat_mode, mirostat_tau, mirostat_eta, model, stopping_criteria, logits_processor, grammar, logit_bias)
#    1833     chunks: Iterator[CreateCompletionStreamResponse] = completion_or_chunks
#    1834     return chunks
# -> 1835 completion: Completion = next(completion_or_chunks)  # type: ignore
#    1836 return completion
#
# File ~/miniconda3/lib/python3.12/site-packages/llama_cpp/llama.py:1320, in Llama._create_completion(self, prompt, suffix, max_tokens, temperature, top_p, min_p, typical_p, logprobs, echo, stop, frequency_penalty, presence_penalty, repeat_penalty, top_k, stream, seed, tfs_z, mirostat_mode, mirostat_tau, mirostat_eta, model, stopping_criteria, logits_processor, grammar, logit_bias)
#    1318 finish_reason = "length"
#    1319 multibyte_fix = 0
# -> 1320 for token in self.generate(
#    1321     prompt_tokens,
#    1322     top_k=top_k,
#    1323     top_p=top_p,
#    1324     min_p=min_p,
#    1325     typical_p=typical_p,
#    1326     temp=temperature,
#    1327     tfs_z=tfs_z,
#    1328     mirostat_mode=mirostat_mode,
#    1329     mirostat_tau=mirostat_tau,
#    1330     mirostat_eta=mirostat_eta,
#    1331     frequency_penalty=frequency_penalty,
#    1332     presence_penalty=presence_penalty,
#    1333     repeat_penalty=repeat_penalty,
#    1334     stopping_criteria=stopping_criteria,
#    1335     logits_processor=logits_processor,
#    1336     grammar=grammar,
#    1337 ):
#    1338     if llama_cpp.llama_token_is_eog(self._model.vocab, token):
#    1339         text = self.detokenize(completion_tokens, prev_tokens=prompt_tokens)
#
# File ~/miniconda3/lib/python3.12/site-packages/llama_cpp/llama.py:912, in Llama.generate(self, tokens, top_k, top_p, min_p, typical_p, temp, repeat_penalty, reset, frequency_penalty, presence_penalty, tfs_z, mirostat_mode, mirostat_tau, mirostat_eta, penalize_nl, logits_processor, stopping_criteria, grammar)
#     910 # Eval and sample
#     911 while True:
# --> 912     self.eval(tokens)
#     913     while sample_idx < self.n_tokens:
#     914         token = self.sample(
#     915             top_k=top_k,
#     916             top_p=top_p,
#    (...)
#     930             idx=sample_idx,
#     931         )
#
# File ~/miniconda3/lib/python3.12/site-packages/llama_cpp/llama.py:646, in Llama.eval(self, tokens)
#     642 n_tokens = len(batch)
#     643 self._batch.set_batch(
#     644     batch=batch, n_past=n_past, logits_all=self.context_params.logits_all
#     645 )
# --> 646 self._ctx.decode(self._batch)
#     647 # Save tokens
#     648 self.input_ids[n_past : n_past + n_tokens] = batch
#
# File ~/miniconda3/lib/python3.12/site-packages/llama_cpp/_internals.py:306, in LlamaContext.decode(self, batch)
#     305 def decode(self, batch: LlamaBatch):
# --> 306     return_code = llama_cpp.llama_decode(
#     307         self.ctx,
#     308         batch.batch,
#     309     )
#     310     if return_code != 0:
#     311         raise RuntimeError(f"llama_decode returned {return_code}")
#
# KeyboardInterrupt:

# %%
print(schedule["choices"][0]["text"].strip())
# Out:
# The capital of Russia is Moscow.
