# %%
#import required packages
import pandas as pd
import requests
import pdfkit
import os
import numpy as np
import csv
import numpy as np
from bs4 import BeautifulSoup
import time

# %%
# URL of the main catalog page
base_url = "https://records.ureg.virginia.edu/"
main_url = base_url + "content.php?catoid=61&navoid=5303"

# Function to fetch HTML content
def get_soup(url):
    headers = {"User-Agent": "Mozilla/5.0"}
    response = requests.get(url, headers=headers)
    if response.status_code == 200:
        return BeautifulSoup(response.text, "html.parser")
    else:
        print(f"Failed to fetch {url}")
        return None

# Step 1: Get all major links
soup = get_soup(main_url)
major_links = []

if soup:
    table = soup.find("table", class_="table_default")
    if table:
        for row in table.find_all("tr")[1:]:  # Skip header row
            link_tag = row.find("a")  # Find first column link
            if link_tag:
                major_name = link_tag.text.strip()
                major_url = base_url + link_tag["href"].replace("&amp;", "&")
                major_links.append((major_name, major_url))

# Step 2: Visit each major page and extract data
data = []

for major_name, major_url in major_links:
    print(f"Scraping: {major_name}")
    soup = get_soup(major_url)
    
    if soup:
        table = soup.find("table", class_="table_default")
        
        if table:
            text = " ".join(table.stripped_strings)  # Extract all text
            data.append({"Major": major_name, "Text": text})
    
    time.sleep(1)  # Politeness delay

# Step 3: Save data to CSV
df = pd.DataFrame(data)
df.to_csv("uva_majors.csv", index=False)

print("Scraping complete! Data saved to 'uva_majors.csv'.")
# Out:
# Scraping: Advanced Search
# Scraping: Advanced Search
# Scraping: Advanced Search
# Scraping: Catalog Home
# Scraping: Catalog Home
# Scraping: HELP
# Scraping: HELP
# Scraping: Architectural History, B.Ar.H.
# Scraping: Architectural History, B.Ar.H.
# Scraping: Architecture, B.S.
# Scraping: Urban and Environmental Planning, B.U.E.P.
# Scraping: African-American and African Studies, B.A.
# Scraping: Anthropology, B.A.
# Scraping: Applied Statistics, B.A.
# Scraping: Area Studies, B.A.
# Scraping: Art History
# Scraping: Studio Art
# Scraping: Astronomy, B.A.
# Scraping: Astronomy, B.S.
# Scraping: Behavioral Neuroscience, B.S.
# Scraping: Biology, B.A.
# Scraping: Biology, B.S.
# Scraping: Chemistry, B.A.
# Scraping: Chemistry, B.S.
# Scraping: Classics, B.A.
# Scraping: Computer Science, B.A.
# Scraping: Drama, B.A.
# Scraping: Economics, B.A.
# Scraping: English, B.A.
# Scraping: Environmental Sciences, B.A.
# Scraping: Environmental Sciences, B.S.
# Scraping: Foreign Affairs, B.A.
# Scraping: French, B.A.
# Scraping: German, B.A.
# Scraping: Government, B.A.
# Scraping: History, B.A.
# Scraping: Interdisciplinary - American Studies
# Scraping: Interdisciplinary - Archaeology
# Scraping: Interdisciplinary - Chinese Language & Literature
# Scraping: Interdisciplinary - Cognitive Science
# Scraping: Interdisciplinary - East Asian Studies
# Scraping: Interdisciplinary - Environmental Thought & Practice
# Scraping: Interdisciplinary - German Studies
# Scraping: Interdisciplinary - Global Studies
# Scraping: Interdisciplinary - Human Biology
# Scraping: Interdisciplinary - Japanese Language & Literature
# Scraping: Interdisciplinary - Jewish Studies
# Scraping: Interdisciplinary - Linguistics
# Scraping: Interdisciplinary - Medieval Studies
# Scraping: Interdisciplinary - Middle Eastern Languages and Literatures
# Scraping: Interdisciplinary - Middle Eastern Studies
# Scraping: Interdisciplinary - Neuroscience
# Scraping: Interdisciplinary - Political & Social Thought
# Scraping: Interdisciplinary - Political Philosophy, Policy, & Law
# Scraping: Interdisciplinary - South Asian Languages and Literatures
# Scraping: Interdisciplinary - South Asian Studies
# Scraping: Interdisciplinary - Women, Gender, and Sexuality
# Scraping: Italian, B.A.
# Scraping: Mathematics, B.A.
# Scraping: Media Studies, B.A.
# Scraping: Music, B.A.
# Scraping: Philosophy, B.A.
# Scraping: Physics, B.A.
# Scraping: Physics, B.S.
# Scraping: Psychology, B.A.
# Scraping: Religious Studies, B.A.
# Scraping: Slavic Languages and Literatures, B.A.
# Scraping: Sociology, B.A.
# Scraping: Spanish, B.A.
# Scraping: Statistics, B.S.
# Scraping: Bachelor of Science in Commerce, B.S.C.
# Scraping: Bachelor of Professional Studies in Health Sciences Management, B.P.S.
# Scraping: Bachelor of Interdisciplinary Studies, B.I.S.
# Scraping: Data Science, B.S.
# Scraping: Elementary Education , B.S.Ed.
# Scraping: Early Childhood Education , B.S.Ed.
# Scraping: Special Education, B.S.Ed.
# Scraping: Kinesiology, B.S.Ed.
# Scraping: Speech Communication Disorders, B.S.Ed.
# Scraping: Youth and Social Innovation, B.S.Ed.
# Scraping: Aerospace Engineering, B.S.
# Scraping: Biomedical Engineering, B.S.
# Scraping: Chemical Engineering, B.S.
# Scraping: Civil Engineering, B.S.
# Scraping: Computer Engineering, B.S.
# Scraping: Computer Science, B.S.
# Scraping: Electrical Engineering, B.S.
# Scraping: Engineering Science, B.S.
# Scraping: Materials Science and Engineering, B.S.
# Scraping: Mechanical Engineering, B.S.
# Scraping: Systems Engineering, B.S.
# Scraping: Public Policy and Leadership, B.A.
# Scraping: Nursing, B.S.N.
# Scraping: catalogs
# Scraping complete! Data saved to 'uva_majors.csv'.

# %%
#read in csv
majors = pd.read_csv("uva_majors.csv")

#remove the first 8 rows and last row because they are not needed
majors = majors.iloc[8:-1]

#print the first 5 rows
majors
# Out:
#                                          Major  \
# 8               Architectural History, B.Ar.H.
# 9                           Architecture, B.S.
# 10  Urban and Environmental Planning, B.U.E.P.
# 11  African-American and African Studies, B.A.
# 12                          Anthropology, B.A.
# ..                                         ...
# 88     Materials Science and Engineering, B.S.
# 89                Mechanical Engineering, B.S.
# 90                   Systems Engineering, B.S.
# 91          Public Policy and Leadership, B.A.
# 92                             Nursing, B.S.N.
#
#                                                  Text
# 8   Info For Students Alumni Military Affiliated S...
# 9   Info For Students Alumni Military Affiliated S...
# 10  Info For Students Alumni Military Affiliated S...
# 11  Info For Students Alumni Military Affiliated S...
# 12  Info For Students Alumni Military Affiliated S...
# ..                                                ...
# 88  Info For Students Alumni Military Affiliated S...
# 89  Info For Students Alumni Military Affiliated S...
# 90  Info For Students Alumni Military Affiliated S...
# 91  Info For Students Alumni Military Affiliated S...
# 92  Info For Students Alumni Military Affiliated S...
#
# [85 rows x 2 columns]

# %%
# remove the extra text from the text column
test = 'Info For Students Alumni Military Affiliated Students Faculty & Staff Search Search Submit Search Close search Info For Students Alumni Military Affiliated Students Faculty & Staff Calendars Academic Calendars Exam Schedules Student Records Diplomas Transcripts FERPA Programs Calendar Schools University Registrar Carruthers Hall, 1001 N. Emmet St. P.O. Box 400203 Charlottesville, VA 22904-4203 Staff Directory Contact Info Phone: (434) 924-4122 Fax: (434) 924-4156 Email: [email protected] Hours Of Operation M-F: 10am - noon and 1pm - 4pm Â© 2024 By the Rector and Visitors of the University of Virginia Legal Privacy Report a Barrier Share Your Feedback University of Virginia Mar 31, 2025 Undergraduate Record 2024-2025 Select a Catalog Undergraduate Record 2024-2025 Graduate Record 2024-2025 Global Search Catalog Search Choose Search Location Select an option Courses Programs Schools/Colleges & Departments Policies and Other Non-Academic Content Entire Catalog Search Keyword Field Whole Word/Phrase Advanced Search Catalog Navigation Catalog Home Academic Calendar Admission Schools Programs, Degrees & Course Info Student Resources ROTC University Regulations About UVA Archived Records HELP Undergraduate Record 2024-2025'
text_to_remove_head = 'Info For Students Alumni Military Affiliated Students Faculty & Staff Search Search Submit Search Close search Info For Students Alumni Military Affiliated Students Faculty & Staff Calendars Academic Calendars Exam Schedules Student Records Diplomas Transcripts FERPA Programs Calendar Schools University Registrar Carruthers Hall, 1001 N. Emmet St. P.O. Box 400203 Charlottesville, VA 22904-4203 Staff Directory Contact Info Phone: (434) 924-4122 Fax: (434) 924-4156 Email: [email protected] Hours Of Operation M-F: 10am - noon and 1pm - 4pm Â© 2024 By the Rector and Visitors of the University of Virginia Legal Privacy Report a Barrier Share Your Feedback University of Virginia Mar 12, 2025 Undergraduate Record 2024-2025 Select a Catalog Undergraduate Record 2024-2025 Graduate Record 2024-2025 Global Search Catalog Search Choose Search Location Select an option Courses Programs Schools/Colleges & Departments Policies and Other Non-Academic Content Entire Catalog Search Keyword Field Whole Word/Phrase Advanced Search Catalog Navigation Catalog Home Academic Calendar Admission Schools Programs, Degrees & Course Info Student Resources ROTC University Regulations About UVA Archived Records HELP Undergraduate Record 2024-2025' 
text_to_remove_tail = 'Back to Top | Print-Friendly Page (opens a new window) All catalogs © 2025 University of Virginia. Powered by Modern Campus Catalog™ . .'
#function to remove the text
def remove_text(text):
    if text.startswith(text_to_remove_head):
        text = text[len(text_to_remove_head):]
    if text.startswith(test):
        text = text[len(test):]
    if text.endswith(text_to_remove_tail):
        text = text[:-len(text_to_remove_tail)]
    return text.strip()

#apply the function to the text column
majors['Text'] = majors['Text'].apply(remove_text)

#since some of the majors have extra text that is a bit different, we need to remove it
majors[majors['Major'] == 'Psychology, B.A.']['Text']

majors[50:90]
# Out:
#                                                 Major  \
# 58                                  Mathematics, B.A.
# 59                                Media Studies, B.A.
# 60                                        Music, B.A.
# 61                                   Philosophy, B.A.
# 62                                      Physics, B.A.
# 63                                      Physics, B.S.
# 64                                   Psychology, B.A.
# 65                            Religious Studies, B.A.
# 66             Slavic Languages and Literatures, B.A.
# 67                                    Sociology, B.A.
# 68                                      Spanish, B.A.
# 69                                   Statistics, B.S.
# 70            Bachelor of Science in Commerce, B.S.C.
# 71  Bachelor of Professional Studies in Health Sci...
# 72      Bachelor of Interdisciplinary Studies, B.I.S.
# 73                                 Data Science, B.S.
# 74                     Elementary Education , B.S.Ed.
# 75                Early Childhood Education , B.S.Ed.
# 76                         Special Education, B.S.Ed.
# 77                               Kinesiology, B.S.Ed.
# 78            Speech Communication Disorders, B.S.Ed.
# 79               Youth and Social Innovation, B.S.Ed.
# 80                        Aerospace Engineering, B.S.
# 81                       Biomedical Engineering, B.S.
# 82                         Chemical Engineering, B.S.
# 83                            Civil Engineering, B.S.
# 84                         Computer Engineering, B.S.
# 85                             Computer Science, B.S.
# 86                       Electrical Engineering, B.S.
# 87                          Engineering Science, B.S.
# 88            Materials Science and Engineering, B.S.
# 89                       Mechanical Engineering, B.S.
# 90                          Systems Engineering, B.S.
# 91                 Public Policy and Leadership, B.A.
# 92                                    Nursing, B.S.N.
#
#                                                  Text
# 58  Mathematics, B.A. Print-Friendly Page (opens a...
# 59  Media Studies, B.A. Print-Friendly Page (opens...
# 60  Music, B.A. Print-Friendly Page (opens a new w...
# 61  Philosophy, B.A. Print-Friendly Page (opens a ...
# 62  Physics, B.A. Print-Friendly Page (opens a new...
# 63  Physics, B.S. Print-Friendly Page (opens a new...
# 64  Psychology, B.A. Print-Friendly Page (opens a ...
# 65  Religious Studies, B.A. Print-Friendly Page (o...
# 66  Slavic Languages and Literatures, B.A. Print-F...
# 67  Sociology, B.A. Print-Friendly Page (opens a n...
# 68  Spanish, B.A. Print-Friendly Page (opens a new...
# 69  Statistics, B.S. Print-Friendly Page (opens a ...
# 70  Commerce, B.S.C. Print-Friendly Page (opens a ...
# 71  Bachelor of Professional Studies in Health Sci...
# 72  Bachelor of Interdisciplinary Studies, B.I.S. ...
# 73  Data Science, B.S. Print-Friendly Page (opens ...
# 74  Elementary Education, B.S.Ed. Print-Friendly P...
# 75  Early Childhood Education, B.S.Ed. Print-Frien...
# 76  Special Education (BSEd) Print-Friendly Page (...
# 77  Kinesiology (BSEd) Print-Friendly Page (opens ...
# 78  Speech Communication Disorders (BSEd) Print-Fr...
# 79  Youth & Social Innovation (BSEd) Print-Friendl...
# 80  Aerospace Engineering, B.S. Print-Friendly Pag...
# 81  Biomedical Engineering, B.S. Print-Friendly Pa...
# 82  Chemical Engineering, B.S. Print-Friendly Page...
# 83  Civil Engineering, B.S. Print-Friendly Page (o...
# 84  Computer Engineering, B.S. Print-Friendly Page...
# 85  Computer Science B.S. Print-Friendly Page (ope...
# 86  Electrical Engineering, B.S. Print-Friendly Pa...
# 87  Engineering Science, B.S. Print-Friendly Page ...
# 88  Materials Science and Engineering, B.S. Print-...
# 89  Mechanical Engineering, B.S. Print-Friendly Pa...
# 90  Systems Engineering, B.S. Print-Friendly Page ...
# 91  Public Policy and Leadership, B.A. Print-Frien...
# 92  Nursing, B.S.N. Print-Friendly Page (opens a n...

# %%
# remove extra text from the majors column where majors includes "interdisciplinary"
text_to_remove = 'Interdisciplinary Major - '
def remove_text_majors(text):
    if text.startswith(text_to_remove):
        text = text[len(text_to_remove):]
    return text.strip()

#apply the function to the majors column
majors['Major'] = majors['Major'].apply(remove_text_majors)

# %%
majors[:40]
# Out:
#                                          Major  \
# 8               Architectural History, B.Ar.H.
# 9                           Architecture, B.S.
# 10  Urban and Environmental Planning, B.U.E.P.
# 11  African-American and African Studies, B.A.
# 12                          Anthropology, B.A.
# 13                    Applied Statistics, B.A.
# 14                          Area Studies, B.A.
# 15                                 Art History
# 16                                  Studio Art
# 17                             Astronomy, B.A.
# 18                             Astronomy, B.S.
# 19               Behavioral Neuroscience, B.S.
# 20                               Biology, B.A.
# 21                               Biology, B.S.
# 22                             Chemistry, B.A.
# 23                             Chemistry, B.S.
# 24                              Classics, B.A.
# 25                      Computer Science, B.A.
# 26                                 Drama, B.A.
# 27                             Economics, B.A.
# 28                               English, B.A.
# 29                Environmental Sciences, B.A.
# 30                Environmental Sciences, B.S.
# 31                       Foreign Affairs, B.A.
# 32                                French, B.A.
# 33                                German, B.A.
# 34                            Government, B.A.
# 35                               History, B.A.
# 36                            American Studies
# 37                                 Archaeology
# 38               Chinese Language & Literature
# 39                           Cognitive Science
# 40                          East Asian Studies
# 41            Environmental Thought & Practice
# 42                              German Studies
# 43                              Global Studies
# 44                               Human Biology
# 45              Japanese Language & Literature
# 46                              Jewish Studies
# 47                                 Linguistics
#
#                                                  Text
# 8   Architectural History, B.Ar.H. Print-Friendly ...
# 9   Architecture, B.S. Print-Friendly Page (opens ...
# 10  Urban and Environmental Planning, B.U.E.P. Pri...
# 11  African American and African Studies, B.A. Pri...
# 12  Anthropology, B.A. Print-Friendly Page (opens ...
# 13  Applied Statistics, B.A. Print-Friendly Page (...
# 14  Area Studies, B.A. Print-Friendly Page (opens ...
# 15  History of Art Print-Friendly Page (opens a ne...
# 16  Studio Art Print-Friendly Page (opens a new wi...
# 17  Astronomy, B.A. Print-Friendly Page (opens a n...
# 18  Astronomy, B.S. Print-Friendly Page (opens a n...
# 19  Behavioral Neuroscience, B.S. Print-Friendly P...
# 20  Biology, B.A. Print-Friendly Page (opens a new...
# 21  Biology, B.S. Print-Friendly Page (opens a new...
# 22  Chemistry, B.A. Print-Friendly Page (opens a n...
# 23  Chemistry, B.S. Print-Friendly Page (opens a n...
# 24  Classics, B.A. Print-Friendly Page (opens a ne...
# 25  Computer Science, B.A. Print-Friendly Page (op...
# 26  Drama, B.A. Print-Friendly Page (opens a new w...
# 27  Economics, B.A. Print-Friendly Page (opens a n...
# 28  English, B.A. Print-Friendly Page (opens a new...
# 29  Environmental Sciences, B.A. Print-Friendly Pa...
# 30  Environmental Sciences, B.S. Print-Friendly Pa...
# 31  Foreign Affairs, B.A. Print-Friendly Page (ope...
# 32  French, B.A. Print-Friendly Page (opens a new ...
# 33  German, B.A. Print-Friendly Page (opens a new ...
# 34  Government, B.A. Print-Friendly Page (opens a ...
# 35  History, B.A. Print-Friendly Page (opens a new...
# 36  Interdisciplinary Major - American Studies Pri...
# 37  Interdisciplinary Major - Archaeology Print-Fr...
# 38  Interdisciplinary Major - Chinese Language & L...
# 39  Interdisciplinary Major - Cognitive Science Pr...
# 40  Interdisciplinary Major - East Asian Studies P...
# 41  Interdisciplinary Major - Environmental Though...
# 42  Interdisciplinary Major - German Studies Print...
# 43  Interdisciplinary Major - Global Studies Print...
# 44  Interdisciplinary Major - Human Biology Print-...
# 45  Interdisciplinary Major - Japanese Language & ...
# 46  Interdisciplinary Major - Jewish Studies Print...
# 47  Interdisciplinary Major - Linguistics Print-Fr...

# %%
# get school requirements



# Define the main URL
url = "https://records.ureg.virginia.edu/content.php?catoid=61&navoid=5916"

# Send a request to the main page
response = requests.get(url)
soup = BeautifulSoup(response.content, "html.parser")

# Find all the links for schools
school_links = soup.find_all('a', class_='card-link')

# Loop through each school link
for link in school_links:
    school_url = link.get('href')
    full_url = f"https://records.ureg.virginia.edu/{school_url}"
    
    # Send a request to each school page
    school_response = requests.get(full_url)
    school_soup = BeautifulSoup(school_response.content, "html.parser")
    
    # Find and click on "Academic Rules" link
    academic_rules_link = school_soup.find('a', string='Academic Rules')
    if academic_rules_link:
        academic_rules_url = f"https://records.ureg.virginia.edu/{academic_rules_link.get('href')}"
        
        # Send a request to the Academic Rules page
        academic_response = requests.get(academic_rules_url)
        academic_soup = BeautifulSoup(academic_response.content, "html.parser")
        
        # Find the table and print its content
        table = academic_soup.find('table', {'class': 'table default'})
        if table:
            rows = table.find_all('tr')
            for row in rows:
                columns = row.find_all('td')
                for column in columns:
                    print(column.get_text(strip=True))

# %%
# URL of the main catalog page
base_url = "https://records.ureg.virginia.edu/"
main_url = base_url + "content.php?catoid=61&navoid=5916"

# Function to fetch HTML content
def get_soup(url):
    headers = {"User-Agent": "Mozilla/5.0"}
    response = requests.get(url, headers=headers)
    if response.status_code == 200:
        return BeautifulSoup(response.text, "html.parser")
    else:
        print(f"Failed to fetch {url}")
        return None

# Step 1: Get all school links
soup = get_soup(main_url)
school_links = []

if soup:
    # Find all school links
    grid_items = soup.find_all("div", class_="cgw-grid-item")

    if not grid_items:
        print("no grid items found")
    else:
        for item in grid_items:
            school_name = item.find("h3").text.strip() if item.find("h3") else "unknown"

            link_tag = item.find("a", href=True)
            if link_tag:    
                school_url = link_tag["href"].replace("&amp;", "&")
                school_links.append((school_name, school_url))
                print(f"Found link: {school_name} -> {school_url}")  # Debug print


print(f"Found {len(school_links)} schools.")
for school_name, school_url in school_links:
    print(f"School: {school_name}, URL: {school_url}")


# Step 2: Visit each school page and extract data from the "Academic Rules"
data = []

for school_name, school_url in school_links:
    print(f"Scraping: {school_name}")
    soup = get_soup(school_url)
    
    if soup:
        academic_rules_link = soup.find("a", string="Academic Rules")
        
        if academic_rules_link:
            academic_rules_url = base_url + academic_rules_link.get("href").replace("&amp;", "&")
            print(f"Found Academic Rules link: {academic_rules_url}")  # Debug print        
            academic_soup = get_soup(academic_rules_url)
            if academic_soup:
                table = academic_soup.find("table")
                
                if table:
                    text = " ".join(table.stripped_strings)  # Extract all text
                    data.append({"School": school_name, "Text": text})
    
    time.sleep(1)  # Politeness delay

# Step 3: Save data to CSV and data frame
df = pd.DataFrame(data)
df.to_csv("uva_schools_academic_rules.csv", index=False)

print("Scraping complete! Data saved to 'uva_schools_academic_rules.csv'.")
# Out:
# Found link: School of Architecture -> http://records.ureg.virginia.edu/content.php?catoid=61&navoid=5306
# Found link: College of Arts & Sciences -> http://records.ureg.virginia.edu/content.php?catoid=61&navoid=5305
# Found link: McIntire School of Commerce -> http://records.ureg.virginia.edu/content.php?catoid=61&navoid=5295
# Found link: School of Continuing and Professional Studies -> http://records.ureg.virginia.edu/content.php?catoid=61&navoid=5310
# Found link: School of Data Science -> http://records.ureg.virginia.edu/content.php?catoid=61&navoid=5281
# Found link: School of Education and Human Development -> http://records.ureg.virginia.edu/content.php?catoid=61&navoid=5307
# Found link: School of Engineering and Applied Science -> http://records.ureg.virginia.edu/content.php?catoid=61&navoid=5308
# Found link: Frank Batten School of Leadership and Public Policy -> http://records.ureg.virginia.edu/content.php?catoid=61&navoid=5311
# Found link: School of Nursing -> http://records.ureg.virginia.edu/content.php?catoid=61&navoid=5309
# Found 9 schools.
# School: School of Architecture, URL: http://records.ureg.virginia.edu/content.php?catoid=61&navoid=5306
# School: College of Arts & Sciences, URL: http://records.ureg.virginia.edu/content.php?catoid=61&navoid=5305
# School: McIntire School of Commerce, URL: http://records.ureg.virginia.edu/content.php?catoid=61&navoid=5295
# School: School of Continuing and Professional Studies, URL: http://records.ureg.virginia.edu/content.php?catoid=61&navoid=5310
# School: School of Data Science, URL: http://records.ureg.virginia.edu/content.php?catoid=61&navoid=5281
# School: School of Education and Human Development, URL: http://records.ureg.virginia.edu/content.php?catoid=61&navoid=5307
# School: School of Engineering and Applied Science, URL: http://records.ureg.virginia.edu/content.php?catoid=61&navoid=5308
# School: Frank Batten School of Leadership and Public Policy, URL: http://records.ureg.virginia.edu/content.php?catoid=61&navoid=5311
# School: School of Nursing, URL: http://records.ureg.virginia.edu/content.php?catoid=61&navoid=5309
# Scraping: School of Architecture
# Found Academic Rules link: https://records.ureg.virginia.edu/content.php?catoid=61&navoid=5227
# Scraping: College of Arts & Sciences
# Found Academic Rules link: https://records.ureg.virginia.edu/content.php?catoid=61&navoid=5224
# Scraping: McIntire School of Commerce
# Found Academic Rules link: https://records.ureg.virginia.edu/content.php?catoid=61&navoid=5230
# Scraping: School of Continuing and Professional Studies
# Found Academic Rules link: https://records.ureg.virginia.edu/content.php?catoid=61&navoid=5263
# Scraping: School of Data Science
# Found Academic Rules link: https://records.ureg.virginia.edu/content.php?catoid=61&navoid=5282
# Scraping: School of Education and Human Development
# Found Academic Rules link: https://records.ureg.virginia.edu/content.php?catoid=61&navoid=5243
# Scraping: School of Engineering and Applied Science
# Found Academic Rules link: https://records.ureg.virginia.edu/content.php?catoid=61&navoid=5250
# Scraping: Frank Batten School of Leadership and Public Policy
# Found Academic Rules link: https://records.ureg.virginia.edu/content.php?catoid=61&navoid=5256
# Scraping: School of Nursing
# Found Academic Rules link: https://records.ureg.virginia.edu/content.php?catoid=61&navoid=5261
# Scraping complete! Data saved to 'uva_schools_academic_rules.csv'.

# %%
# remove the extra text from the text column
extra_begining_text = 'Info For Students Alumni Military Affiliated Students Faculty & Staff Search Search Submit Search Close search Info For Students Alumni Military Affiliated Students Faculty & Staff Calendars Academic Calendars Exam Schedules Student Records Diplomas Transcripts FERPA Programs Calendar Schools University Registrar Carruthers Hall, 1001 N. Emmet St. P.O. Box 400203 Charlottesville, VA 22904-4203 Staff Directory Contact Info Phone: (434) 924-4122 Fax: (434) 924-4156 Email: [email protected] Hours Of Operation M-F: 10am - noon and 1pm - 4pm Â© 2024 By the Rector and Visitors of the University of Virginia Legal Privacy Report a Barrier Share Your Feedback University of Virginia Mar 31, 2025 Undergraduate Record 2024-2025 Select a Catalog Undergraduate Record 2024-2025 Graduate Record 2024-2025 Global Search Catalog Search Choose Search Location Select an option Courses Programs Schools/Colleges & Departments Policies and Other Non-Academic Content Entire Catalog Search Keyword Field Whole Word/Phrase Advanced Search Catalog Navigation Catalog Home Academic Calendar Admission Schools Programs, Degrees & Course Info Student Resources ROTC University Regulations About UVA Archived Records HELP Undergraduate Record 2024-2025'

def remove_text_requirements(text):
    if text.startswith(extra_begining_text):
        text = text[len(extra_begining_text):]
    return text.strip()

df['Text'] = df['Text'].apply(remove_text_requirements)

# %%
df
# Out:
#                                               School  \
# 0                             School of Architecture
# 1                         College of Arts & Sciences
# 2                        McIntire School of Commerce
# 3      School of Continuing and Professional Studies
# 4                             School of Data Science
# 5          School of Education and Human Development
# 6          School of Engineering and Applied Science
# 7  Frank Batten School of Leadership and Public P...
# 8                                  School of Nursing
#
#                                                 Text
# 0  School of Architecture: Academic Rules, Regula...
# 1  College of Arts & Sciences: Academic Rules, Re...
# 2  McIntire School of Commerce: Academic Rules, R...
# 3  School of Continuing and Professional Studies:...
# 4  School of Data Science: Academic Rules Print-F...
# 5  School of Education and Human Development: Aca...
# 6  School of Engineering and Applied Science: Aca...
# 7  Frank Batten School of Leadership and Public P...
# 8  School of Nursing: Academic Rules, Regulations...
